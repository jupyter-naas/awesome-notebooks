# %% [markdown]
# <img width="8%" alt="OS.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OS.png" style="border-radius: 15%">

# %% [markdown]
# # OS - Rename file
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OS+-+Rename+file:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #os #python #snippet #operations

# %% [markdown]
# **Author:** [Divakar](https://www.linkedin.com/in/divakar-r-9b34b86b/)

# %% [markdown]
# **Last update:** 2023-06-06 (Created: 2023-06-06)

# %% [markdown]
# **Description:** This notebook will show how to rename file using os library.

# %% [markdown]
# **References:**
# - [OS Module Python Tutorial](https://pythonprogramming.net/python-3-os-module/)
# - [os — Miscellaneous operating system interfaces](https://docs.python.org/3/library/os.html)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import os

# %% [markdown]
# ### Setup Variables
# - `input_file_path`: input file path
# - `output_file_path`: output file path

# %%
input_file_path = "test1.ppt"
output_file_path = "test2.ppt"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Rename file using os

# %%
os.rename(input_file_path, output_file_path)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print(f"File {input_file_path} successfully renamed: {output_file_path}!")
