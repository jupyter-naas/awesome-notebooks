# %% [markdown]
# <img width="8%" alt="YouTube.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/YouTube.png" style="border-radius: 15%">

# %% [markdown]
# # YouTube - Download video
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=YouTube+-+Download+video:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #youtube #download #video #content #snippet #naas

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-06-03 (Created: 2022-03-18)

# %% [markdown]
# **Description:** This notebook allows users to download videos from YouTube.

# %% [markdown]
# **References:**
# - [pytube library](https://pypi.org/project/pytube/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    from pytube import YouTube
except:
    # !pip install pytube --user
    from pytube import YouTube

# %% [markdown]
# ### Setup Variables
# - `youtube_video_url`: YouTube video URL
# - `output_dir`: Output directory to save the video.

# %%
# Inputs
youtube_video_url = "https://www.youtube.com/watch?v=ONiILHFItzs"

# Outputs
output_dir = "videos"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Init YouTube obj

# %%
try:
    yt_obj = YouTube(youtube_video_url)
except:
    # !pip install pytube --upgrade --user
    yt_obj = YouTube(youtube_video_url)

# %% [markdown]
# ### Display Youtube URL streams

# %%
for stream in yt_obj.streams:
    print(stream)

# %% [markdown]
# ### Get MP4 Quality

# %%
videos_mp4 = yt_obj.streams.filter(progressive=True, file_extension="mp4")

for videos in videos_mp4:
    print(videos)

# %% [markdown]
# ### Get highest resolution

# %%
video_highest_resolution = videos_mp4.get_highest_resolution()
video_highest_resolution

# %% [markdown]
# ## Output

# %% [markdown]
# ### Download video
# If output_dir does not exist, it will be created

# %%
video_highest_resolution.download(output_path=output_dir)
