# %% [markdown]
# <img width="8%" alt="YouTube.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/YouTube.png" style="border-radius: 15%">

# %% [markdown]
# # YouTube - Extract and summarize transcript
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=YouTube+-+Extract+and+summarize+transcript:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #youtube #transcript #video #summarize #content #snippet #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/ACoAABCNSioBW3YZHc2lBHVG0E_TXYWitQkmwog/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-03-18)

# %% [markdown]
# **Description:** This notebook provides a method to extract and summarize the transcript of a YouTube video.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Install packages

# %%
# !pip install youtube_transcript_api

# %% [markdown]
# ### Import library

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from naas_drivers import huggingface

# %% [markdown]
# ### Variables

# %%
video_id = "I6XbLIRa0v0"
file_name = "What on earth is data science?"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Extract the transcript in JSON

# %%
json = YouTubeTranscriptApi.get_transcript(video_id)

# %% [markdown]
# ### Parse JSON in text string

# %%
para = ""
for i in json:
    para += i["text"]
    para += " "
para

# %%
text = huggingface.get("summarization", model="t5-small", tokenizer="t5-small")(para)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display results

# %%
text
