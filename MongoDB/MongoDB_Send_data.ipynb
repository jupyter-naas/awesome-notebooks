# %% [markdown]
# <img width="8%" alt="MongoDB.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/MongoDB.png" style="border-radius: 15%">

# %% [markdown]
# # MongoDB - Send data
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=MongoDB+-+Send+data:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #mongodb #database #naas_drivers #snippet #operations #naas

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/ACoAABCNSioBW3YZHc2lBHVG0E_TXYWitQkmwog/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-03-03)

# %% [markdown]
# **Description:** This notebook provides instructions on how to send data to a MongoDB database.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import mongo
import pandas as pd

# %% [markdown]
# ### Variables

# %%
# Credentials
user = "my user"
passwd = "my passwd"
host = "url"
port = 9090

# DB parameters
collection_name = "col"
db_name = "db_name"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Read dataframe

# %%
data = {"LABEL": "Label 1", "VALUE": 0}
df = pd.DataFrame([data])
df

# %% [markdown]
# ## Output

# %% [markdown]
# ### Send data

# %%
mongo.connect(host, port, user, passwd).send(
    df, collection_name, db_name, replace=False
)
