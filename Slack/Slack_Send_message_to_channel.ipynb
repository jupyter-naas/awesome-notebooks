# %% [markdown]
# <img width="8%" alt="Slack.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Slack.png" style="border-radius: 15%">

# %% [markdown]
# # Slack - Send message
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Slack+-+Send+message:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #slack #message #send #operations #snippet

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-06-22 (Created: 2023-06-22)

# %% [markdown]
# **Description:** This notebook allows you to quickly and easily send text messages through Slack.

# %% [markdown]
# **References:**
# - [Sending messages](https://api.slack.com/messaging/sending)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import needed library

# %%
from naas_drivers import slack
import naas

# %% [markdown]
# ### Setup Variables
# - Create [Slack App](https://api.slack.com/apps)
# - Add OAuth & Permissions(chat:write, chat:write.public to send message in a public channel)
# - Install your App
# - Get your Bot Token
#
# Once it's done, update the variables below and run the notebook.
#
# - `slack_token`: This is where you place the Bot token
# - `slack_channel`: the channel where you wish to send the message
# - `text_message`: the message you wish to send

# %%
slack_token = naas.secret.get("SLACK_TOKEN") or "SLACK_TOKEN"
slack_channel = "channel-name" 
text_message = "Hello World!"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Connect to Slack

# %%
SLACK = slack.connect(slack_token)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Send your message

# %%
SLACK.send(slack_channel, text_message)
