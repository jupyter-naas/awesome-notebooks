# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - Delete Asset
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+Delete+Asset:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #asset #snipet #operations

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-08-16 (Created: 2023-03-21)

# %% [markdown]
# **Description:** This notebook will show how to delete an asset from naas production environment.

# %% [markdown]
# **References:**
# - [Deleting Assets](https://site.naas.ai/docs/framework/jobs/asset/#deleting-assets)
# - [Naas Asset Documentation](https://site.naas.ai/docs/framework/jobs/asset)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import naas

# %% [markdown]
# ### Setup Variables
# - `path`: Go to your Naas manager, section "Jobs" and copy/paste the path of the asset you want to delete.
#
# If this notebook is not on your root folder, you need to set absolute path of your notebook starting with "/home/ftp/".

# %%
path = "/home/ftp/"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Delete Asset

# %%
naas.asset.delete(path=path)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print("🗑 Done! Your Assets has been remove from production.")
