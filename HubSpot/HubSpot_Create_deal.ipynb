# %% [markdown]
# <img width="8%" alt="HubSpot.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/HubSpot.png" style="border-radius: 15%">

# %% [markdown]
# # HubSpot - Create deal
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=HubSpot+-+Create+deal:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #hubspot #crm #sales #deal #naas_drivers #snippet

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-02-21)

# %% [markdown]
# **Description:** This notebook allows users to create deals in HubSpot, helping them to manage their sales pipeline.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import hubspot
import naas

# %% [markdown]
# ### Setup HubSpot
# 👉 Starting November 30, 2022, HubSpot API keys no longer enable access to HubSpot APIs, so in Naas version 2.8.3 and above, you need [create a private app and use the access token](https://developers.hubspot.com/docs/api/private-apps).

# %% [markdown]
# #### Enter Your Access Token

# %%
HS_ACCESS_TOKEN = naas.secret.get("HS_ACCESS_TOKEN") or "YOUR_HS_ACCESS_TOKEN"

# %% [markdown]
# #### Enter deal parameters

# %%
dealname = "TEST"
closedate = None  # must be in format %Y-%m-%d
amount = None
hubspot_owner_id = None

# %% [markdown]
# #### Enter deal stage ID

# %%
df_pipelines = hubspot.connect(HS_ACCESS_TOKEN).pipelines.get_all()
df_pipelines

# %%
dealstage = "5102584"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create deal using send method
# This method will allow you to add any deal properties available in your HubSpot.

# %%
deal1 = {
    "properties": {
        "dealstage": dealstage,
        "dealname": dealname,
        "amount": amount,
        "closedate": closedate,
        "hubspot_owner_id": hubspot_owner_id,
    }
}

deal1 = hubspot.connect(HS_ACCESS_TOKEN).deals.send(send_deal)

# %% [markdown]
# ### Create deal using create method

# %%
deal2 = hubspot.connect(HS_ACCESS_TOKEN).deals.create(dealname, dealstage, closedate)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display results

# %%
deal1

# %%
deal2
