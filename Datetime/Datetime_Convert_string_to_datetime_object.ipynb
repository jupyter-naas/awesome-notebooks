# %% [markdown]
# <img width="8%" alt="Datetime.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Datetime.png" style="border-radius: 15%">

# %% [markdown]
# # Datetime - Convert a string date to a datetime object
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Datetime+-+Convert+a+string+date+to+a+datetime+object:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #datetime #snippet #operations #python

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-07-05 (Created: 2023-07-05)

# %% [markdown]
# **Description:** This notebook converts a string date to a datetime object

# %% [markdown]
# **References:**
# - [Python datetime library](https://docs.python.org/3/library/datetime.html)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from datetime import datetime

# %% [markdown]
# ### Setup Variables
# To parse your date format : you can use the [d3 time format documentation](https://github.com/d3/d3-time-format)
# - `date_string`: Date string
# - `current_format`: Date string format

# %%
# Date string format
date_string = "2022-02-25"

# Your date string format
current_format = "%Y-%m-%d"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Convert a string date to a datetime object

# %%
datetime_obj = datetime.strptime(date_string, current_format)
datetime_obj

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print(datetime_obj)
