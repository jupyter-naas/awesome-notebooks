# %% [markdown]
# <img width="8%" alt="Polars.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Polars.png" style="border-radius: 15%">

# %% [markdown]
# # Polars - Concatenate DataFrames
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Polars+-+Concatenate+DataFrames:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #polars #dataframes #concatenate #python #pandas #data #snippet

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-07-25 (Created: 2023-07-25)

# %% [markdown]
# **Description:** This notebook explains how to concatenate DataFrames using Polars and Python. It is usefull for data analysis and data manipulation.

# %% [markdown]
# **References:**
# - [Polars.concat](https://pola-rs.github.io/polars/py-polars/html/reference/api/polars.concat.html)
# - [Pandas Documentation - Concatenation](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html#concatenating-objects)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import polars as pl
except ModuleNotFoundError:
    # !pip install polars
    import polars as pl

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create DataFrames

# %%
df1 = pl.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
)
df1

# %%
df2 = pl.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
)
df2

# %%
df3 = pl.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
)
df3

# %% [markdown]
# ## Output

# %% [markdown]
# ### Concatenate DataFrames

# %%
# Concatenate DataFrames
frames = [df1, df2, df3]
result = pl.concat(frames)

# Display result
result
