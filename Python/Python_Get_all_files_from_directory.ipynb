# %% [markdown]
# <img width="8%" alt="Python.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Python.png" style="border-radius: 15%">

# %% [markdown]
# # Python - Get all files from directory
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Python+-+Get+all+files+from+directory:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #python #naas #glob #pprint #snippet

# %% [markdown]
# **Author:** [Ayoub Berdeddouch](https://www.linkedin.com/ayoub-berdeddouch)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-10-18)

# %% [markdown]
# **Description:** This notebook gives you the ability to get all files from a directory even in a sub-directory.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import glob
from os import path

# %% [markdown]
# ### Setup Variables

# %%
dir_path = ""  # If dir path is "", it will returned files from current folder

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get all files

# %%
files = glob.glob(path.join(dir_path, "**"), recursive=True)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Dislay result

# %%
print(f"Total files and folders fetched:", len(files))
sorted(files)
