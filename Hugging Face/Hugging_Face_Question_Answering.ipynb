# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Hugging Face - Question Answering
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/Hugging%20Face/Hugging_Face_Ask_boolean_question_to_T5.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #huggingface #ml #question_answer #ai #text #snippet

# %% [markdown]
# **Author:** [Muhammad Talha Khan](https://www.linkedin.com/in/muhtalhakhan/)

# %% [markdown]
# ## Hugging Face Transformers QA Pipeline
#
# Question Answering models can retrieve the answer to a question from a given text, which is useful for searching for an answer in a document. Some question answering models can generate answers without context!

# %% [markdown]
# ## Input

# %% [markdown]
# ### Install Packages

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (2.9.2)
# Requirement already satisfied: setuptools in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.21.4)
# Requirement already satisfied: packaging in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (21.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.41.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.3.3)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from packaging->tensorflow) (2.4.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kzp12\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)

# %% [markdown]
# Use "--user" if it asks for permission prompt.

# %% [markdown]
# ### Import Libraries

# %%
try:
    from transformers import pipeline
except:
    # !pip install -q transformers
    from transformers import pipeline
# try:
#     import gradio as gr
# except:
#     !pip install gradio --user
#     import gradio as gr

# %%
# !pip install -q transformers

# %% [markdown]
# ## Model

# %% [markdown]
# ### Loading the pipeline
# Import Pipeline from Transformer after installing the transformers and tensorflow.

# %%
nlp = pipeline('question-answering', model='deepset/roberta-base-squad2', tokenizer='deepset/roberta-base-squad2')
# Out:
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# C:\Users\Kzp12\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:123: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Kzp12\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading:   0%|          | 0.00/497M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFRobertaForQuestionAnswering.
#
# All the layers of TFRobertaForQuestionAnswering were initialized from the model checkpoint at deepset/roberta-base-squad2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForQuestionAnswering for predictions without further training.
# Downloading:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]

# %% [markdown]
# ### QNA model

# %%
context = input('Enter your context:\n') 
question = input('\nEnter your question:\n')

question_set = {
        'context': context,
        'question': question
    }

results = nlp(question_set)
# Out:
# Enter your context:
# My name is Muhammad Talha Khan, my brother lives in southern punjab, and I lives in Utopia.
#
# Enter your question:
# What is Talha's last name?

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display output
# For the output a new window is opened at the link provided above by Gradio, where you can enter your context and get your answer delivered.

# %%
print("\nAnswer: " + results['answer'])
# Out:
# Answer: Muhammad Talha Khan
