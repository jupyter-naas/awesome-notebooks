# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Naas - Secret demo
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/Naas/Naas_Secret_demo.ipynb" target="_parent"><img src="https://img.shields.io/badge/-Open%20in%20Naas-success?labelColor=000000&logo=data:image/svg+xml;base64,..."/></a>

# %% [markdown]
# **Tags:** #naas #secret

# %% [markdown]
# Read the doc: https://naas.gitbook.io/naas/features/secret

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
import naas

# %% [markdown]
# ## Model

# %% [markdown]
# ### Variable for the secret

# %%
API_NAME = "HUBSPOT"
API_KEY = "123456789"

# %% [markdown]
# ## Output

# %% [markdown]
# ### Add the secret

# %%
naas.secret.add(name="API_NAME", secret="API_KEY")
