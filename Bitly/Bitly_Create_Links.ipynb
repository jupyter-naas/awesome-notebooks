# %% [markdown]
# <img width="8%" alt="Bitly.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Bitly.png" style="border-radius: 15%">

# %% [markdown]
# # Bitly - Create Links
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Bitly+-+Create+Links:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #bitly #link #shorten #url #create #python

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-02-16)

# %% [markdown]
# **Description:** This notebook will show how to create short links with Bitly.

# %% [markdown]
# <u>References:</u>
# - [Bitly Documentation](https://dev.bitly.com/v4_documentation.html)
# - [Bitly API](https://dev.bitly.com/get_started.html)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import requests
import json

# %% [markdown]
# ### Setup Variables
# - `token`: [Generate a Bitly Access Token](https://dev.bitly.com/get_started.html)
# - `long_url`: URL to be shortened

# %%
token = "<YOUR_TOKEN_HERE>"
long_url = "https://www.example.com/"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Shorten URL

# %% [markdown]
# This function will use the Bitly API to shorten a given URL.

# %%
def shorten_url(token, long_url):
    url = "https://api-ssl.bitly.com/v4/shorten"
    headers = {"Authorization": "Bearer " + token}
    payload = {"long_url": long_url}
    response = requests.post(url, headers=headers, json=payload)
    response_json = response.json()
    return response_json["link"]

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
short_url = shorten_url(token, long_url)
print(short_url)
