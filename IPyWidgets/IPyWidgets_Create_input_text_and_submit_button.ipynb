# %% [markdown]
# <img width="8%" alt="Naas" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # IPyWidgets - Create input text and submit button
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=IPyWidgets+-+Create+input+text+and+submit+button:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #ipywidgets #naas #secret #snippet #operation #button #text

# %% [markdown]
# **Author:** [Ismail CHIHAB](https://www.linkedin.com/in/ismail-chihab-4b0a04202/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-08-05)

# %% [markdown]
# **Description:** This notebook demonstrates how to use IPyWidgets to create an interactive input text box and submit button.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from IPython.display import display, clear_output
from ipywidgets import widgets

# %% [markdown]
# ### Setup variable

# %%
# Text area variables:
input_description = "Description"
style = {"description_width": "150px"}
layout = widgets.Layout(width="400px")
value = "Enter your value here"

# Button variables:
button_description = "Submit"
button_style = "success"

# Result variables:
result_message = "Your input is:"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Setup widgets and event on click

# %%
# Setup input text widget
text = widgets.Text(
    description=input_description, value=value, style=style, layout=layout
)

# Setup button widget
button = widgets.Button(description=button_description, button_style=button_style)

# Setup HBox to display widget horizontally
Box = widgets.HBox([text, button])

# Setup output
output = widgets.Output()

# Event on click
def save(b):
    output.clear_output()
    with output:
        print(result_message, text.value)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display secret
# If secret empty, default value is displayed.

# %%
# Display
display(Box, output)
button.on_click(save)
