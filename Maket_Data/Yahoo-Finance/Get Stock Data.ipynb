# %% [markdown]
# # Get Stock Data

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/en/archive/7/70/20191225000430%21Yahoo_Finance_Logo_2019.jpg" alt="drawing" width="100" align='left'/>
# <br>

# %% [markdown]
# ### 1. Install the quandl package

# %%
#!pip install yfinance

# %% [markdown]
# ### 2. Import the quandl package

# %%
import yfinance as yf

# %% [markdown]
# ### 3. Get the data for the stock AAPL

# %%
data = yf.download('TSLA','2016-01-01','2019-08-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### 4. Import the plotting library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 5. Plot the close price of the AAPL

# %%
data['Adj Close'].plot()
plt.show()
