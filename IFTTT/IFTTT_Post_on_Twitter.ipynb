# %% [markdown]
# <img width="8%" alt="IFTTT.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/IFTTT.png" style="border-radius: 15%">

# %% [markdown]
# # IFTTT - Post on Twitter
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=IFTTT+-+Post+on+Twitter:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #ifttt #nocode #snippet #marketing #twitter

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-02-28)

# %% [markdown]
# **Description:** This notebook allows you to post messages to Twitter using IFTTT.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import ifttt

# %% [markdown]
# ### Variables

# %%
twitter_post = """Hello world, this is my first automated post 
                with @JupyterNaas @IFTTT driver🔥
                """
event = "naas_demo"
key = "ke4AigvXI5-EABaowdLt4fju1aOUxeMxSXQoN***"
data = {"value1": twitter_post}

# %% [markdown]
# ## Model

# %% [markdown]
# ### Connect to IFTTT

# %%
result = ifttt.connect(key)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
result = ifttt.send(event, data)
