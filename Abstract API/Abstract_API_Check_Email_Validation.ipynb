# %% [markdown]
# <img width="8%" alt="Abstract API.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Abstract%20API.png" style="border-radius: 15%">

# %% [markdown]
# # Abstract API - Check Email Validation
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Abstract+API+-+Check+Email+Validation:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #abstractapi #email #validation #api #check #tester

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-02-23)

# %% [markdown]
# **Description:** This notebook will demonstrate how to use Abstract API to check if an email is valid.

# %% [markdown]
# **References:**
# - [Abstract API - Email Validation](https://app.abstractapi.com/api/email-validation/tester)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import requests
import naas
from pprint import pprint

# %% [markdown]
# ### Setup Variables
# - `api_key`: [Get your API key](https://app.abstractapi.com/signup)
# - `email`: Email to be validated

# %%
api_key = naas.secret.get("ABSTRACT_API") or "YOUR_API_KEY"
email = "florent@naas.ai"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Validate Email

# %% [markdown]
# Validate an email address using Abstract API's Email Validation API.

# %%
url = f"https://emailvalidation.abstractapi.com/v1/?api_key={api_key}&email={email}"
response = requests.get(url)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
pprint(response.json())
