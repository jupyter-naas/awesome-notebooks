# %% [markdown]
# <img width="8%" alt="Geopy.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Geopy.png" style="border-radius: 15%">

# %% [markdown]
# # Geopy - Calculate distance between two locations in kilometers
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Geopy+-+Calculate+distance+between+two+locations+in+kilometers:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #geopy #distance #navigation #snippet

# %% [markdown]
# **Author:** [Antonio Georgiev](www.linkedin.com/in/antonio-georgiev-b672a325b)

# %% [markdown]
# **Last update:** 2023-07-28 (Created: 2023-07-28)

# %% [markdown]
# **Description:** This notebook demonstrates how to calculate distance between two locations in kilometers using `geopy`.

# %% [markdown]
# **References:**
# - [Nominatim geocoder for OpenStreetMap data](https://geopy.readthedocs.io/en/stable/#nominatim)
# - [Calculating Distance](https://geopy.readthedocs.io/en/stable/index.html?highlight=distance#module-geopy.distance)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from geopy.geocoders import Nominatim
from geopy.distance import geodesic

# %% [markdown]
# ### Setup variables
# **Mandatory**
#
# - `address1`: Address to be used to get coordinates
# - `address2`: Address to be used to get coordinates

# %%
address1 = "Bulgaria Blvd 69, 1404 Manastirski Livadi, Sofia, Bulgaria"
address2 = "Sofia, 1680, Bulgaria"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get locations

# %%
geolocator = Nominatim(user_agent="distance_calculator")
location1 = geolocator.geocode(address1)
location2 = geolocator.geocode(address2)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Calculate distance

# %%
distance = geodesic((location1.latitude, location1.longitude), (location2.latitude, location2.longitude)).kilometers
rounded_distance = round(distance, 2)
print("Distance between the two addresses:", rounded_distance, "km")
