# %% [markdown]
# <img width="8%" alt="Qonto.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Qonto.png" style="border-radius: 15%">

# %% [markdown]
# # Qonto - Get statement summary by operation type
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Qonto+-+Get+statement+summary+by+operation+type:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #qonto #bank #statement #naas_drivers #finance #snippet #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-02-16)

# %% [markdown]
# **Description:** This notebook provides a summary of financial operations by type for Qonto users.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import qonto

# %% [markdown]
# ### Get your Qonto credentials
# <a href='https://www.notion.so/naas-official/Qonto-driver-Get-your-credentials-0cc97828b4e7467c8bfbcf704a77e5f4'>How to get your credentials ?</a>

# %%
QONTO_USER_ID = "YOUR_USER_ID"
QONTO_SECRET_KEY = "YOUR_SECRET_KEY"

# %% [markdown]
# ### Parameters

# %%
# Date to start extraction, format: "AAAA-MM-JJ", example: "2021-01-01"
date_from = None
# Date to end extraction, format: "AAAA-MM-JJ", example: "2021-01-01", default = now
date_to = None

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get statement summary

# %%
df_summary = qonto.connect(QONTO_USER_ID, QONTO_SECRET_KEY).statements.summary(
    summary_type="OPERATION_TYPE", date_from=date_from, date_to=date_to
)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
df_summary
