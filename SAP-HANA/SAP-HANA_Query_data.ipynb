# %% [markdown]
# <img width="8%" alt="SAP-HANA.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/SAP-HANA.png" style="border-radius: 15%">

# %% [markdown]
# # SAP-HANA - Query data
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=SAP-HANA+-+Query+data:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #sap-hana #sap #saphana #database #snippet #operations #dataframe

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-03-01)

# %% [markdown]
# **Description:** This notebook provides an introduction to querying data in SAP HANA.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Install packages

# %%
# !pip install hdbcli

# %% [markdown]
# ### Import library

# %%
import sap_hana_connector

# %% [markdown]
# ### Declare variables

# %%
type: "SapHana"
name: "JPAK_LIVE"
user: "USER"
password: "PASSWORD"
port: 30015
host: "HOST"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Query to get specific table in SAP HANA

# %%
query: "SELECT * FROM JPAK_LIVE.OINV T0"

# %% [markdown]
# ## Output

# %% [markdown]
# ### Return Data Frame

# %%
df = query
