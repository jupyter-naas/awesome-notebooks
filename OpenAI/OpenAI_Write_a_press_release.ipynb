# %% [markdown]
# <img width="8%" alt="OpenAI.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OpenAI.png" style="border-radius: 15%">

# %% [markdown]
# # OpenAI - Write a press release
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OpenAI+-+Write+a+press+release:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #openai #pressrelease #writing #communication #publicrelations #journalism

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-02-24)

# %% [markdown]
# **Description:** This notebook will provide a guide to write using OpenAI API.

# %% [markdown]
# **References:**
# - [OpenAI](https://openai.com/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import openai
except:
    # !pip install openai --user
    import openai
import naas

# %% [markdown]
# ### Setup Variables
# - `api_key`: OpenAI API key, to obtain an OpenAI API key, please refer to the [OpenAI Documentation](https://openai.com/docs/).
# - `topic`: the topic of the blog post

# %%
# Inputs
api_key = naas.secret.get(name="OPENAI_API_KEY") or "ENTER_YOUR_OPENAI_API_KEY"
topic = "naas.ai re-launch March 2023"
prompt = f"Write a press release about '{topic}'"

# Outputs
file_path = f"Press_Release_{topic.replace(' ', '_')}.txt"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Send requests to OpenAI API

# %%
openai.api_key = api_key
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=prompt,
    max_tokens=2084,
    temperature=0.7,
    top_p=0.9
)

# %% [markdown]
# ### Get text

# %%
text = response['choices'][0]['text']
print(text)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save text to txt file

# %%
text_file = open(file_path, "w")
text_file.write(text)
text_file.close()
