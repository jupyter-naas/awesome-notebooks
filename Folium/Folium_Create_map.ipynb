# %% [markdown]
# <img width="8%" alt="Folium.jpg" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Folium.jpg" style="border-radius: 15%">

# %% [markdown]
# # Folium - Create map
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Folium+-+Create+map:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #folium #map #leaflet #snippet

# %% [markdown]
# **Author:** [Florent Ravenel](www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-07-31 (Created: 2023-07-31)

# %% [markdown]
# **Description:** This notebook creates a map with Folium and Leaflet.js.

# %% [markdown]
# **References:**
# - [PyPI folium](https://pypi.org/project/folium/)
# - [Using Leaflet and Folium to make interactive maps in Python](https://www.earthdatascience.org/tutorials/introduction-to-leaflet-animated-maps/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import folium
except:
    # !pip install folium --user
    import folium

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create map

# %%
folium_map = folium.Map()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display map

# %%
folium_map
