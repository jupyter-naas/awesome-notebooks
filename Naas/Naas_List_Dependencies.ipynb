# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - List Dependencies
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+List+Dependencies:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #dependency #snipet #operations #list

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-05-24 (Created: 2023-05-24)

# %% [markdown]
# **Description:** This notebook will show how to list current dependencies in production.

# %% [markdown]
# **References:**
# - [Naas Documentation](https://docs.naas.ai/)
# - [Naas Dependency Documentation](https://docs.naas.ai/features/dependency)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import naas

# %% [markdown]
# ## Model

# %% [markdown]
# ### List current Dependencies

# %%
dependencies = naas.dependency.currents()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print("Dependencies found in production:", len(dependencies))
dependencies.head(5)
