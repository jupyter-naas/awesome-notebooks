# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # GitHub - List repository events

# %% [markdown]
# **Tags:** #github #api #rest #events #repository #list

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Description:** This notebook will list repository events from GitHub using the REST API. It is usefull for organizations to keep track of their repositories.

# %% [markdown]
# **References:**
# - [GitHub REST API](https://docs.github.com/en/rest/reference/events)
# - [List repository events](https://docs.github.com/en/rest/activity/events?apiVersion=2022-11-28#list-repository-events)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import requests
import naas

# %% [markdown]
# ### Setup Variables
# - `token`: [GitHub personal access token](https://docs.github.com/en/github/authenticating-to-github/creating-a-personal-access-token)
# - `owner`: owner of the repository
# - `repo`: name of the repository

# %%
token = naas.secret.get("GITHUB_TOKEN") or "YOUR_GITHUB_TOKEN"
owner = "jupyter-naas"
repo = "awesome-notebooks"

# %% [markdown]
# ## Model

# %% [markdown]
# ### List repository events

# %% [markdown]
# This function will list repository events from GitHub using the REST API.

# %%
def list_repo_events(token, owner, repo):
    url = f"https://api.github.com/repos/{owner}/{repo}/events"
    headers = {"Authorization": f"token {token}"}
    response = requests.get(url, headers=headers)
    return response.json()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result
# - created_at: 2023-07-13T14:02:26Z'
# - type: 'IssueCommentEvent'
# - actor.login: 'Benjifilly'
# - action: 'Ready to review'
# - issue: 'number'

# %%
import pprint 
events = list_repo_events(token, owner, repo)
pprint.pprint(events[0])
# Out:
# {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?',
#            'display_login': 'Benjifilly',
#            'gravatar_id': '',
#            'id': 112804903,
#            'login': 'Benjifilly',
#            'url': 'https://api.github.com/users/Benjifilly'},
#  'created_at': '2023-07-13T15:00:32Z',
#  'id': '30403974726',
#  'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#          'gravatar_id': '',
#          'id': 71603764,
#          'login': 'jupyter-naas',
#          'url': 'https://api.github.com/orgs/jupyter-naas'},
#  'payload': {'before': '883ee483379169ce0e892eaf9a23ddc70fa2a17c',
#              'commits': [{'author': {'email': 'Benji.filly@gmail.com',
#                                      'name': 'Benjifilly'},
#                           'distinct': True,
#                           'message': 'feat: update unfinished',
#                           'sha': '00062b9e16b082af527ae5f979462b9a0d085670',
#                           'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/commits/00062b9e16b082af527ae5f979462b9a0d085670'}],
#              'distinct_size': 1,
#              'head': '00062b9e16b082af527ae5f979462b9a0d085670',
#              'push_id': 14309972256,
#              'ref': 'refs/heads/1978-github-get-dataframe-from-project-view',
#              'repository_id': 299951448,
#              'size': 1},
#  'public': True,
#  'repo': {'id': 299951448,
#           'name': 'jupyter-naas/awesome-notebooks',
#           'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#  'type': 'PushEvent'}

# %%
pprint.pprint(events)
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?',
#             'display_login': 'Benjifilly',
#             'gravatar_id': '',
#             'id': 112804903,
#             'login': 'Benjifilly',
#             'url': 'https://api.github.com/users/Benjifilly'},
#   'created_at': '2023-07-13T15:00:32Z',
#   'id': '30403974726',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'before': '883ee483379169ce0e892eaf9a23ddc70fa2a17c',
#               'commits': [{'author': {'email': 'Benji.filly@gmail.com',
#                                       'name': 'Benjifilly'},
#                            'distinct': True,
#                            'message': 'feat: update unfinished',
#                            'sha': '00062b9e16b082af527ae5f979462b9a0d085670',
#                            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/commits/00062b9e16b082af527ae5f979462b9a0d085670'}],
#               'distinct_size': 1,
#               'head': '00062b9e16b082af527ae5f979462b9a0d085670',
#               'push_id': 14309972256,
#               'ref': 'refs/heads/1978-github-get-dataframe-from-project-view',
#               'repository_id': 299951448,
#               'size': 1},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?',
#             'display_login': 'Benjifilly',
#             'gravatar_id': '',
#             'id': 112804903,
#             'login': 'Benjifilly',
#             'url': 'https://api.github.com/users/Benjifilly'},
#   'created_at': '2023-07-13T14:02:26Z',
#   'id': '30402195650',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'action': 'created',
#               'comment': {'author_association': 'CONTRIBUTOR',
#                           'body': 'Ready to review',
#                           'created_at': '2023-07-13T14:02:25Z',
#                           'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666#issuecomment-1634303909',
#                           'id': 1634303909,
#                           'issue_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666',
#                           'node_id': 'IC_kwDOEeDlWM5haX-l',
#                           'performed_via_github_app': None,
#                           'reactions': {'+1': 0,
#                                         '-1': 0,
#                                         'confused': 0,
#                                         'eyes': 0,
#                                         'heart': 0,
#                                         'hooray': 0,
#                                         'laugh': 0,
#                                         'rocket': 0,
#                                         'total_count': 0,
#                                         'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/comments/1634303909/reactions'},
#                           'updated_at': '2023-07-13T14:02:25Z',
#                           'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/comments/1634303909',
#                           'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                    'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                    'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                    'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                    'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                    'gravatar_id': '',
#                                    'html_url': 'https://github.com/Benjifilly',
#                                    'id': 112804903,
#                                    'login': 'Benjifilly',
#                                    'node_id': 'U_kgDOBrlEJw',
#                                    'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                    'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                    'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                    'site_admin': False,
#                                    'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                    'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                    'type': 'User',
#                                    'url': 'https://api.github.com/users/Benjifilly'}},
#               'issue': {'active_lock_reason': None,
#                         'assignee': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                      'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                      'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                      'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                      'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                      'gravatar_id': '',
#                                      'html_url': 'https://github.com/Benjifilly',
#                                      'id': 112804903,
#                                      'login': 'Benjifilly',
#                                      'node_id': 'U_kgDOBrlEJw',
#                                      'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                      'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                      'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                      'site_admin': False,
#                                      'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                      'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                      'type': 'User',
#                                      'url': 'https://api.github.com/users/Benjifilly'},
#                         'assignees': [{'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                        'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                        'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                        'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                        'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                        'gravatar_id': '',
#                                        'html_url': 'https://github.com/Benjifilly',
#                                        'id': 112804903,
#                                        'login': 'Benjifilly',
#                                        'node_id': 'U_kgDOBrlEJw',
#                                        'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                        'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                        'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                        'site_admin': False,
#                                        'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                        'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                        'type': 'User',
#                                        'url': 'https://api.github.com/users/Benjifilly'}],
#                         'author_association': 'CONTRIBUTOR',
#                         'body': 'This PR resolves '
#                                 'https://github.com/jupyter-naas/awesome-notebooks/issues/1665',
#                         'closed_at': '2023-07-13T13:54:51Z',
#                         'comments': 4,
#                         'comments_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/comments',
#                         'created_at': '2023-04-17T15:56:51Z',
#                         'draft': False,
#                         'events_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/events',
#                         'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666',
#                         'id': 1671504700,
#                         'labels': [{'color': '7057ff',
#                                     'default': True,
#                                     'description': 'Good for newcomers',
#                                     'id': 2388470225,
#                                     'name': 'good first issue',
#                                     'node_id': 'MDU6TGFiZWwyMzg4NDcwMjI1',
#                                     'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/labels/good%20first%20issue'}],
#                         'labels_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/labels{/name}',
#                         'locked': False,
#                         'milestone': None,
#                         'node_id': 'PR_kwDOEeDlWM5Ofp_i',
#                         'number': 1666,
#                         'performed_via_github_app': None,
#                         'pull_request': {'diff_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666.diff',
#                                          'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666',
#                                          'merged_at': '2023-07-13T13:54:51Z',
#                                          'patch_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666.patch',
#                                          'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/pulls/1666'},
#                         'reactions': {'+1': 0,
#                                       '-1': 0,
#                                       'confused': 0,
#                                       'eyes': 0,
#                                       'heart': 0,
#                                       'hooray': 0,
#                                       'laugh': 0,
#                                       'rocket': 0,
#                                       'total_count': 0,
#                                       'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/reactions'},
#                         'repository_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks',
#                         'state': 'closed',
#                         'state_reason': None,
#                         'timeline_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/timeline',
#                         'title': 'feat: Trello - List Boards',
#                         'updated_at': '2023-07-13T14:02:26Z',
#                         'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666',
#                         'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/21052349?v=4',
#                                  'events_url': 'https://api.github.com/users/jravenel/events{/privacy}',
#                                  'followers_url': 'https://api.github.com/users/jravenel/followers',
#                                  'following_url': 'https://api.github.com/users/jravenel/following{/other_user}',
#                                  'gists_url': 'https://api.github.com/users/jravenel/gists{/gist_id}',
#                                  'gravatar_id': '',
#                                  'html_url': 'https://github.com/jravenel',
#                                  'id': 21052349,
#                                  'login': 'jravenel',
#                                  'node_id': 'MDQ6VXNlcjIxMDUyMzQ5',
#                                  'organizations_url': 'https://api.github.com/users/jravenel/orgs',
#                                  'received_events_url': 'https://api.github.com/users/jravenel/received_events',
#                                  'repos_url': 'https://api.github.com/users/jravenel/repos',
#                                  'site_admin': False,
#                                  'starred_url': 'https://api.github.com/users/jravenel/starred{/owner}{/repo}',
#                                  'subscriptions_url': 'https://api.github.com/users/jravenel/subscriptions',
#                                  'type': 'User',
#                                  'url': 'https://api.github.com/users/jravenel'}}},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?',
#             'display_login': 'Benjifilly',
#             'gravatar_id': '',
#             'id': 112804903,
#             'login': 'Benjifilly',
#             'url': 'https://api.github.com/users/Benjifilly'},
#   'created_at': '2023-07-13T13:57:04Z',
#   'id': '30402032107',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'before': '2ee433661a04eedd25dd0c3db1ec38689e5016b6',
#               'commits': [{'author': {'email': 'Benji.filly@gmail.com',
#                                       'name': 'Benjifilly'},
#                            'distinct': True,
#                            'message': 'feat: get token added',
#                            'sha': 'cb3e9bfd2e522c1a09792b4332162b8e3f719f90',
#                            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/commits/cb3e9bfd2e522c1a09792b4332162b8e3f719f90'}],
#               'distinct_size': 1,
#               'head': 'cb3e9bfd2e522c1a09792b4332162b8e3f719f90',
#               'push_id': 14309064819,
#               'ref': 'refs/heads/1970-trello-retrieve-list-id',
#               'repository_id': 299951448,
#               'size': 1},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?',
#             'display_login': 'github-actions',
#             'gravatar_id': '',
#             'id': 41898282,
#             'login': 'github-actions[bot]',
#             'url': 'https://api.github.com/users/github-actions[bot]'},
#   'created_at': '2023-07-13T13:56:34Z',
#   'id': '30402017121',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'action': 'created',
#               'comment': {'author_association': 'NONE',
#                           'body': 'The template is now available on the master '
#                                   'branch on this link: \n'
#                                   '    '
#                                   'https://github.com/jupyter-naas/awesome-notebooks/blob/master/Trello/Trello_List_Boards.ipynb\n'
#                                   '    \n',
#                           'created_at': '2023-07-13T13:56:34Z',
#                           'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666#issuecomment-1634294052',
#                           'id': 1634294052,
#                           'issue_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666',
#                           'node_id': 'IC_kwDOEeDlWM5haVkk',
#                           'performed_via_github_app': None,
#                           'reactions': {'+1': 0,
#                                         '-1': 0,
#                                         'confused': 0,
#                                         'eyes': 0,
#                                         'heart': 0,
#                                         'hooray': 0,
#                                         'laugh': 0,
#                                         'rocket': 0,
#                                         'total_count': 0,
#                                         'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/comments/1634294052/reactions'},
#                           'updated_at': '2023-07-13T13:56:34Z',
#                           'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/comments/1634294052',
#                           'user': {'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#                                    'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#                                    'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#                                    'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#                                    'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#                                    'gravatar_id': '',
#                                    'html_url': 'https://github.com/apps/github-actions',
#                                    'id': 41898282,
#                                    'login': 'github-actions[bot]',
#                                    'node_id': 'MDM6Qm90NDE4OTgyODI=',
#                                    'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#                                    'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#                                    'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#                                    'site_admin': False,
#                                    'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#                                    'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#                                    'type': 'Bot',
#                                    'url': 'https://api.github.com/users/github-actions%5Bbot%5D'}},
#               'issue': {'active_lock_reason': None,
#                         'assignee': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                      'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                      'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                      'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                      'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                      'gravatar_id': '',
#                                      'html_url': 'https://github.com/Benjifilly',
#                                      'id': 112804903,
#                                      'login': 'Benjifilly',
#                                      'node_id': 'U_kgDOBrlEJw',
#                                      'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                      'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                      'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                      'site_admin': False,
#                                      'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                      'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                      'type': 'User',
#                                      'url': 'https://api.github.com/users/Benjifilly'},
#                         'assignees': [{'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                        'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                        'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                        'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                        'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                        'gravatar_id': '',
#                                        'html_url': 'https://github.com/Benjifilly',
#                                        'id': 112804903,
#                                        'login': 'Benjifilly',
#                                        'node_id': 'U_kgDOBrlEJw',
#                                        'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                        'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                        'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                        'site_admin': False,
#                                        'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                        'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                        'type': 'User',
#                                        'url': 'https://api.github.com/users/Benjifilly'}],
#                         'author_association': 'CONTRIBUTOR',
#                         'body': 'This PR resolves '
#                                 'https://github.com/jupyter-naas/awesome-notebooks/issues/1665',
#                         'closed_at': '2023-07-13T13:54:51Z',
#                         'comments': 3,
#                         'comments_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/comments',
#                         'created_at': '2023-04-17T15:56:51Z',
#                         'draft': False,
#                         'events_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/events',
#                         'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666',
#                         'id': 1671504700,
#                         'labels': [{'color': '7057ff',
#                                     'default': True,
#                                     'description': 'Good for newcomers',
#                                     'id': 2388470225,
#                                     'name': 'good first issue',
#                                     'node_id': 'MDU6TGFiZWwyMzg4NDcwMjI1',
#                                     'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/labels/good%20first%20issue'}],
#                         'labels_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/labels{/name}',
#                         'locked': False,
#                         'milestone': None,
#                         'node_id': 'PR_kwDOEeDlWM5Ofp_i',
#                         'number': 1666,
#                         'performed_via_github_app': None,
#                         'pull_request': {'diff_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666.diff',
#                                          'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666',
#                                          'merged_at': '2023-07-13T13:54:51Z',
#                                          'patch_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666.patch',
#                                          'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/pulls/1666'},
#                         'reactions': {'+1': 0,
#                                       '-1': 0,
#                                       'confused': 0,
#                                       'eyes': 0,
#                                       'heart': 0,
#                                       'hooray': 0,
#                                       'laugh': 0,
#                                       'rocket': 0,
#                                       'total_count': 0,
#                                       'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/reactions'},
#                         'repository_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks',
#                         'state': 'closed',
#                         'state_reason': None,
#                         'timeline_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/timeline',
#                         'title': 'feat: Trello - List Boards',
#                         'updated_at': '2023-07-13T13:56:34Z',
#                         'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666',
#                         'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/21052349?v=4',
#                                  'events_url': 'https://api.github.com/users/jravenel/events{/privacy}',
#                                  'followers_url': 'https://api.github.com/users/jravenel/followers',
#                                  'following_url': 'https://api.github.com/users/jravenel/following{/other_user}',
#                                  'gists_url': 'https://api.github.com/users/jravenel/gists{/gist_id}',
#                                  'gravatar_id': '',
#                                  'html_url': 'https://github.com/jravenel',
#                                  'id': 21052349,
#                                  'login': 'jravenel',
#                                  'node_id': 'MDQ6VXNlcjIxMDUyMzQ5',
#                                  'organizations_url': 'https://api.github.com/users/jravenel/orgs',
#                                  'received_events_url': 'https://api.github.com/users/jravenel/received_events',
#                                  'repos_url': 'https://api.github.com/users/jravenel/repos',
#                                  'site_admin': False,
#                                  'starred_url': 'https://api.github.com/users/jravenel/starred{/owner}{/repo}',
#                                  'subscriptions_url': 'https://api.github.com/users/jravenel/subscriptions',
#                                  'type': 'User',
#                                  'url': 'https://api.github.com/users/jravenel'}}},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/22365519?',
#             'display_login': 'Dr0p42',
#             'gravatar_id': '',
#             'id': 22365519,
#             'login': 'Dr0p42',
#             'url': 'https://api.github.com/users/Dr0p42'},
#   'created_at': '2023-07-13T13:56:18Z',
#   'id': '30402009212',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'before': '6e70d587bb99d3007ae75ce95957d6dd71d6ff53',
#               'commits': [{'author': {'email': 'FlorentLvr@users.noreply.github.com',
#                                       'name': 'FlorentLvr'},
#                            'distinct': True,
#                            'message': 'generateReadme: Refresh',
#                            'sha': '8e78eb27c588f592ff9aba3fdc2b74b1ca736c76',
#                            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/commits/8e78eb27c588f592ff9aba3fdc2b74b1ca736c76'}],
#               'distinct_size': 1,
#               'head': '8e78eb27c588f592ff9aba3fdc2b74b1ca736c76',
#               'push_id': 14309054375,
#               'ref': 'refs/heads/master',
#               'repository_id': 299951448,
#               'size': 1},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/48032461?',
#             'display_login': 'FlorentLvr',
#             'gravatar_id': '',
#             'id': 48032461,
#             'login': 'FlorentLvr',
#             'url': 'https://api.github.com/users/FlorentLvr'},
#   'created_at': '2023-07-13T13:54:54Z',
#   'id': '30401965925',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'action': 'closed',
#               'issue': {'active_lock_reason': None,
#                         'assignee': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                      'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                      'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                      'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                      'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                      'gravatar_id': '',
#                                      'html_url': 'https://github.com/Benjifilly',
#                                      'id': 112804903,
#                                      'login': 'Benjifilly',
#                                      'node_id': 'U_kgDOBrlEJw',
#                                      'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                      'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                      'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                      'site_admin': False,
#                                      'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                      'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                      'type': 'User',
#                                      'url': 'https://api.github.com/users/Benjifilly'},
#                         'assignees': [{'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                        'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                        'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                        'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                        'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                        'gravatar_id': '',
#                                        'html_url': 'https://github.com/Benjifilly',
#                                        'id': 112804903,
#                                        'login': 'Benjifilly',
#                                        'node_id': 'U_kgDOBrlEJw',
#                                        'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                        'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                        'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                        'site_admin': False,
#                                        'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                        'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                        'type': 'User',
#                                        'url': 'https://api.github.com/users/Benjifilly'}],
#                         'author_association': 'CONTRIBUTOR',
#                         'body': ' This notebook would allow you to retrieve a '
#                                 'list of all the boards that you have access '
#                                 'to in Trello. You could then use this '
#                                 'information to perform further actions on the '
#                                 'boards, such as listing the cards or updating '
#                                 'their details.\n'
#                                 '\n',
#                         'closed_at': '2023-07-13T13:54:53Z',
#                         'comments': 6,
#                         'comments_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1665/comments',
#                         'created_at': '2023-04-17T15:56:02Z',
#                         'events_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1665/events',
#                         'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/issues/1665',
#                         'id': 1671502743,
#                         'labels': [{'color': '7057ff',
#                                     'default': True,
#                                     'description': 'Good for newcomers',
#                                     'id': 2388470225,
#                                     'name': 'good first issue',
#                                     'node_id': 'MDU6TGFiZWwyMzg4NDcwMjI1',
#                                     'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/labels/good%20first%20issue'}],
#                         'labels_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1665/labels{/name}',
#                         'locked': False,
#                         'milestone': None,
#                         'node_id': 'I_kwDOEeDlWM5joRuX',
#                         'number': 1665,
#                         'performed_via_github_app': None,
#                         'reactions': {'+1': 0,
#                                       '-1': 0,
#                                       'confused': 0,
#                                       'eyes': 0,
#                                       'heart': 0,
#                                       'hooray': 0,
#                                       'laugh': 0,
#                                       'rocket': 0,
#                                       'total_count': 0,
#                                       'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1665/reactions'},
#                         'repository_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks',
#                         'state': 'closed',
#                         'state_reason': 'completed',
#                         'timeline_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1665/timeline',
#                         'title': 'Trello - List Boards',
#                         'updated_at': '2023-07-13T13:54:53Z',
#                         'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1665',
#                         'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/21052349?v=4',
#                                  'events_url': 'https://api.github.com/users/jravenel/events{/privacy}',
#                                  'followers_url': 'https://api.github.com/users/jravenel/followers',
#                                  'following_url': 'https://api.github.com/users/jravenel/following{/other_user}',
#                                  'gists_url': 'https://api.github.com/users/jravenel/gists{/gist_id}',
#                                  'gravatar_id': '',
#                                  'html_url': 'https://github.com/jravenel',
#                                  'id': 21052349,
#                                  'login': 'jravenel',
#                                  'node_id': 'MDQ6VXNlcjIxMDUyMzQ5',
#                                  'organizations_url': 'https://api.github.com/users/jravenel/orgs',
#                                  'received_events_url': 'https://api.github.com/users/jravenel/received_events',
#                                  'repos_url': 'https://api.github.com/users/jravenel/repos',
#                                  'site_admin': False,
#                                  'starred_url': 'https://api.github.com/users/jravenel/starred{/owner}{/repo}',
#                                  'subscriptions_url': 'https://api.github.com/users/jravenel/subscriptions',
#                                  'type': 'User',
#                                  'url': 'https://api.github.com/users/jravenel'}}},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'IssuesEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/48032461?',
#             'display_login': 'FlorentLvr',
#             'gravatar_id': '',
#             'id': 48032461,
#             'login': 'FlorentLvr',
#             'url': 'https://api.github.com/users/FlorentLvr'},
#   'created_at': '2023-07-13T13:54:53Z',
#   'id': '30401965448',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'action': 'closed',
#               'number': 1666,
#               'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666/comments'},
#                                           'commits': {'href': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/pulls/1666/commits'},
#                                           'html': {'href': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1666'},
#                                           'issue': {'href': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1666'},
#                                           'review_comment': {'href': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/pulls/comments{/number}'},
#                                           'review_comments': {'href': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/pulls/1666/comments'},
#                                           'self': {'href': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/pulls/1666'},
#                                           'statuses': {'href': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/statuses/1e8e4e568727010b4a86fce3d5b378e03051bae8'}},
#                                'active_lock_reason': None,
#                                'additions': 313,
#                                'assignee': {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                             'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                             'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                             'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                             'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                             'gravatar_id': '',
#                                             'html_url': 'https://github.com/Benjifilly',
#                                             'id': 112804903,
#                                             'login': 'Benjifilly',
#                                             'node_id': 'U_kgDOBrlEJw',
#                                             'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                             'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                             'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                             'site_admin': False,
#                                             'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                             'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                             'type': 'User',
#                                             'url': 'https://api.github.com/users/Benjifilly'},
#                                'assignees': [{'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                               'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                               'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                               'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                               'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                               'gravatar_id': '',
#                                               'html_url': 'https://github.com/Benjifilly',
#                                               'id': 112804903,
#                                               'login': 'Benjifilly',
#                                               'node_id': 'U_kgDOBrlEJw',
#                                               'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                               'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                               'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                               'site_admin': False,
#                                               'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                               'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                               'type': 'User',
#                                               'url': 'https://api.github.com/users/Benjifilly'}],
#                                'author_association': 'CONTRIBUTOR',
#                                'auto_merge': None,
#                                'base': {'label': 'jupyter-naas:master',
#                                         'ref': 'master',
#                                         'repo': {'allow_forking': True,
#                                                  'archive_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/{archive_format}{/ref}',
#                                                  'archived': False,
#                                                  'assignees_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/assignees{/user}',
#                                                  'blobs_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/git/blobs{/sha}',
#                                                  'branches_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/branches{/branch}',
#                                                  'clone_url': 'https://github.com/jupyter-naas/awesome-notebooks.git',
#                                                  'collaborators_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/collaborators{/collaborator}',
#                                                  'comments_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/comments{/number}',
#                                                  'commits_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/commits{/sha}',
#                                                  'compare_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/compare/{base}...{head}',
#                                                  'contents_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/contents/{+path}',
#                                                  'contributors_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/contributors',
#                                                  'created_at': '2020-09-30T14:44:55Z',
#                                                  'default_branch': 'master',
#                                                  'deployments_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/deployments',
#                                                  'description': 'Ready to use '
#                                                                 'data & AI '
#                                                                 'templates, '
#                                                                 'organized by '
#                                                                 'tools to '
#                                                                 'jumpstart '
#                                                                 'your projects '
#                                                                 'and data '
#                                                                 'products in '
#                                                                 'minutes. 😎  '
#                                                                 'published by '
#                                                                 'the Naas '
#                                                                 'community.',
#                                                  'disabled': False,
#                                                  'downloads_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/downloads',
#                                                  'events_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/events',
#                                                  'fork': False,
#                                                  'forks': 330,
#                                                  'forks_count': 330,
#                                                  'forks_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/forks',
#                                                  'full_name': 'jupyter-naas/awesome-notebooks',
#                                                  'git_commits_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/git/commits{/sha}',
#                                                  'git_refs_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/git/refs{/sha}',
# ...
#               'distinct_size': 1,
#               'head': '06f13bf6c1599c81e6969e5c7eaf67970c464f07',
#               'push_id': 14297139763,
#               'ref': 'refs/heads/2010-agicap-get-bank-account-from-company',
#               'repository_id': 299951448,
#               'size': 1},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'PushEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/81156510?',
#             'display_login': 'srini047',
#             'gravatar_id': '',
#             'id': 81156510,
#             'login': 'srini047',
#             'url': 'https://api.github.com/users/srini047'},
#   'created_at': '2023-07-12T16:38:06Z',
#   'id': '30377380052',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'action': 'created',
#               'comment': {'author_association': 'MEMBER',
#                           'body': '@FlorentLvr Yes, on it.',
#                           'created_at': '2023-07-12T16:38:05Z',
#                           'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1979#issuecomment-1632866887',
#                           'id': 1632866887,
#                           'issue_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1979',
#                           'node_id': 'IC_kwDOEeDlWM5hU5JH',
#                           'performed_via_github_app': None,
#                           'reactions': {'+1': 0,
#                                         '-1': 0,
#                                         'confused': 0,
#                                         'eyes': 0,
#                                         'heart': 0,
#                                         'hooray': 0,
#                                         'laugh': 0,
#                                         'rocket': 0,
#                                         'total_count': 0,
#                                         'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/comments/1632866887/reactions'},
#                           'updated_at': '2023-07-12T16:38:05Z',
#                           'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/comments/1632866887',
#                           'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/81156510?v=4',
#                                    'events_url': 'https://api.github.com/users/srini047/events{/privacy}',
#                                    'followers_url': 'https://api.github.com/users/srini047/followers',
#                                    'following_url': 'https://api.github.com/users/srini047/following{/other_user}',
#                                    'gists_url': 'https://api.github.com/users/srini047/gists{/gist_id}',
#                                    'gravatar_id': '',
#                                    'html_url': 'https://github.com/srini047',
#                                    'id': 81156510,
#                                    'login': 'srini047',
#                                    'node_id': 'MDQ6VXNlcjgxMTU2NTEw',
#                                    'organizations_url': 'https://api.github.com/users/srini047/orgs',
#                                    'received_events_url': 'https://api.github.com/users/srini047/received_events',
#                                    'repos_url': 'https://api.github.com/users/srini047/repos',
#                                    'site_admin': False,
#                                    'starred_url': 'https://api.github.com/users/srini047/starred{/owner}{/repo}',
#                                    'subscriptions_url': 'https://api.github.com/users/srini047/subscriptions',
#                                    'type': 'User',
#                                    'url': 'https://api.github.com/users/srini047'}},
#               'issue': {'active_lock_reason': None,
#                         'assignee': {'avatar_url': 'https://avatars.githubusercontent.com/u/81156510?v=4',
#                                      'events_url': 'https://api.github.com/users/srini047/events{/privacy}',
#                                      'followers_url': 'https://api.github.com/users/srini047/followers',
#                                      'following_url': 'https://api.github.com/users/srini047/following{/other_user}',
#                                      'gists_url': 'https://api.github.com/users/srini047/gists{/gist_id}',
#                                      'gravatar_id': '',
#                                      'html_url': 'https://github.com/srini047',
#                                      'id': 81156510,
#                                      'login': 'srini047',
#                                      'node_id': 'MDQ6VXNlcjgxMTU2NTEw',
#                                      'organizations_url': 'https://api.github.com/users/srini047/orgs',
#                                      'received_events_url': 'https://api.github.com/users/srini047/received_events',
#                                      'repos_url': 'https://api.github.com/users/srini047/repos',
#                                      'site_admin': False,
#                                      'starred_url': 'https://api.github.com/users/srini047/starred{/owner}{/repo}',
#                                      'subscriptions_url': 'https://api.github.com/users/srini047/subscriptions',
#                                      'type': 'User',
#                                      'url': 'https://api.github.com/users/srini047'},
#                         'assignees': [{'avatar_url': 'https://avatars.githubusercontent.com/u/81156510?v=4',
#                                        'events_url': 'https://api.github.com/users/srini047/events{/privacy}',
#                                        'followers_url': 'https://api.github.com/users/srini047/followers',
#                                        'following_url': 'https://api.github.com/users/srini047/following{/other_user}',
#                                        'gists_url': 'https://api.github.com/users/srini047/gists{/gist_id}',
#                                        'gravatar_id': '',
#                                        'html_url': 'https://github.com/srini047',
#                                        'id': 81156510,
#                                        'login': 'srini047',
#                                        'node_id': 'MDQ6VXNlcjgxMTU2NTEw',
#                                        'organizations_url': 'https://api.github.com/users/srini047/orgs',
#                                        'received_events_url': 'https://api.github.com/users/srini047/received_events',
#                                        'repos_url': 'https://api.github.com/users/srini047/repos',
#                                        'site_admin': False,
#                                        'starred_url': 'https://api.github.com/users/srini047/starred{/owner}{/repo}',
#                                        'subscriptions_url': 'https://api.github.com/users/srini047/subscriptions',
#                                        'type': 'User',
#                                        'url': 'https://api.github.com/users/srini047'},
#                                       {'avatar_url': 'https://avatars.githubusercontent.com/u/112804903?v=4',
#                                        'events_url': 'https://api.github.com/users/Benjifilly/events{/privacy}',
#                                        'followers_url': 'https://api.github.com/users/Benjifilly/followers',
#                                        'following_url': 'https://api.github.com/users/Benjifilly/following{/other_user}',
#                                        'gists_url': 'https://api.github.com/users/Benjifilly/gists{/gist_id}',
#                                        'gravatar_id': '',
#                                        'html_url': 'https://github.com/Benjifilly',
#                                        'id': 112804903,
#                                        'login': 'Benjifilly',
#                                        'node_id': 'U_kgDOBrlEJw',
#                                        'organizations_url': 'https://api.github.com/users/Benjifilly/orgs',
#                                        'received_events_url': 'https://api.github.com/users/Benjifilly/received_events',
#                                        'repos_url': 'https://api.github.com/users/Benjifilly/repos',
#                                        'site_admin': False,
#                                        'starred_url': 'https://api.github.com/users/Benjifilly/starred{/owner}{/repo}',
#                                        'subscriptions_url': 'https://api.github.com/users/Benjifilly/subscriptions',
#                                        'type': 'User',
#                                        'url': 'https://api.github.com/users/Benjifilly'}],
#                         'author_association': 'CONTRIBUTOR',
#                         'body': 'This PR resolves '
#                                 'https://github.com/jupyter-naas/awesome-notebooks/issues/1978',
#                         'closed_at': None,
#                         'comments': 3,
#                         'comments_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1979/comments',
#                         'created_at': '2023-07-03T13:01:52Z',
#                         'draft': False,
#                         'events_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1979/events',
#                         'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1979',
#                         'id': 1786141462,
#                         'labels': [{'color': 'bfd4f2',
#                                     'default': False,
#                                     'description': 'To be prioritize for '
#                                                    'notebook templates '
#                                                    'maintainer',
#                                     'id': 5508100645,
#                                     'name': 'templates maintainer',
#                                     'node_id': 'LA_kwDOEeDlWM8AAAABSE7yJQ',
#                                     'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/labels/templates%20maintainer'}],
#                         'labels_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1979/labels{/name}',
#                         'locked': False,
#                         'milestone': None,
#                         'node_id': 'PR_kwDOEeDlWM5UhjPq',
#                         'number': 1979,
#                         'performed_via_github_app': None,
#                         'pull_request': {'diff_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1979.diff',
#                                          'html_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1979',
#                                          'merged_at': None,
#                                          'patch_url': 'https://github.com/jupyter-naas/awesome-notebooks/pull/1979.patch',
#                                          'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/pulls/1979'},
#                         'reactions': {'+1': 0,
#                                       '-1': 0,
#                                       'confused': 0,
#                                       'eyes': 0,
#                                       'heart': 0,
#                                       'hooray': 0,
#                                       'laugh': 0,
#                                       'rocket': 0,
#                                       'total_count': 0,
#                                       'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1979/reactions'},
#                         'repository_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks',
#                         'state': 'open',
#                         'state_reason': None,
#                         'timeline_url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1979/timeline',
#                         'title': 'feat: GitHub - Get DataFrame from project '
#                                  'view',
#                         'updated_at': '2023-07-12T16:38:05Z',
#                         'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/issues/1979',
#                         'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/48032461?v=4',
#                                  'events_url': 'https://api.github.com/users/FlorentLvr/events{/privacy}',
#                                  'followers_url': 'https://api.github.com/users/FlorentLvr/followers',
#                                  'following_url': 'https://api.github.com/users/FlorentLvr/following{/other_user}',
#                                  'gists_url': 'https://api.github.com/users/FlorentLvr/gists{/gist_id}',
#                                  'gravatar_id': '',
#                                  'html_url': 'https://github.com/FlorentLvr',
#                                  'id': 48032461,
#                                  'login': 'FlorentLvr',
#                                  'node_id': 'MDQ6VXNlcjQ4MDMyNDYx',
#                                  'organizations_url': 'https://api.github.com/users/FlorentLvr/orgs',
#                                  'received_events_url': 'https://api.github.com/users/FlorentLvr/received_events',
#                                  'repos_url': 'https://api.github.com/users/FlorentLvr/repos',
#                                  'site_admin': False,
#                                  'starred_url': 'https://api.github.com/users/FlorentLvr/starred{/owner}{/repo}',
#                                  'subscriptions_url': 'https://api.github.com/users/FlorentLvr/subscriptions',
#                                  'type': 'User',
#                                  'url': 'https://api.github.com/users/FlorentLvr'}}},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'IssueCommentEvent'},
#  {'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/81156510?',
#             'display_login': 'srini047',
#             'gravatar_id': '',
#             'id': 81156510,
#             'login': 'srini047',
#             'url': 'https://api.github.com/users/srini047'},
#   'created_at': '2023-07-12T16:37:22Z',
#   'id': '30377363768',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/71603764?',
#           'gravatar_id': '',
#           'id': 71603764,
#           'login': 'jupyter-naas',
#           'url': 'https://api.github.com/orgs/jupyter-naas'},
#   'payload': {'before': '1a621565cb7f773f90f10063f7324ecbbbb87651',
#               'commits': [{'author': {'email': '81156510+srini047@users.noreply.github.com',
#                                       'name': 'Sriniketh J'},
#                            'distinct': True,
#                            'message': 'fix: .env exposure issue',
#                            'sha': '932275ea2197072dec69cfe944215b57b32441ae',
#                            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks/commits/932275ea2197072dec69cfe944215b57b32441ae'}],
#               'distinct_size': 1,
#               'head': '932275ea2197072dec69cfe944215b57b32441ae',
#               'push_id': 14297082899,
#               'ref': 'refs/heads/1893-langchain-vector-search-on-the-pdf-using-langchain-abstraction',
#               'repository_id': 299951448,
#               'size': 1},
#   'public': True,
#   'repo': {'id': 299951448,
#            'name': 'jupyter-naas/awesome-notebooks',
#            'url': 'https://api.github.com/repos/jupyter-naas/awesome-notebooks'},
#   'type': 'PushEvent'}]
