# %% [markdown]
# <img width="8%" alt="Python.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Python.png" style="border-radius: 15%">

# %% [markdown]
# # Python - Remove duplicates from a list
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Python+-+Remove+duplicates+from+a+list:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #python #list #remove #duplicates #function #data

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-08-28 (Created: 2023-08-28)

# %% [markdown]
# **Description:** This notebook explains how to remove duplicates from a list in Python. It is usefull for data cleaning and data wrangling.

# %% [markdown]
# **References:**
# - [Python List remove()](https://www.programiz.com/python-programming/methods/list/remove)
# - [Python List comprehension](https://www.programiz.com/python-programming/list-comprehension)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
# No libraries needed

# %% [markdown]
# ### Setup variables

# %%
# Create a list with duplicates
my_list = [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8, 9]

# %% [markdown]
# ## Model

# %% [markdown]
# ### Remove duplicates from a list

# %%
# Create a new list with no duplicates
my_list_no_duplicates = list(dict.fromkeys(my_list))
# Print the new list
print(my_list_no_duplicates)
# Alternative with list comprehension
my_list_no_duplicates_2 = [x for x in my_list if x not in my_list_no_duplicates]
# Print the new list
print(my_list_no_duplicates_2)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
# Print the new list
print(my_list_no_duplicates)
# Print the new list
print(my_list_no_duplicates_2)
