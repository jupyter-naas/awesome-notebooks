# %% [markdown]
# <img width="8%" alt="Google Sheets.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Google%20Sheets.png" style="border-radius: 15%">

# %% [markdown]
# # Google Sheets - Get data from sheet
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Google+Sheets+-+Get+data+from+sheet:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #googlesheets #gsheet #data #naas_drivers #operations #snippet #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-12-01 (Created: 2022-03-04)

# %% [markdown]
# **Description:** This notebook demonstrates how to get data from a Google Sheets spreadsheet sheet and return a DataFrame.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import gsheet

# %% [markdown]
# ### Setup variables
# **Pre-requisite**
#
# - Share your Google Sheets spreadsheet with our service account : 🔗 naas-share@naas-gsheets.iam.gserviceaccount.com
#
# **Mandatory**
# - `spreadsheet_url`: Google Sheets spreadsheet URL
# - `sheet_name`: Google Sheets sheet name

# %%
# Mandatory
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1RdwdYXDFDSFSFxxxxxxxx/edit#gid=XXXXXXXX33"
sheet_name = "MY_SHEET"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get data from sheet

# %%
df = gsheet.connect(spreadsheet_url).get(sheet_name=sheet_name)
print('Row fetched:', len(df))

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
df
