# %% [markdown]
# <img width="8%" alt="OpenAI.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OpenAI.png" style="border-radius: 15%">

# %% [markdown]
# # OpenAI - Generate Q&A
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OpenAI+-+Generate+Q&A:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #openai #q&a

# %% [markdown]
# **Author:** [Mohit Singh](https://www.linkedin.com/in/mohwits/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-03-16)

# %% [markdown]
# **Description:** This notebook shows how to use the OpenAI API to generate answer to a question.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Install package

# %%
import naas
import os
# OpenAI
try:
    import openai
except ModuleNotFoundError:
    # !pip install --user openai
    import openai

# %% [markdown]
# ### Setup Variables
# - `api_key`: OpenAI API key, to obtain an OpenAI API key, please refer to the [OpenAI Documentation](https://openai.com/docs/).
# - `question`: the question to get the answer

# %%
# api key
openai.api_key = naas.secret.get("OPENAI_API_KEY")

# prompt to ask question
question = input('Enter the question: ')

# %% [markdown]
# ## Model

# %% [markdown]
# ### Establish connection with OpenAI and get the response

# %%
response = openai.Completion.create(
  model="text-davinci-003",
  prompt=question,
  temperature=0.7,
  max_tokens=256,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)

# %%
# get the answer from response generated
answer = response.choices[0].text

# %% [markdown]
# ## Output

# %%
print(answer)
