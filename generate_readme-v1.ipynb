# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>
#
# # Generate Readme for Awesome Notebooks

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import librairies

# %%
import os
import requests
import pandas as pd
import urllib.parse
try:
    from git import Repo
except:
    # !pip install GitPython
    from git import Repo
from naas_drivers import markdown
from pprint import pprint
import json

# %% [markdown]
# ### Setup Variables
# - `readme_template`: This variable stores the file name or path of the README template file. It is used as a template to generate the final README file.
# - `naas_lab_logo`: This variable contains the URL of the Naas Lab logo image.
# - `naas_chat_logo`: This variable holds the URL of the Naas Chat logo image.
# - `template_request`: This variable represents the URL for submitting a template request on GitHub. It includes parameters such as assignees, labels, template, and title.
# - `bug_report`: This variable stores the URL for submitting a bug report on GitHub. It includes parameters such as assignees, labels, template, and title.
# - `start_data_product`: This variable contains the URL for the "Naas_Start_data_product" notebook.
# - `json_file`: This variable represents the file name or path for the output JSON file that will store the templates.
# - `naas_lab_url`: This variable holds the URL prefix for accessing Naas Lab resources.
# - `naas_chat_url`: This variable represents the URL prefix for using Naas Chat plugins.
# - `readme`: This variable stores the file name or path for the final README file.

# %%
# Inputs
readme_template = "README_template.md"
naas_lab_logo = "https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"
naas_chat_logo = "https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"
template_request = "https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=&template=template-request.md&title=Tool+-+Action+of+the+notebook+"
bug_report = "https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title="
start_data_product = "https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/Naas/Naas_Start_data_product.ipynb"

# Outputs
json_file = "templates.json"
naas_lab_url ='https://app.naas.ai/user-redirect/naas/downloader?url='
naas_chat_url = "https://workspace.naas.ai/chat/use?plugin_url="
readme = "README.md"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get all notebooks

# %%
def get_all_notebooks():
    # Init
    html_url_base = "https://github.com/jupyter-naas/awesome-notebooks/blob/master"
    raw_url_base = "https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master"
    notebooks = []
    res_json = []
    
    # Connect to GitHub and get branch
    repo = Repo('.')
    branch = repo.active_branch
    
    # Get tree from json
    url = f"https://api.github.com/repos/jupyter-naas/awesome-notebooks/git/trees/{branch.name}?recursive=1"
    res = requests.get(url)
    if res.status_code == 200:
        res_json = res.json().get("tree")
    
    # Loop on files
    for r in res_json:
        root = None
        file_name = None
        file_path = r.get("path")
        notebook_path = urllib.parse.quote(file_path)
        if ".github" not in file_path and ".gitignore" not in file_path and "/" in file_path:
            if file_path.endswith(".ipynb"):
                data = {
                    "tool": file_path.split("/")[0],
                    "notebook_name": file_path.split("/")[1],
                    "notebook_path": notebook_path,
                    "html_url": f"{html_url_base}/{notebook_path}",
                    "raw_url": f"{raw_url_base}/{notebook_path}",
                }
                notebooks.append(data)
    return pd.DataFrame(notebooks)

df_notebooks = get_all_notebooks()
print("✅ Notebooks fetched:", len(df_notebooks))
df_notebooks.head(1)
# Out:
# ✅ Notebooks fetched: 752
#   tool                                 notebook_name  \
# 0  AWS  AWS_Daily_biling_notification_to_slack.ipynb
#
#                                       notebook_path  \
# 0  AWS/AWS_Daily_biling_notification_to_slack.ipynb
#
#                                             html_url  \
# 0  https://github.com/jupyter-naas/awesome-notebo...
#
#                                              raw_url
# 0  https://raw.githubusercontent.com/jupyter-naas...

# %% [markdown]
# ### Create header button, generate markdown & json

# %%
def create_first_cell(
    tool,
    title,
    open_in_lab,
    naas_lab_logo,
    open_in_chat,
    naas_chat_logo,
    template_request,
    bug_report,
    naas_lab_url,
    start_data_product,
):
    # Init
    notebook_title = ''
    open_in_lab_url = ''
    open_in_chat_url = ''
    template_request_url = ''
    bug_report_url = ''
    generate_data_product_url = ''
    
    # Create notebook title
    notebook_title = f"# {tool} - {title}\n" # Jupyter Notebooks - Get libraries
    
    # Create logos
    if open_in_lab != "":
        open_in_lab_url = f"""<a href="{open_in_lab}" target="_parent"><img src="{naas_lab_logo}"/></a>"""
    if open_in_chat != "":
        open_in_chat_url = f"""<a href="{open_in_chat}" target="_parent"><img src="{naas_chat_logo}"/></a>"""
        
    # Hyperlinks
    template_request_url = f"""<a href="{template_request}">Template request</a>"""
    
    title_url = (f"{tool}+-+{title}").replace(" ", "+")
    bug_report_url = f"""<a href="{bug_report}{title_url}:+Error+short+description">Bug report</a>"""
    
    start_data_product_url = f"{naas_lab_url}{start_data_product}"
    generate_data_product_url = f"""<a href="{start_data_product_url}" target="_parent">Generate Data Product</a>"""
    return f"""{notebook_title}{open_in_lab_url}{open_in_chat_url}<br><br>{template_request_url} | {bug_report_url} | {generate_data_product_url}"""

def get_imports(sources, imports):
    # Loop on sources
    for source in sources:
        if "from" in source and "import" in source:
            lib = (
                source.replace("\n", "")
                .split("from")[-1]
                .split("import")[0]
                .strip()
            )
            module = (
                source.replace("\n", "")
                .split("import")[-1]
                .split(" as ")[0]
                .strip()
            )
            imports.append(f"{lib}.{module}")
        if "from" not in source and "import" in source:
            library = (
                source.replace("\n", "")
                .split("import")[-1]
                .split(" as ")[0]
                .strip()
            )
            imports.append(library)
    return imports

def get_notebook_info(url):
    # Init
    action = ""
    title = ""
    tags = ""
    author = ""
    author_url = ""
    description = ""
    plugin = False
    imports = []
    first_cell = []
    
    # Request
    res = requests.get(url)
#     return res.json()
    
    # Manage result
    if res.status_code == 200:
        res_json = res.json()
        cells = res_json.get("cells")
        
        # Get metadata store in fixed cells
        first_cell = cells[1].get("source")
        title = first_cell[0].replace("#", "").split("-")[-1].strip()
        action = "".join(first_cell).split("<br><br>")[0].split("\n")[-1].strip()
        tags = cells[2].get("source")[0].replace("**Tags:**", "").strip()
        tags = [f"#{tag.strip()}" for tag in tags.split("#") if tag != ""]
        author = cells[3].get("source")[0].replace("**Author:**", "").strip()
        author_name = author.replace("[", "").replace("]", "").split("(")[0].strip()
        if "(" in author:
            author_url = author.split("(")[-1].replace(")", "")
        description = "".join(cells[4].get("source")).replace("**Description:**", "").strip()
        
        # Get metadata store in variables cells
        for cell in cells:
            cell_type = cell.get("cell_type")
            metadata = cell.get("metadata")
            sources = cell.get("source")
            if cell_type == "code":
                imports = get_imports(sources, imports)
            if metadata:
                metadata_tags = metadata.get("tags")
                if len(metadata_tags) > 0 and not plugin:
                    for m in metadata_tags:
                        if m == "plugin":
                            plugin = True
                            break
        
    return title, action, tags, author_name, author_url, description, imports, plugin, "".join(first_cell)

url = "https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/OpenAI/OpenAI_Act_as_a_chef.ipynb"
title, action, tags, author_name, author_url, description, imports, plugin, first_cell = get_notebook_info(url)
print("- Title:", title)
print("- Action:", action)
print("- Tags:", tags)
print("- Author:", author_name)
print("- Author URL:", author_url)
print("- Description:", description)
print("- Imports:", imports)
print("- Plugin:", plugin)
print("- First cell:", first_cell)
# Out:
# - Title: Act as a chef
# - Action: <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/OpenAI/OpenAI_Act_as_a_chef.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>
# - Tags: ['#openai', '#chef', '#cooking', '#ai', '#machinelearning', '#deeplearning']
# - Author: Florent Ravenel
# - Author URL: https://www.linkedin.com/in/florent-ravenel/
# - Description: This notebook will create a plugin to act as a chef and use OpenAI to create delicious recipes.
# - Imports: ['json', 'naas', 'pprint.pprint']
# - Plugin: True
# - First cell: # OpenAI - Act as a chef
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/OpenAI/OpenAI_Act_as_a_chef.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a><br><br><a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=&template=template-request.md&title=Tool+-+Action+of+the+notebook+">Template request</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OpenAI+-+Act+as+a+chef:+Error+short+description">Bug report</a> | <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/Naas/Naas_Start_data_product.ipynb" target="_parent">Generate Data Product</a>

# %%
generated_list = ""
json_templates = []
folder = None

for row in df_notebooks.itertuples():
    notebook_path = row.notebook_path
    print(notebook_path)
    tool = row.tool
    raw_url = row.raw_url
    html_url = row.html_url
    open_in_lab = f"{naas_lab_url}{raw_url}"
    open_in_chat = ""
    
    # Get data from notebook
    title, action, tags, author_name, author_url, description, imports, plugin, first_cell = get_notebook_info(raw_url)
    
    # Create Open in MyChatGPT URL
    if plugin:
        open_in_chat = f"{naas_chat_url}{raw_url}"
        
    # Create OpenButton
    new_first_cell = create_first_cell(
        tool,
        title,
        open_in_lab,
        naas_lab_logo,
        open_in_chat,
        naas_chat_logo,
        template_request,
        bug_report,
        naas_lab_url,
        start_data_product,
    )
    
    # Display open button
#     markdown.display(new_first_cell)

    # Update OpenButton in notebook
    if first_cell != new_first_cell:
        print("Button to be updated:", html_url)
#         update_button()

    # Update json
    new_json = {
        'tool': tool,
        'notebook': title,
        'action': action,
        'tags': tags,
        'author': author_name,
        'author_url': author_url,
        'description':  description,
        "open_in_lab": open_in_lab,
        "open_in_chat": open_in_chat,
        "notebook_url": html_url,
        "imports": imports,
        "updated_at": "",
        "image_url": "",
    }
    json_templates.append(new_json)
    
    # Create markdwon
    new_folder = row.tool
    if new_folder != folder:
        generated_list += f"\n## {new_folder}\n"
        folder = new_folder
    nb_redirect = f"* [{title}]({html_url})\n"
    generated_list += nb_redirect
# Out:
# AWS/AWS_Daily_biling_notification_to_slack.ipynb
# AWS/AWS_Get_files_from_S3_bucket.ipynb
# AWS/AWS_Read_dataframe_from_S3.ipynb
# AWS/AWS_Send_dataframe_to_S3.ipynb
# AWS/AWS_Upload_file_to_S3_bucket.ipynb
# Abstract%20API/Abstract_API_Check_Email_Validation.ipynb
# Abstract%20API/Abstract_API_Get_IP_Geolocation.ipynb
# Advertools/Advertools_Analyze_website_content_using_XML_sitemap.ipynb
# Advertools/Advertools_Audit_robots_txt_and_xml_sitemap_issues.ipynb
# Affinity/Affinity_Sync_with_Notion_database.ipynb
# Agicap/Agicap_Export_treasury_plan.ipynb
# Agicap/Agicap_Export_treasury_plan_by_account.ipynb
# Agicap/Agicap_List_companies.ipynb
# Airtable/Airtable_Delete_data.ipynb
# Airtable/Airtable_Get_data.ipynb
# Airtable/Airtable_Insert_data.ipynb
# Airtable/Airtable_Search_data.ipynb
# AlphaVantage/AlphaVantage_Get_balance_sheet.ipynb
# AlphaVantage/AlphaVantage_Get_cashflow_statement.ipynb
# AlphaVantage/AlphaVantage_Get_company_overview.ipynb
# AlphaVantage/AlphaVantage_Get_income_statement.ipynb
# Azure%20Blob%20Storage/Azure_Blob_Storage_Upload_files.ipynb
# Bazimo/Bazimo_Get_export_Actifs.ipynb
# Bazimo/Bazimo_Get_export_Baux.ipynb
# Bazimo/Bazimo_Get_export_Factures.ipynb
# Bazimo/Bazimo_Get_export_Locataires.ipynb
# Bazimo/Bazimo_Get_export_Lots.ipynb
# BeautifulSoup/BeautifulSoup_List_social_network_links_from_website.ipynb
# BeautifulSoup/BeautifulSoup_Scrape_emails_from_URL.ipynb
# BigQuery/BigQuery_Create_table_from_csv.ipynb
# BigQuery/BigQuery_Read_Table.ipynb
# Bitly/Bitly_Create_Links.ipynb
# Bitly/Bitly_Delete_a_Bitlink.ipynb
# Bitly/Bitly_Get_Clicks_for_a_Bitlink.ipynb
# Bitly/Bitly_Get_Metrics_for_a_Bitlink_by_City.ipynb
# Bitly/Bitly_Get_Metrics_for_a_Bitlink_by_Country.ipynb
# Bitly/Bitly_Get_Metrics_for_a_Bitlink_by_Devices.ipynb
# Bitly/Bitly_Get_Metrics_for_a_Bitlink_by_Referrers.ipynb
# Bitly/Bitly_Get_a_Clicks_Summary_for_a_Bitlink.ipynb
# Bitly/Bitly_Retrieve_Bitlink.ipynb
# Bitly/Bitly_Update_a_Bitlink.ipynb
# Boursorama/Boursorama_Get_CDS.ipynb
# Boursorama/Boursorama_Get_EURIBOR_3_MOIS.ipynb
# Bubble/Bubble_Send_data.ipynb
# CCXT/CCXT_Calculate_Support_and_Resistance.ipynb
# CCXT/CCXT_Predict_Bitcoin_from_Binance.ipynb
# CSV/CSV_Read_file.ipynb
# CSV/CSV_Save_file.ipynb
# Canny/Canny_Create.ipynb
# Canny/Canny_Github_issue_update.ipynb
# Canny/Canny_Read.ipynb
# Celestrak/Celestrak_Satellites_over_time.ipynb
# Cityfalcon/Cityfalcon_Get_data_from_API.ipynb
# Clockify/Clockify_Add_a_new_client.ipynb
# Clockify/Clockify_Add_a_new_project.ipynb
# Clockify/Clockify_Delete_client.ipynb
# Clockify/Clockify_Delete_project.ipynb
# Clockify/Clockify_Find_all_users_on_workspace.ipynb
# Clockify/Clockify_Find_clients_on_workspace.ipynb
# Clockify/Clockify_Find_tasks_on_project.ipynb
# Clockify/Clockify_Get_all_my_workspaces.ipynb
# Clockify/Clockify_Get_all_projects_on_workspace.ipynb
# Clockify/Clockify_Get_client_by_ID.ipynb
# Clockify/Clockify_Get_project_by_ID.ipynb
# Clockify/Clockify_Get_time_entries_for_a_user_on_workspace.ipynb
# Clockify/Clockify_Remove_user_from_workspace.ipynb
# Clockify/Clockify_Update_client.ipynb
# Clockify/Clockify_Update_project.ipynb
# Cloud%20Mercato/Cloud_Mercato_Compare_VM_pricing.ipynb
# Creditsafe/Creditsafe_Get_Company_Credit_Report.ipynb
# D-Tale/D-Tale_Visualize_dataframe.ipynb
# Dash/Dash_Add_a_customisable_sidebar.ipynb
# Dash/Dash_Create_Datatable_With_Dropdown.ipynb
# Dash/Dash_Create_Dropdown_Callback.ipynb
# Dash/Dash_Create_Dropdown_with_multiples_output_callbacks.ipynb
# Dash/Dash_Create_Interactive_Plot.ipynb
# Dash/Dash_Create_Navbar.ipynb
# Dash/Dash_Create_Navbar_Dashboard.ipynb
# Dash/Dash_Create_Navbar_Search.ipynb
# Dash/Dash_Create_button_to_refresh_page.ipynb
# Dash/Dash_Create_conditional_formatting_on_HTML_element.ipynb
# Dash/Dash_Create_conditional_formatting_on_number_value.ipynb
# Dash/Dash_Create_download_button.ipynb
# Dash/Dash_Create_loading_button.ipynb
# Dash/Dash_Create_spinner_button.ipynb
# Dash/Dash_Deploy_app_in_Naas.ipynb
# Dash/Dash_LinkedIn_posts_metrics_dashboard.ipynb
# Dash/Dash_Plotly_Dynamic_Link.ipynb
# Dash/Dash_Upload_mutiples_CSV_Excel.ipynb
# Dask/Dask_parallelize_operations_on_multiple_csvs.ipynb
# Data.gouv.fr/COVID19%20-%20%20FR%20-%20Entr%C3%A9es%20et%20sorties%20par%20r%C3%A9gion%20pour%201%20million%20d%27hab..ipynb
# Button to be updated: https://github.com/jupyter-naas/awesome-notebooks/blob/master/Data.gouv.fr/COVID19%20-%20%20FR%20-%20Entr%C3%A9es%20et%20sorties%20par%20r%C3%A9gion%20pour%201%20million%20d%27hab..ipynb
# Data.gouv.fr/Data.gouv.fr_R%C3%A9cup%C3%A9ration_donn%C3%A9es_l%C3%A9gales_entreprise.ipynb
# Draft%20Kings/Draft_Kings_Get_MLB_Moneylines.ipynb
# Draft%20Kings/Draft_Kings_Get_NBA_Moneylines.ipynb
# EM-DAT/EM-DAT_natural_disasters.ipynb
# Elasticsearch/Elasticsearch_Connect_to_server.ipynb
# Excel/Excel_Apply_Custom_Styles.ipynb
# Excel/Excel_Consolidate_files.ipynb
# Excel/Excel_Get_dynamic_active_range.ipynb
# Excel/Excel_List_sheets_in_workbook.ipynb
# Excel/Excel_Read_file.ipynb
# Excel/Excel_Save_file.ipynb
# FAO/FAO_Consumer_price_indice.ipynb
# FEC/FEC_Creer_un_dashboard_PowerBI.ipynb
# FEC/FEC_Lecture_des_fichiers.ipynb
# FEC/FEC_Visualiser_Bilan_Treemap.ipynb
# FEC/FEC_Visualiser_Charges_Horizontal_Barchart.ipynb
# FEC/FEC_Visualiser_Comparer_Ventes_Line_Chart.ipynb
# FEC/FEC_Visualiser_Tr%C3%A9sorerie_Barline_Chart.ipynb
# FED/FED_Visualize_Inflation_Rate.ipynb
# FTP/FTPS_Connect.ipynb
# FTP/FTP_Connect.ipynb
# FTP/FTP_Get_file.ipynb
# FTP/FTP_Send_file.ipynb
# Faker/Faker_Anonymize_Address_from_dataframe.ipynb
# Faker/Faker_Anonymize_Personal_Names_from_dataframe.ipynb
# Formant/Formant_Query_Device_Network.ipynb
# GitHub/GitHub_Add_new_issues_as_page_in_Notion_database.ipynb
# GitHub/GitHub_Add_new_member_to_team.ipynb
# GitHub/GitHub_Add_or_update_team_membership_for_a_user.ipynb
# GitHub/GitHub_Clone_repository.ipynb
# GitHub/GitHub_Clone_repository_and_switch_branch.ipynb
# GitHub/GitHub_Close_issue.ipynb
# GitHub/GitHub_Create_Repo.ipynb
# GitHub/GitHub_Create_an_issue_comment.ipynb
# GitHub/GitHub_Create_issue.ipynb
# GitHub/GitHub_Create_leaderboard_of_contributors.ipynb
# GitHub/GitHub_Create_newsletter_based_on_repository_activity.ipynb
# GitHub/GitHub_Create_pull_request.ipynb
# GitHub/GitHub_Create_repository_on_personal_account.ipynb
# GitHub/GitHub_Delete_an_issue_comment.ipynb
# GitHub/GitHub_Download_Excel_file_from_URL.ipynb
# GitHub/GitHub_Download_file_from_url.ipynb
# GitHub/GitHub_Download_repository_from_URL.ipynb
# GitHub/GitHub_Follow_stargazers_trend.ipynb
# GitHub/GitHub_Get_Traffic_Clones_on_repository.ipynb
# GitHub/GitHub_Get_Traffic_Views_on_repository.ipynb
# GitHub/GitHub_Get_a_repository.ipynb
# GitHub/GitHub_Get_active_projects.ipynb
# GitHub/GitHub_Get_commits_from_repository.ipynb
# GitHub/GitHub_Get_commits_ranking_from_repository.ipynb
# GitHub/GitHub_Get_files_added_on_pull_request.ipynb
# GitHub/GitHub_Get_files_changed_on_pull_request.ipynb
# GitHub/GitHub_Get_issues_from_repo.ipynb
# GitHub/GitHub_Get_most_starred_repos.ipynb
# GitHub/GitHub_Get_open_pull_requests.ipynb
# GitHub/GitHub_Get_profile_from_user.ipynb
# GitHub/GitHub_Get_profiles_from_teams.ipynb
# GitHub/GitHub_Get_team_membership_for_a_user.ipynb
# GitHub/GitHub_Get_weekly_commits_from_repository.ipynb
# GitHub/GitHub_List_all_pull_requests.ipynb
# GitHub/GitHub_List_closed_pull_requests.ipynb
# GitHub/GitHub_List_issue_comments.ipynb
# GitHub/GitHub_List_open_pull_requests.ipynb
# GitHub/GitHub_List_organization_repositories.ipynb
# GitHub/GitHub_List_pending_team_invitations.ipynb
# GitHub/GitHub_List_stargazers_from_repository.ipynb
# GitHub/GitHub_List_team_members.ipynb
# GitHub/GitHub_Peform_basic_actions.ipynb
# GitHub/GitHub_Read_issue.ipynb
# GitHub/GitHub_Remove_member_from_team.ipynb
# GitHub/GitHub_Remove_team_membership_for_a_user.ipynb
# GitHub/GitHub_Reopen_issue.ipynb
# GitHub/GitHub_Send_stargazers_to_Google_Sheets.ipynb
# GitHub/GitHub_Track_issues_on_projects.ipynb
# GitHub/GitHub_Track_notebooks_created_over_time.ipynb
# GitHub/GitHub_Update_issue.ipynb
# Gmail/Gmail_Automate_response_from_keywords_in_mailbox.ipynb
# Gmail/Gmail_Clean_mailbox.ipynb
# Gmail/Gmail_Create_GitHub_issue_on_specific_email.ipynb
# Gmail/Gmail_Create_draft_email.ipynb
# Gmail/Gmail_Delete_email_from_mailbox.ipynb
# Gmail/Gmail_Get_emails_stats_by_sender.ipynb
# Gmail/Gmail_Get_seen_emails.ipynb
# Gmail/Gmail_Get_unseen_emails.ipynb
# Gmail/Gmail_Read_mailbox.ipynb
# Gmail/Gmail_Send_email.ipynb
# Gmail/Gmail_Update_email_flag.ipynb
# Google%20Analytics/Google_Analytics_Follow_average_session_duration_daily.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_new_visitors_daily.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_new_visitors_hourly.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_new_visitors_monthly.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_new_visitors_weekly.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_sessions_daily.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_sessions_hourly.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_sessions_monthly.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_sessions_weekly.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_visitors_daily.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_visitors_hourly.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_visitors_monthly.ipynb
# Google%20Analytics/Google_Analytics_Follow_number_of_visitors_weekly.ipynb
# Google%20Analytics/Google_Analytics_Get_bounce_rate.ipynb
# Google%20Analytics/Google_Analytics_Get_pageview_ranking.ipynb
# Google%20Analytics/Google_Analytics_Get_stats_per_country.ipynb
# Google%20Analytics/Google_Analytics_Get_time_on_landing_page.ipynb
# Google%20Analytics/Google_Analytics_Get_unique_visitors.ipynb
# Google%20Analytics/Google_Analytics_Get_unique_visitors_by_country.ipynb
# Google%20Analytics/Google_Analytics_Send_visitors_traffic_graph_and_trends_prediction_to_Slack_channel.ipynb
# Google%20Calendar/Google_Calendar_Get_calendar.ipynb
# Google%20Calendar/Google_Calendar_List_calendars.ipynb
# Google%20Calendar/Google_Calendar_List_events_from_calendar.ipynb
# Google%20Drive/Google_Drive_Download_file.ipynb
# Google%20Search/Google_Search_Get_LinkedIn_company_url_from_name.ipynb
# Google%20Search/Google_Search_Get_LinkedIn_profile_url_from_name.ipynb
# Google%20Search/Google_Search_Perform_search.ipynb
# Google%20Sheets/Google_Sheets_Add_items_to_Notion_databases_from_new_rows_in_Google_Sheets.ipynb
# Google%20Sheets/Google_Sheets_Add_new_github_member_to_team_from_spreadsheet.ipynb
# Google%20Sheets/Google_Sheets_Get_data.ipynb
# Google%20Sheets/Google_Sheets_Send_LinkedIn_invitations_from_spreadsheet.ipynb
# Google%20Sheets/Google_Sheets_Send_data.ipynb
# Google%20Sheets/Google_Sheets_Send_data_to_MongoDB.ipynb
# Google%20Sheets/Google_Sheets_Send_emails_from_sheet.ipynb
# Google%20Slides/Google_Slides_Create_a_Slide.ipynb
# Google%20Slides/Google_Slides_Create_a_blank_presentation.ipynb
# Google%20Slides/Google_Slides_Duplicate_slide.ipynb
# Google%20Slides/Google_Slides_List_slides_in_presentation.ipynb
# Google%20Slides/Google_Slides_Replace_text_within_a_shape.ipynb
# HTML/HTML_Create_a_website.ipynb
# Healthchecks/Healthchecks_Perfom_basic_actions.ipynb
# HubSpot/HubSpot_Associate_contact_to_deal.ipynb
# HubSpot/HubSpot_Create_Task.ipynb
# HubSpot/HubSpot_Create_contact.ipynb
# HubSpot/HubSpot_Create_contact_from_LinkedIn_profile.ipynb
# HubSpot/HubSpot_Create_contacts_from_linkedin_post_likes.ipynb
# HubSpot/HubSpot_Create_deal.ipynb
# HubSpot/HubSpot_Create_note.ipynb
# HubSpot/HubSpot_Delete_Task.ipynb
# HubSpot/HubSpot_Delete_contact.ipynb
# HubSpot/HubSpot_Delete_deal.ipynb
# HubSpot/HubSpot_Delete_note.ipynb
# HubSpot/HubSpot_Get_Task.ipynb
# HubSpot/HubSpot_Get_all_contacts.ipynb
# HubSpot/HubSpot_Get_all_deals.ipynb
# HubSpot/HubSpot_Get_all_pipelines_and_dealstages.ipynb
# HubSpot/HubSpot_Get_contact_from_URL.ipynb
# HubSpot/HubSpot_Get_contact_from_email.ipynb
# HubSpot/HubSpot_Get_contact_from_id.ipynb
# HubSpot/HubSpot_Get_contacts_associated_to_deal.ipynb
# HubSpot/HubSpot_Get_deal.ipynb
# HubSpot/HubSpot_Get_notes_from_contact.ipynb
# HubSpot/HubSpot_Send_LinkedIn_invitations_from_contacts.ipynb
# HubSpot/HubSpot_Send_closed_deals_weekly.ipynb
# HubSpot/HubSpot_Send_contacts_to_gsheet.ipynb
# HubSpot/HubSpot_Send_deals_to_gsheet.ipynb
# HubSpot/HubSpot_Send_new_deals_created_weekly.ipynb
# HubSpot/HubSpot_Send_sales_brief.ipynb
# HubSpot/HubSpot_Send_sales_pipeline_to_Notion.ipynb
# HubSpot/HubSpot_Update_Task.ipynb
# HubSpot/HubSpot_Update_contact.ipynb
# HubSpot/HubSpot_Update_deal.ipynb
# HubSpot/HubSpot_Update_followers_from_linkedin.ipynb
# HubSpot/HubSpot_Update_jobtitle_country_industry_from_linkedin.ipynb
# HubSpot/HubSpot_Update_linkedinbio_from_google.ipynb
# Hugging%20Face/Hugging_Face_Ask_boolean_question_to_T5.ipynb
# Hugging%20Face/Hugging_Face_Naas_drivers_integration.ipynb
# Hugging%20Face/Hugging_Face_Question_Answering_from_PDF.ipynb
# IFTTT/IFTTT_Post_on_Twitter.ipynb
# IFTTT/IFTTT_Trigger_workflow.ipynb
# IMDB/Top_IMDB_Movie.ipynb
# INPI/INPI_Download_PDF_recap.ipynb
# IPyWidgets/IPyWidgets_Create_button.ipynb
# IPyWidgets/IPyWidgets_Create_input_text_and_submit_button.ipynb
# IPyWidgets/IPyWidgets_Setup_naas_secret.ipynb
# IUCN/IUCN_Extinct_species.ipynb
# Insee/Insee_Download_PDF_recap.ipynb
# Instagram/Instagram_Get_stats_from_posts.ipynb
# Instagram/Instagram_Post_image_and_caption.ipynb
# Integromat/Integromat_Trigger_workflow.ipynb
# Johns%20Hopkins/Johns_Hopkins_Covid19_Active_Cases.ipynb
# Johns%20Hopkins/Johns_Hopkins_Get_Covid19_data.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Add_cells_in_notebook_json.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Add_tags_in_cells.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Apply_black_on_notebook_file.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Count_code_characters.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Count_code_lines.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Get_installs.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Get_libraries.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Read_file_json.ipynb
# Jupyter%20Notebooks/Jupyter_Notebooks_Save_file_ipynb.ipynb
# Jupyter/Jupyter_Get_server_uptime.ipynb
# Jupyter/Jupyter_Get_user_information.ipynb
# Jupyter/Jupyter_Get_user_session.ipynb
# Jupyter/Jupyter_Get_user_terminal.ipynb
# Jupyter/Jupyter_Restart_server.ipynb
# Kaggle/Kaggle_Download_Data.ipynb
# Knative/Knative_Create_command_file.ipynb
# LangChain/LangChain_Pandas_Dataframe_Agent.ipynb
# LeFigaro/LeFigaro_House_Price_analysis.ipynb
# LinkedIn%20Sales%20Navigator/LinkedIn_Sales_Navigator_Extract_Leads_List_from_URL.ipynb
# LinkedIn%20Sales%20Navigator/LinkedIn_Sales_Navigator_Send_Leads_to_Spreadsheet.ipynb
# LinkedIn/LinkedIn_Accept_all_invitations_and_send_first_message.ipynb
# LinkedIn/LinkedIn_Accept_invitation_received.ipynb
# LinkedIn/LinkedIn_Create_Post.ipynb
# LinkedIn/LinkedIn_Create_posts_metrics_dashboard.ipynb
# LinkedIn/LinkedIn_Extract_content_world_cloud.ipynb
# LinkedIn/LinkedIn_Follow_company_followers.ipynb
# LinkedIn/LinkedIn_Follow_connections_from_profile.ipynb
# LinkedIn/LinkedIn_Follow_content_comments_monthly.ipynb
# LinkedIn/LinkedIn_Follow_content_comments_weekly.ipynb
# LinkedIn/LinkedIn_Follow_content_engagements_monthly.ipynb
# LinkedIn/LinkedIn_Follow_content_engagements_weekly.ipynb
# LinkedIn/LinkedIn_Follow_content_frequency.ipynb
# LinkedIn/LinkedIn_Follow_content_likes_monthly.ipynb
# LinkedIn/LinkedIn_Follow_content_likes_weekly.ipynb
# LinkedIn/LinkedIn_Follow_content_published_by_weekdays_by_months.ipynb
# LinkedIn/LinkedIn_Follow_content_published_monthly.ipynb
# LinkedIn/LinkedIn_Follow_content_published_weekly.ipynb
# LinkedIn/LinkedIn_Follow_content_views_by_weekdays_by_hours.ipynb
# LinkedIn/LinkedIn_Follow_content_views_monthly.ipynb
# LinkedIn/LinkedIn_Follow_content_views_weekly.ipynb
# LinkedIn/LinkedIn_Follow_number_of_connections_monthly.ipynb
# LinkedIn/LinkedIn_Generate_leads_from_posts.ipynb
# LinkedIn/LinkedIn_Get_age_and_gender_from_profile_picture.ipynb
# LinkedIn/LinkedIn_Get_comments_from_post.ipynb
# LinkedIn/LinkedIn_Get_company_followers.ipynb
# LinkedIn/LinkedIn_Get_company_posts_stats.ipynb
# LinkedIn/LinkedIn_Get_connections_from_network.ipynb
# LinkedIn/LinkedIn_Get_contact_from_profile.ipynb
# LinkedIn/LinkedIn_Get_conversations.ipynb
# LinkedIn/LinkedIn_Get_followers_from_network.ipynb
# LinkedIn/LinkedIn_Get_guests_from_event.ipynb
# LinkedIn/LinkedIn_Get_identity_from_profile.ipynb
# LinkedIn/LinkedIn_Get_info_from_company.ipynb
# LinkedIn/LinkedIn_Get_invitations_received.ipynb
# LinkedIn/LinkedIn_Get_invitations_sent.ipynb
# LinkedIn/LinkedIn_Get_likes_from_post.ipynb
# LinkedIn/LinkedIn_Get_messages_from_profile.ipynb
# LinkedIn/LinkedIn_Get_network_from_profile.ipynb
# LinkedIn/LinkedIn_Get_polls_from_post.ipynb
# LinkedIn/LinkedIn_Get_posts_engagements.ipynb
# LinkedIn/LinkedIn_Get_profile_information.ipynb
# LinkedIn/LinkedIn_Get_profile_posts_stats.ipynb
# LinkedIn/LinkedIn_Get_resume_from_profile.ipynb
# LinkedIn/LinkedIn_Get_sentiment_emotion_irony_offensiveness_from_comments.ipynb
# LinkedIn/LinkedIn_Get_stats_from_post.ipynb
# LinkedIn/LinkedIn_Ignore_invitation_received.ipynb
# LinkedIn/LinkedIn_Send_comments_from_post_to_gsheet.ipynb
# LinkedIn/LinkedIn_Send_company_followers_to_Google_Sheets.ipynb
# LinkedIn/LinkedIn_Send_connections_from_network_to_gsheet.ipynb
# LinkedIn/LinkedIn_Send_event_invitations_post_engagements.ipynb
# LinkedIn/LinkedIn_Send_followers_demographic_data_to_a_Google_Sheets_spreadsheet.ipynb
# LinkedIn/LinkedIn_Send_invitation_to_company_followers.ipynb
# LinkedIn/LinkedIn_Send_invitation_to_profile.ipynb
# LinkedIn/LinkedIn_Send_invitation_to_profile_from_post_likes.ipynb
# LinkedIn/LinkedIn_Send_invitations_to_post_commenters.ipynb
# LinkedIn/LinkedIn_Send_likes_from_post_to_gsheet.ipynb
# LinkedIn/LinkedIn_Send_message_to_new_connections.ipynb
# LinkedIn/LinkedIn_Send_message_to_profile.ipynb
# LinkedIn/LinkedIn_Send_message_to_profile_from_post_likes.ipynb
# LinkedIn/LinkedIn_Send_posts_feed_to_gsheet.ipynb
# LinkedIn/LinkedIn_Send_profile_followers_by_email.ipynb
# LinkedIn/LinkedIn_Send_weekly_post_engagement_metrics_by_email.ipynb
# LinkedIn/LinkedIn_Update_metrics_from_company_posts_in_Notion_content_calendar.ipynb
# LinkedIn/LinkedIn_Update_metrics_from_posts_in_Notion_content_calendar.ipynb
# LinkedIn/LinkedIn_Withdraw_pending_profile_invitations.ipynb
# Matplotlib/Matplotlib_Create_Waterfall_chart.ipynb
# Metrics%20Store/Content_creation_Track_connections.ipynb
# Microsoft%20Teams/Microsoft_Teams_Send_message.ipynb
# Microsoft%20Word/Microsoft_Word_Convert_to_HMTL.ipynb
# MongoDB/MongoDB_Get_data.ipynb
# MongoDB/MongoDB_Send_data.ipynb
# MongoDB/MongoDB_Send_data_to_Google_Sheets.ipynb
# MySQL/MySQL_Query_database.ipynb
# NASA/NASA_Artic_sea_ice.ipynb
# NASA/NASA_Global_temperature.ipynb
# NASA/NASA_Sea_level.ipynb
# Naas%20Auth/Naas_Auth_bearer_validate.ipynb
# Naas%20Auth/Naas_Auth_connect.ipynb
# Naas%20Auth/Naas_Auth_users_me.ipynb
# Naas%20Dashboard/Naas_Dashboard_Financial_Consolidation.ipynb
# Naas%20Dashboard/Naas_Dashboard_Revenue_Cogs_by_Segment.ipynb
# Naas%20Dashboard/Naas_Dashboard_Social_Media_KPIs_ScoreCard.ipynb
# Naas/Naas_Add_or_Update_Asset.ipynb
# Naas/Naas_Add_or_Update_Dependency.ipynb
# Naas/Naas_Add_or_Update_Scheduler.ipynb
# Naas/Naas_Add_or_Update_Secret.ipynb
# Naas/Naas_Add_or_Update_Webhook.ipynb
# Naas/Naas_Asset_demo.ipynb
# Naas/Naas_Automate_GitHub_Auth.ipynb
# Naas/Naas_Configure_Github_with_ssh.ipynb
# Naas/Naas_Create_Kernel.ipynb
# Naas/Naas_Create_Pipeline.ipynb
# Naas/Naas_Credits_Get_Balance.ipynb
# Naas/Naas_Delete_Asset.ipynb
# Naas/Naas_Delete_Dependency.ipynb
# Naas/Naas_Delete_Scheduler.ipynb
# Naas/Naas_Delete_Secret.ipynb
# Naas/Naas_Delete_Webhook.ipynb
# Naas/Naas_Dependency_demo.ipynb
# Naas/Naas_Doc_demo.ipynb
# Naas/Naas_Download_Content_Engine.ipynb
# Naas/Naas_Emailbuilder_demo.ipynb
# Naas/Naas_Find_Asset_link_from_path.ipynb
# Naas/Naas_Get_Transactions.ipynb
# Naas/Naas_Get_help.ipynb
# Naas/Naas_Get_number_of_downloads_naas_drivers_package.ipynb
# Naas/Naas_Get_number_of_downloads_naas_package.ipynb
# Naas/Naas_Get_total_downloads_naas_libraries.ipynb
# Naas/Naas_List_Assets.ipynb
# Naas/Naas_List_Dependencies.ipynb
# Naas/Naas_List_Schedulers.ipynb
# Naas/Naas_List_Schedulers_with_all_executions.ipynb
# Naas/Naas_List_Schedulers_with_last_execution.ipynb
# Naas/Naas_List_Secrets.ipynb
# Naas/Naas_List_Webhooks.ipynb
# Naas/Naas_Manage_Pipeline_Errors.ipynb
# Naas/Naas_NLP_Examples.ipynb
# Naas/Naas_Notification_demo.ipynb
# Naas/Naas_Remove_Pipeline_Executions_Outputs.ipynb
# Naas/Naas_Remove_Scheduler_Outputs.ipynb
# Naas/Naas_Reset_Instance.ipynb
# Naas/Naas_Scheduler_demo.ipynb
# Naas/Naas_Secret_demo.ipynb
# Naas/Naas_Send_Asset_image_to_Notion_page.ipynb
# Naas/Naas_Send_notifications_from_Google_Sheets.ipynb
# Naas/Naas_Set_timezone.ipynb
# Naas/Naas_Start_data_product.ipynb
# Naas/Naas_Use_SSH_tunnel_to_reach_network_protected_resources.ipynb
# Naas/Naas_Webhook_demo.ipynb
# Neo/Neo_Get_currencies_live_prices.ipynb
# Newsapi/Newsapi_Get_data.ipynb
# Newsapi/Newsapi_Run_sentiment_analysis.ipynb
# Newsapi/Newsapi_Send_emails_briefs.ipynb
# Notion/Notion_Add_bulleted_list_in_page.ipynb
# Notion/Notion_Add_code_block_in_page.ipynb
# Notion/Notion_Add_cover_image_to_page.ipynb
# Notion/Notion_Add_equation_in_page.ipynb
# Notion/Notion_Add_heading_in_page.ipynb
# Notion/Notion_Add_icon_image_to_page.ipynb
# Notion/Notion_Add_new_github_member_to_team_from_database.ipynb
# Notion/Notion_Add_numbered_list_in_page.ipynb
# Notion/Notion_Add_paragraph_with_link_in_page.ipynb
# Notion/Notion_Add_to_do_list_in_page.ipynb
# Notion/Notion_Automate_transcript_generation_from_recording_link_in_page_property.ipynb
# Notion/Notion_Create_page.ipynb
# Notion/Notion_Create_pages_in_database_from_dataframe.ipynb
# Notion/Notion_Delete_all_pages_from_database.ipynb
# Notion/Notion_Delete_blocks_from_page.ipynb
# Notion/Notion_Delete_page.ipynb
# Notion/Notion_Duplicate_page.ipynb
# Notion/Notion_Explore_API.ipynb
# Notion/Notion_Generate_Google_Sheets_rows_for_new_items_in_Notion_database.ipynb
# Notion/Notion_Get_blocks_from_page.ipynb
# Notion/Notion_Get_database.ipynb
# Notion/Notion_Get_page.ipynb
# Notion/Notion_Get_users.ipynb
# Notion/Notion_Send_LinkedIn_invitations_from_database.ipynb
# Notion/Notion_Send_Slack_Messages_For_New_Notion_Database_Items.ipynb
# Notion/Notion_Sent_Gmail_On_New_Item.ipynb
# Notion/Notion_Update_database_with_GitHub_repositories_info.ipynb
# Notion/Notion_Update_database_with_LinkedIn_company_info.ipynb
# Notion/Notion_Update_database_with_LinkedIn_profile_info.ipynb
# Notion/Notion_Update_page.ipynb
# Notion/Notion_Update_page_relation.ipynb
# Notion/Notion_Update_pages_from_database.ipynb
# Notion/Notion_Upload_PDF_in_page.ipynb
# Notion/Notion_Upload_image_in_page.ipynb
# Notion/Notion_Upload_video_in_page.ipynb
# OS/OS_Access_environment_variable.ipynb
# OS/OS_Add_new_environment_variable.ipynb
# OS/OS_Check_path_exist.ipynb
# OS/OS_Create_directory.ipynb
# OS/OS_Get_access_of_environment_variables.ipynb
# OS/OS_Get_current_working_directory.ipynb
# OS/OS_Remove_file.ipynb
# OS/OS_Rename_file.ipynb
# OpenAI/OpenAI_Act_as_a_chef.ipynb
# Button to be updated: https://github.com/jupyter-naas/awesome-notebooks/blob/master/OpenAI/OpenAI_Act_as_a_chef.ipynb
# OpenAI/OpenAI_Brainstorm_ideas.ipynb
# OpenAI/OpenAI_Create_Completion.ipynb
# OpenAI/OpenAI_Create_chat_completion.ipynb
# OpenAI/OpenAI_Create_chatbot.ipynb
# OpenAI/OpenAI_Generate_Dialogue.ipynb
# OpenAI/OpenAI_Generate_Q%26A.ipynb
# OpenAI/OpenAI_Generate_README_for_GitHub_repository.ipynb
# OpenAI/OpenAI_Generate_Text_to_Speech.ipynb
# OpenAI/OpenAI_Generate_image_from_text.ipynb
# OpenAI/OpenAI_Generate_language_translations.ipynb
# OpenAI/OpenAI_Generate_text_based_prediction.ipynb
# OpenAI/OpenAI_Generate_text_replacements.ipynb
# OpenAI/OpenAI_Generate_text_summaries.ipynb
# OpenAI/OpenAI_Write_a_blog_post.ipynb
# OpenAI/OpenAI_Write_a_job_description.ipynb
# OpenAI/OpenAI_Write_a_press_release.ipynb
# OpenAI/OpenAI_Write_a_social_media_post.ipynb
# OpenAI/OpenAI_Write_an_outline.ipynb
# OpenBB/OpenBB_Create_an_OpenBB_kernel_on_Naas.ipynb
# OpenPIV/openpiv-python-template.ipynb
# Button to be updated: https://github.com/jupyter-naas/awesome-notebooks/blob/master/OpenPIV/openpiv-python-template.ipynb
# OpenWeatherMap/OpenWeatherMap_Get_City_Weather.ipynb
# OpenWeatherMap/OpenWeatherMap_Get_City_temperature_weather-type_wind-speed.ipynb
# Button to be updated: https://github.com/jupyter-naas/awesome-notebooks/blob/master/OpenWeatherMap/OpenWeatherMap_Get_City_temperature_weather-type_wind-speed.ipynb
# OpenWeatherMap/OpenWeatherMap_Send_daily_email_with_predictions.ipynb
# OwnCloud/OwnCloud_Download_file.ipynb
# OwnCloud/OwnCloud_Upload_file.ipynb
# PDF/PDF_Extract_Text_from_PDF.ipynb
# PDF/PDF_Merge_multiple_PDF_documents.ipynb
# PDF/PDF_Transform_to_MP3.ipynb
# Pandas/Pandas_Check_Columns_type.ipynb
# Pandas/Pandas_Concatenate_dataframes.ipynb
# Pandas/Pandas_Convert_datetime_series.ipynb
# Pandas/Pandas_Create_Pivot_Table.ipynb
# Pandas/Pandas_Create_conditional_column_enrichment_using_DataFrame.loc.ipynb
# Pandas/Pandas_Create_dataframe_from_dict.ipynb
# Pandas/Pandas_Drop_Columns_By_Index.ipynb
# Pandas/Pandas_Drop_First_column.ipynb
# Pandas/Pandas_Drop_columns.ipynb
# Pandas/Pandas_Drop_duplicates.ipynb
# Pandas/Pandas_Enforce_data_types_to_columns.ipynb
# Pandas/Pandas_Fill_emtpy_values.ipynb
# Pandas/Pandas_Filter_DataFrame.ipynb
# Pandas/Pandas_Flatten_MultiIndex_Columns.ipynb
# Pandas/Pandas_Format_number_to_string.ipynb
# Pandas/Pandas_Groupby_and_Aggregate.ipynb
# Pandas/Pandas_ISO_Date_Conversion.ipynb
# Pandas/Pandas_Insert_column.ipynb
# Pandas/Pandas_Iterate_over_DataFrame_rows.ipynb
# Pandas/Pandas_Iterate_over_DataFrame_rows_as_namedtuples.ipynb
# Pandas/Pandas_Keep_columns.ipynb
# Pandas/Pandas_Looping_Over_Dataframe.ipynb
# Pandas/Pandas_Map_column_with_values_in_dict.ipynb
# Pandas/Pandas_Merge_Dataframes.ipynb
# Pandas/Pandas_Pivot_rows_to_columns.ipynb
# Pandas/Pandas_Read_CSV.ipynb
# Pandas/Pandas_Read_Excel.ipynb
# Pandas/Pandas_Rename_columns.ipynb
# Pandas/Pandas_Save_dataframe_to_CSV.ipynb
# Pandas/Pandas_Save_dataframe_to_Excel.ipynb
# Pandas/Pandas_Transform_DataFrame_to_json_file.ipynb
# Pandas/Pandas_Transform_Dataframe_to_dict.ipynb
# Pandasql/Pandasql_Query_CSV_Using_SQL.ipynb
# Pandasql/Pandasql_Query_Excel_Using_SQL.ipynb
# Pandasql/Pandasql_Query_Parquet_Using_SQL.ipynb
# Panel/Panel_Create_a_Panel_kernel_on_Naas.ipynb
# Pillow/Pillow_Add_data_to_image.ipynb
# Pillow/Pillow_Create_indicator.ipynb
# Pillow/Pillow_Create_new_image.ipynb
# Pillow/Pillow_Generate_A_Certificate_Template.ipynb
# Pipedrive/Pipedrive_Get_contact.ipynb
# Plaid/Plaid_Get_accounts.ipynb
# Plaid/Plaid_Get_transactions.ipynb
# Plotly/Plotly_Create_Balance_Sheet_Treemaps.ipynb
# Plotly/Plotly_Create_Barline_chart.ipynb
# Plotly/Plotly_Create_Bubblechart.ipynb
# Plotly/Plotly_Create_Bubblemap_by_City.ipynb
# Plotly/Plotly_Create_Candlestick.ipynb
# Plotly/Plotly_Create_Gantt_chart.ipynb
# Plotly/Plotly_Create_Heatmap.ipynb
# Plotly/Plotly_Create_Horizontal_Barchart.ipynb
# Plotly/Plotly_Create_Leaderboard.ipynb
# Plotly/Plotly_Create_Leaderboard_stacked.ipynb
# Plotly/Plotly_Create_Linechart.ipynb
# Plotly/Plotly_Create_Mapchart_world.ipynb
# Plotly/Plotly_Create_Treemaps_with_plotly.express.ipynb
# Plotly/Plotly_Create_Treemaps_with_plotly.graph_objects.ipynb
# Plotly/Plotly_Create_Vertical_Barchart.ipynb
# Plotly/Plotly_Create_Vertical_Barchart_group.ipynb
# Plotly/Plotly_Create_Vertical_Barchart_stacked.ipynb
# Plotly/Plotly_Create_Waterfall_chart.ipynb
# Polars/Polars_Read_CSV.ipynb
# PostgresSQL/PostgresSQL_Get_data_from_database.ipynb
# PowerPoint/PowerPoint_Add_Slide_With_Image.ipynb
# PowerPoint/PowerPoint_Add_Slide_With_Textbox.ipynb
# PowerPoint/PowerPoint_Add_Slide_With_Title_Subtitle.ipynb
# PowerPoint/PowerPoint_Add_title_%2B_line_in_presentation.ipynb
# PowerPoint/PowerPoint_Create_Presentation.ipynb
# PowerPoint/PowerPoint_Set_portrait_format.ipynb
# PyCaret/PyCaret_automl_classification.ipynb
# PyCaret/PyCaret_automl_regression.ipynb
# PyGWalker/PyGWalker_Analyze_Pandas_dataframe.ipynb
# PyPI/PyPI%20-%20Get_number_of_downloads_any_package.ipynb
# Button to be updated: https://github.com/jupyter-naas/awesome-notebooks/blob/master/PyPI/PyPI%20-%20Get_number_of_downloads_any_package.ipynb
# Python/Python_Calculate_relative_time_delta_between_two_dates.ipynb
# Python/Python_Calculate_time_delta_between_two_dates.ipynb
# Python/Python_Clean_your_download_folder.ipynb
# Python/Python_Compress_images.ipynb
# Python/Python_Consolidate_Excel_files.ipynb
# Python/Python_Convert_CSV_to_Excel.ipynb
# Python/Python_Convert_Datetime_with_Timezone_to_ISO_8601_date_string.ipynb
# Python/Python_Convert_PNG_Images_To_JPG.ipynb
# Python/Python_Convert_URL_to_string.ipynb
# Python/Python_Convert_audiofile_from_wav_to_mp3.ipynb
# Python/Python_Convert_relative_time_delta_to_months.ipynb
# Python/Python_Convert_string_to_URL.ipynb
# Python/Python_Convert_time_delta_to_months.ipynb
# Python/Python_Copy_files_and_subdir_from_directory_to_another_directory.ipynb.ipynb
# Python/Python_Create_Email_Combination_with_Firstname_Lastname_Domain_address.ipynb
# Python/Python_Create_Strong_Random_Password.ipynb
# Python/Python_Create_dataframe_from_lists.ipynb
# Python/Python_Create_dict_from_lists.ipynb
# Python/Python_Delete_entire_directory_tree.ipynb
# Python/Python_Download_Image_from_URL.ipynb
# Python/Python_Download_PDF_from_URL.ipynb
# Python/Python_Download_ZIP_from_URL.ipynb
# Python/Python_Explore_Dataset_with_Pivot_Table.ipynb
# Python/Python_Find_Phone_Number_in_string.ipynb
# Python/Python_Flatten_nested_dict.ipynb
# Python/Python_Get_Word_Definition_and_Translation.ipynb
# Python/Python_Get_all_files_from_directory.ipynb
# Python/Python_Get_coordinates_from_address.ipynb
# Python/Python_Get_last_file_modified_from_directy.ipynb
# Python/Python_Get_next_occurrences_of_a_cron_job.ipynb
# Python/Python_Get_random_number.ipynb
# Python/Python_List_specific_files_from_directory_and_subdirectories.ipynb
# Python/Python_Locate_address_on_map.ipynb
# Python/Python_Locate_city_on_map.ipynb
# Python/Python_Locate_coordinates.ipynb
# Python/Python_Looping_Over_Dataframe.ipynb
# Python/Python_Organize_Directories_based_on_file_types.ipynb
# Python/Python_Read_json_file.ipynb
# Python/Python_Read_pickle_file.ipynb
# Python/Python_Remove_all_spaces_on_string.ipynb
# Python/Python_Save_dict_to_pickle.ipynb
# Python/Python_Save_json_file.ipynb
# Python/Python_Split_string.ipynb
# Python/Python_Using_datetime_library.ipynb
# Python/Python_Validate_email_and_phone_numbers.ipynb
# Pyvis/Pyvis_Create_a_network_visualization.ipynb
# Qonto/Qonto_Get_cash_position_trend.ipynb
# Qonto/Qonto_Get_organizations.ipynb
# Qonto/Qonto_Get_positions.ipynb
# Qonto/Qonto_Get_statement.ipynb
# Qonto/Qonto_Get_statement_barline.ipynb
# Qonto/Qonto_Get_statement_ranking_by_category.ipynb
# Qonto/Qonto_Get_statement_summary_by_operation_type.ipynb
# Qonto/Qonto_Get_transactions.ipynb
# Qonto/Qonto_Releve_de_compte_augmente.ipynb
# Quandl/Quandl_Get_data_from_API.ipynb
# Quandl/Quandl_Get_data_from_CSV.ipynb
# Reddit/Reddit_Get_Hot_Posts_From_Subreddit.ipynb
# Redshift/Redshift_Connect_with_SQL_Magic_and_IAM_Credentials.ipynb
# RegEx/RegEx_Check_email_validity.ipynb
# RegEx/RegEx_Match_pattern.ipynb
# RegEx/RegEx_Replace_value_in_text_in_a_specific_paragraph.ipynb
# Remoteok/Remoteok_Get_jobs_from_categories.ipynb
# Remoteok/Remoteok_Post_daily_jobs_on_slack.ipynb
# Remotive/Remotive_Get_categories_from_job.ipynb
# Remotive/Remotive_Get_jobs_from_categories.ipynb
# Remotive/Remotive_Post_daily_jobs_on_slack.ipynb
# Remotive/Remotive_Send_jobs_to_gsheet.ipynb
# SAP-HANA/SAP-HANA_Query_data.ipynb
# SEON/SEON_Get_email_info.ipynb
# SQLite/SQLite_Create_Database_file.ipynb
# SQLite/SQLite_Create_Table_in_Database.ipynb
# SQLite/SQLite_Insert_data_in_Table.ipynb
# SQLite/SQLite_List_Tables_in_Database.ipynb
# SQLite/SQLite_Read_data_in_Table.ipynb
# SWIFT/SWIFT_Create_MT940_XML_file.ipynb
# SendGrid/SendGrid_Get_all_messages.ipynb
# SendGrid/SendGrid_Send_message.ipynb
# Sendinblue/Sendinblue_Get_no_of_emails_opened.ipynb
# Sendinblue/Sendinblue_Get_no_of_emails_sent.ipynb
# Sendinblue/Sendinblue_Get_no_of_spam_reports.ipynb
# Sendinblue/Sendinblue_Get_no_of_undelivered_emails.ipynb
# SharePoint/SharePoint_Get_file.ipynb
# SharePoint/SharePoint_List_folder.ipynb
# SharePoint/SharePoint_Upload_file.ipynb
# Slack/Slack_Add_new_user_to_Google_Sheets.ipynb
# Slack/Slack_Follow_number_of_users_in_workspace.ipynb
# Slack/Slack_Send_message.ipynb
# Snowflake/Snowflake_Basics_and_data_querying.ipynb
# Snowflake/Snowflake_Ingest_csv_data_from_local_stage.ipynb
# Snowflake/Snowflake_Ingest_data_from_AWS_external_stages.ipynb
# Snowflake/Snowflake_Ingest_json_data_from_local_stage.ipynb
# Societe.com/Societe.com_Get_company_details.ipynb
# Societe.com/Societe.com_Get_verif.com.ipynb
# Spotify/Spotify_Create_Radar_Chart_to_analyze_Playlist.ipynb
# Stabilty%20AI/Stabilty_AI_Generate_Image_from_text.ipynb
# Stable%20Diffusion/Stable_Diffusion_Generate_image_from_text.ipynb
# Streamlit/Streamlit_Create_prediction_app.ipynb
# Stripe/Stripe_Create_a_customer.ipynb
# Stripe/Stripe_Delete_a_customer.ipynb
# Stripe/Stripe_Get_balances.ipynb
# Stripe/Stripe_Get_charges.ipynb
# Stripe/Stripe_List_all_customers.ipynb
# Stripe/Stripe_Retrieve_a_customer.ipynb
# Stripe/Stripe_Update_a_customer.ipynb
# Supabase/Supabase_Email_Auth.ipynb
# Telegram/Telegram_Create_crypto_sentiment_bot.ipynb
# Text/Text_Reformat_Text_Without_Spaces.ipynb
# Thinkific/Thinkific_Get_users.ipynb
# Thinkific/Thinkific_Send_users.ipynb
# TikTok/TikTok_Get_user_stats.ipynb
# TikTok/TikTok_Get_videos_stats.ipynb
# Trello/Trello_Get_board_data.ipynb
# Twilio/Twilio_Add_SMS_to_Google_Sheets_spreadsheet.ipynb
# Twilio/Twilio_Make_Call.ipynb
# Twilio/Twilio_Send_SMS.ipynb
# Twitter/Twitter_Add_member_to_list.ipynb
# Twitter/Twitter_Get_followers_list.ipynb
# Twitter/Twitter_Get_members_of%20list.ipynb
# Twitter/Twitter_Get_posts_stats.ipynb
# Twitter/Twitter_Get_tweets_from_search.ipynb
# Twitter/Twitter_Get_tweets_stats_from_profile.ipynb
# Twitter/Twitter_Get_user_data.ipynb
# Twitter/Twitter_Post_text_and_image.ipynb
# Twitter/Twitter_Remove_member_from_list.ipynb
# Twitter/Twitter_Schedule_posts.ipynb
# Twitter/Twitter_Send_posts_stats_to_Notion.ipynb
# Typeform/Typeform_Log_New_Typeform_Entries_In_Notion_Databases.ipynb
# US%20Bureau%20of%20Labor%20Statistics/US_Bureau_of_Labor_Statistics_Follow_CPI.ipynb
# Vizzu/Vizzu_Create_Animated_Bar_Chart.ipynb
# Vizzu/Vizzu_Create_Animated_Pie_Chart.ipynb
# Vizzu/Vizzu_Create_Column_Chart.ipynb
# Vizzu/Vizzu_Create_Grouped_Column_Chart.ipynb
# Vizzu/Vizzu_Create_Line_Chart.ipynb
# Vizzu/Vizzu_Create_Stacked_Column_Chart.ipynb
# Vizzu/Vizzu_Create_Waterfall_Chart.ipynb
# WAQI/WAQI_Display_AQI_on_worldmap.ipynb
# WAQI/WAQI_Get_daily_air_quality_data_by_coordinates.ipynb
# WAQI/WAQI_Get_daily_air_quality_data_for_a_city.ipynb
# WAQI/WAQI_Get_stations_by_coordinates.ipynb
# WAQI/WAQI_Search_station_by_name.ipynb
# WSR/WHI_Create_indicator.ipynb
# WSR/WSR_Get_daily_Covid19_active_cases_trend_JHU.ipynb
# WSR/WSR_Get_daily_Covid19_active_cases_worldmap_JHU.ipynb
# WhatsApp/WhatsApp_Create_heatmap_of_activities.ipynb
# WhatsApp/WhatsApp_Transform_chat_txt_to_dataframe.ipynb
# Wikipedia/Wikipedia_List_largest_cities_in_the_world.ipynb
# WindsorAI/WindsorAI_Create_Dash_app_to_query_AP.ipynb
# WorldBank/WorldBank_GDP_contributors.ipynb
# WorldBank/WorldBank_GDP_per_capita_and_growth.ipynb
# WorldBank/WorldBank_GDP_per_country_and_evolution.ipynb
# WorldBank/WorldBank_Gini_index.ipynb
# WorldBank/WorldBank_Most_populated_countries.ipynb
# WorldBank/WorldBank_Richest_countries_top10.ipynb
# WorldBank/WorldBank_World_employment_by_sector.ipynb
# WorldBank/WorldBank_World_population_and_density.ipynb
# Worldometer/Worldometer_World_population_evolution_and_projections.ipynb
# XGBoost/XGBoost_Binary_classification_example_with_hyper-parameters_optimization.ipynb
# Button to be updated: https://github.com/jupyter-naas/awesome-notebooks/blob/master/XGBoost/XGBoost_Binary_classification_example_with_hyper-parameters_optimization.ipynb
# XML/XML_Transform_sitemap_to_dataframe.ipynb
# YahooFinance/YahooFinance_Candlestick_chart.ipynb
# YahooFinance/YahooFinance_Cryptocurrencies_heatmap_correlation_graph.ipynb
# YahooFinance/YahooFinance_Display_chart_from_ticker.ipynb
# YahooFinance/YahooFinance_Find_the_stock_with_closest_performance_using_KNN.ipynb
# YahooFinance/YahooFinance_Get_Brent_Crude_Oil_trend_and_predictions.ipynb
# YahooFinance/YahooFinance_Get_Stock_Update.ipynb
# YahooFinance/YahooFinance_Get_USDEUR_data_and_chart.ipynb
# YahooFinance/YahooFinance_Get_data_from_ticker.ipynb
# YahooFinance/YahooFinance_Send_daily_prediction_to_Email.ipynb
# YahooFinance/YahooFinance_Send_daily_prediction_to_Notion.ipynb
# YahooFinance/YahooFinance_Send_daily_prediction_to_Slack.ipynb
# YouTube/YouTube_Download_video.ipynb
# YouTube/YouTube_Extract_and_summarize_transcript.ipynb
# YouTube/YouTube_Extract_transcript_from_video.ipynb
# YouTube/YouTube_Get_statistics_from_channel.ipynb
# YouTube/YouTube_Get_statistics_from_video.ipynb
# YouTube/YouTube_Get_uploads_from_channel.ipynb
# YouTube/YouTube_Send_track_to_Spotify.ipynb
# YouTube/YouTube_Send_video_stats_to_Notion.ipynb
# YouTube/YouTube_Summarize_video.ipynb
# ZIP/ZIP_Extract_files.ipynb
# Zapier/Zapier_Trigger_workflow.ipynb
# ZeroBounce/ZeroBounce_Validate_Single_Email.ipynb
# gTTS/gTTS_Save_Text_to_Speech_to_MP3.ipynb
# spaCy/SpaCy_Build_a_sentiment_analysis_model_using_Twitter.ipynb

# %% [markdown]
# ## Output

# %% [markdown]
# ### Preview the generated list

# %%
markdown.display(generated_list)
# Out:
# <h2>AWS</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AWS/AWS_Daily_biling_notification_to_slack.ipynb">Daily biling notification to slack</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AWS/AWS_Get_files_from_S3_bucket.ipynb">Get files from S3 bucket</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AWS/AWS_Read_dataframe_from_S3.ipynb">Read dataframe from S3</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AWS/AWS_Send_dataframe_to_S3.ipynb">Send dataframe to S3</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AWS/AWS_Upload_file_to_S3_bucket.ipynb">Upload file to S3 bucket</a></li>
# </ul>
#
# <h2>Abstract API</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Abstract%20API/Abstract_API_Check_Email_Validation.ipynb">Check Email Validation</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Abstract%20API/Abstract_API_Get_IP_Geolocation.ipynb">Get IP Geolocation</a></li>
# </ul>
#
# <h2>Advertools</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Advertools/Advertools_Analyze_website_content_using_XML_sitemap.ipynb">Analyze website content using XML sitemap</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Advertools/Advertools_Audit_robots_txt_and_xml_sitemap_issues.ipynb">Audit robots txt and xml sitemap issues</a></li>
# </ul>
#
# <h2>Affinity</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Affinity/Affinity_Sync_with_Notion_database.ipynb">Sync with Notion database</a></li>
# </ul>
#
# <h2>Agicap</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Agicap/Agicap_Export_treasury_plan.ipynb">Export treasury plan</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Agicap/Agicap_Export_treasury_plan_by_account.ipynb">Export treasury plan by account</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Agicap/Agicap_List_companies.ipynb">List companies</a></li>
# </ul>
#
# <h2>Airtable</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Airtable/Airtable_Delete_data.ipynb">Delete data</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Airtable/Airtable_Get_data.ipynb">Get data</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Airtable/Airtable_Insert_data.ipynb">Insert data</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Airtable/Airtable_Search_data.ipynb">Search data</a></li>
# </ul>
#
# <h2>AlphaVantage</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AlphaVantage/AlphaVantage_Get_balance_sheet.ipynb">Get balance sheet</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AlphaVantage/AlphaVantage_Get_cashflow_statement.ipynb">Get cashflow statement</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AlphaVantage/AlphaVantage_Get_company_overview.ipynb">Get company overview</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/AlphaVantage/AlphaVantage_Get_income_statement.ipynb">Get income statement</a></li>
# </ul>
#
# <h2>Azure Blob Storage</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Azure%20Blob%20Storage/Azure_Blob_Storage_Upload_files.ipynb">Upload files</a></li>
# </ul>
#
# <h2>Bazimo</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bazimo/Bazimo_Get_export_Actifs.ipynb">Get export Actifs</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bazimo/Bazimo_Get_export_Baux.ipynb">Get export Baux</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bazimo/Bazimo_Get_export_Factures.ipynb">Get export Factures</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bazimo/Bazimo_Get_export_Locataires.ipynb">Get export Locataires</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bazimo/Bazimo_Get_export_Lots.ipynb">Get export Lots</a></li>
# </ul>
#
# <h2>BeautifulSoup</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/BeautifulSoup/BeautifulSoup_List_social_network_links_from_website.ipynb">List social network links from website</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/BeautifulSoup/BeautifulSoup_Scrape_emails_from_URL.ipynb">Scrape emails from URL</a></li>
# </ul>
#
# <h2>BigQuery</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/BigQuery/BigQuery_Create_table_from_csv.ipynb">Create table from csv</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/BigQuery/BigQuery_Read_Table.ipynb">Read Table</a></li>
# </ul>
#
# <h2>Bitly</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Create_Links.ipynb">Create Links</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Delete_a_Bitlink.ipynb">Delete a Bitlink</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Get_Clicks_for_a_Bitlink.ipynb">Get Clicks for a Bitlink</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Get_Metrics_for_a_Bitlink_by_City.ipynb">Get Metrics for a Bitlink by City</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Get_Metrics_for_a_Bitlink_by_Country.ipynb">Get Metrics for a Bitlink by Country</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Get_Metrics_for_a_Bitlink_by_Devices.ipynb">Get Metrics for a Bitlink by Devices</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Get_Metrics_for_a_Bitlink_by_Referrers.ipynb">Get Metrics for a Bitlink by Referrers</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Get_a_Clicks_Summary_for_a_Bitlink.ipynb">Get a Clicks Summary for a Bitlink</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Retrieve_Bitlink.ipynb">Retrieve Bitlink</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bitly/Bitly_Update_a_Bitlink.ipynb">Update a Bitlink</a></li>
# </ul>
#
# <h2>Boursorama</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Boursorama/Boursorama_Get_CDS.ipynb">Get CDS</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Boursorama/Boursorama_Get_EURIBOR_3_MOIS.ipynb">Get EURIBOR 3 MOIS</a></li>
# </ul>
#
# <h2>Bubble</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Bubble/Bubble_Send_data.ipynb">Send data</a></li>
# </ul>
#
# <h2>CCXT</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/CCXT/CCXT_Calculate_Support_and_Resistance.ipynb">Calculate Support and Resistance</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/CCXT/CCXT_Predict_Bitcoin_from_Binance.ipynb">Predict Bitcoin from Binance</a></li>
# </ul>
#
# <h2>CSV</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/CSV/CSV_Read_file.ipynb">Read file</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/CSV/CSV_Save_file.ipynb">Save file</a></li>
# </ul>
#
# <h2>Canny</h2>
#
# <ul>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/master/Canny/Canny_Create.ipynb">Create</a></li>
# <li><a href="https://github.com/jupyter-naas/awesome-notebooks/blob/ma

# %% [markdown]
# ### Generate README.md

# %%
# Open README template
template = open(readme_template).read()

# Replace var to get list of templates in markdown format
template = template.replace("[[DYNAMIC_LIST]]", generated_list)

# Save README
f  = open(readme, "w+")
f.write(template)
f.close()
print("✅ README updated")
# Out:
# ✅ README updated

# %% [markdown]
# ### Preview json

# %%
print("✅ JSON len:", len(json_templates))
pprint(json_templates[0])
# Out:
# ✅ JSON len: 752
# {'action': '<a '
#            'href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/AWS/AWS_Daily_biling_notification_to_slack.ipynb" '
#            'target="_parent"><img '
#            'src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>',
#  'author': 'Maxime Jublou',
#  'author_url': 'https://www.linkedin.com/in/maximejublou/',
#  'description': 'This notebook sends a daily notification to a Slack channel '
#                 'with the billing information from an AWS account. It allows '
#                 'users to easily keep track of their AWS spending.',
#  'image_url': '',
#  'imports': ['datetime',
#              'boto3',
#              'naas',
#              'dateutil.relativedelta',
#              'pandas',
#              'naas_drivers'],
#  'notebook': 'Daily biling notification to slack',
#  'notebook_url': 'https://github.com/jupyter-naas/awesome-notebooks/blob/master/AWS/AWS_Daily_biling_notification_to_slack.ipynb',
#  'open_in_chat': '',
#  'open_in_lab': 'https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/AWS/AWS_Daily_biling_notification_to_slack.ipynb',
#  'tags': ['#aws',
#           '#cloud',
#           '#storage',
#           '#S3bucket',
#           '#slack',
#           '#operations',
#           '#automation'],
#  'tool': 'AWS',
#  'updated_at': ''}

# %% [markdown]
# ### Generate json for naas manager & naas search

# %%
with open(json_file, 'w') as f:
    json.dump(json_templates, f)
print("✅ JSON file updated")
# Out:
# ✅ JSON file updated
