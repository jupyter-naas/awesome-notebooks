# %% [markdown]
# <img width="8%" alt="PowerPoint.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/PowerPoint.png" style="border-radius: 15%">

# %% [markdown]
# # PowerPoint - Set portrait format
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=PowerPoint+-+Set+portrait+format:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #powerpoint #slide #portrait #pptx #snippet

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-09-30)

# %% [markdown]
# **Description:** This notebook allows you to easily set the portrait format for your PowerPoint presentation.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    from pptx import Presentation
except:
    # !pip install python-pptx --user
    from pptx import Presentation
from pptx.util import Inches

# %% [markdown]
# ### Setup Variables

# %%
output_pptx = "MyPowerPoint_Slide.pptx"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create Presentation Obj

# %%
prs = Presentation()

# %% [markdown]
# ### Setup Width & Height (Portrait)

# %%
prs.slide_height = Inches(11.69)
prs.slide_width = Inches(8.27)

# %% [markdown]
# ### Add slide

# %%
blank_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(blank_slide_layout)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save presentation

# %%
prs.save(output_pptx)
