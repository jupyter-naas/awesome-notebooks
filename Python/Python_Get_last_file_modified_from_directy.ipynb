# %% [markdown]
# <img width="8%" alt="Python.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Python.png" style="border-radius: 15%">

# %% [markdown]
# # Python - Get last file modified from directy
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Python+-+Get+last+file+modified+from+directy:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #python #os #library #file #modified #directory

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-02-23)

# %% [markdown]
# **Description:** This notebook will show how to get the last file modified from a directory using the os library.

# %% [markdown]
# **References:**
# - [os library documentation](https://docs.python.org/3/library/os.html)
# - [os.listdir() documentation](https://docs.python.org/3/library/os.html#os.listdir)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import os

# %% [markdown]
# ### Setup Variables

# %%
# Set the directory path
directory_path = "./"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get last file modified

# %%
# Get the list of files in the directory
files_list = os.listdir(directory_path)
# Get the last file modified
last_file_modified = max(files_list, key=os.path.getmtime)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
# Print the last file modified
print(f"The last file modified is {last_file_modified}")
