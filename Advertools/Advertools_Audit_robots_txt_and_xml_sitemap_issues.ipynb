# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Advertools - Audit robots.txt and XML sitemap potential issues

# %% [markdown]
# **Tags:** #advertools #xml #sitemap #website #analyze #seo #robots.txt

# %% [markdown]
# **Author:** [Elias Dabbas](https://www.linkedin.com/in/eliasdabbas/)

# %% [markdown]
# **Description:** This notebook helps you check if there are any conflicts between robots.txt rules and your XML sitemap.
#
# * Are you disallowing URLs that you shouldn't?
# * Test and make sure you don't publish new pages with such conflicts.
# * Do this in bulk: for all URL/rule/user-agent combinations run all tests with one command.

# %% [markdown]
# **References:**
# - [advertools robots.txt functions](https://advertools.readthedocs.io/en/master/advertools.robotstxt.html)
# - [Google's robots reference](https://developers.google.com/search/docs/crawling-indexing/robots/robots_txt)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import advertools as adv
except ModuleNotFoundError:
    # !pip install advertools

# %% [markdown]
# ### Setup Variables
# - `robotstxt_url`: URL of the robots.txt file to convert to a `DataFrame`

# %%
robotstxt_url = "https://www.example.com/robots.txt"

# just for testing:
robotstxt_url = "https://www.google.com/robots.txt"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Analyze potential robots.txt and XML conflicts
#
# Getting the robots.txt file and converting it to a `DataFrame`.

# %%
robots_df = adv.robotstxt_to_df(robotstxt_url=robotstxt_url)
robots_df
# Out:
# 2023-05-24 15:22:39,594 | INFO | robotstxt.py:381 | robotstxt_to_df | Getting: https://www.google.com/robots.txt
#       directive                             content robotstxt_last_modified
# 0    User-agent                                   *     2023-05-22 21:30:00  \
# 1      Disallow                             /search     2023-05-22 21:30:00
# 2         Allow                       /search/about     2023-05-22 21:30:00
# 3         Allow                      /search/static     2023-05-22 21:30:00
# 4         Allow              /search/howsearchworks     2023-05-22 21:30:00
# ..          ...                                 ...                     ...
# 296    Disallow                             /search     2023-05-22 21:30:00
# 297    Disallow                             /groups     2023-05-22 21:30:00
# 298    Disallow                     /hosted/images/     2023-05-22 21:30:00
# 299    Disallow                                 /m/     2023-05-22 21:30:00
# 300     Sitemap  https://www.google.com/sitemap.xml     2023-05-22 21:30:00
#
#                          robotstxt_url                    download_date
# 0    https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# 1    https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# 2    https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# 3    https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# 4    https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# ..                                 ...                              ...
# 296  https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# 297  https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# 298  https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# 299  https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
# 300  https://www.google.com/robots.txt 2023-05-24 13:22:39.746456+00:00
#
# [301 rows x 5 columns]

# %% [markdown]
# Get XML sitemap(s) and convert to a `DataFrame`.

# %%
sitemap = adv.sitemap_to_df(
    # the function will extract and combine all available sitemaps
    # in the robots.txt file
    robotstxt_url,
    max_workers=8,
    recursive=True)
sitemap
# Out:
# 2023-05-24 15:22:46,730 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/docs/sitemaps.xml
# 2023-05-24 15:22:46,753 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/sheets/sitemaps.xml
# 2023-05-24 15:22:46,775 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/slides/sitemaps.xml
# 2023-05-24 15:22:46,813 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/forms/sitemaps.xml
# 2023-05-24 15:22:46,845 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/gmail/sitemap.xml
# 2023-05-24 15:22:46,879 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/get/sitemap.xml
# 2023-05-24 15:22:47,033 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/drive/sitemap.xml
# 2023-05-24 15:22:47,204 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/admob/sitemap.xml
# 2023-05-24 15:22:47,222 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/partners/about/sitemap.xml
# 2023-05-24 15:22:47,232 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/adwords/sitemap.xml
# 2023-05-24 15:22:47,789 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/business/sitemap.xml
# 2023-05-24 15:22:47,797 | WARNING | sitemaps.py:530 | sitemap_to_df | HTTP Error 404: Not Found https://www.google.com/webmasters/sitemap.xml
# 2023-05-24 15:22:47,898 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/services/sitemap.xml
# 2023-05-24 15:22:48,060 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/search/about/sitemap.xml
# 2023-05-24 15:22:48,143 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/calendar/about/sitemap.xml
# 2023-05-24 15:22:48,390 | WARNING | sitemaps.py:530 | sitemap_to_df | syntax error: line 1, column 0 https://www.google.com/flights/sitemap.xml
# 2023-05-24 15:22:48,878 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/adsense/start/sitemap-2.xml
# 2023-05-24 15:22:49,066 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/chromebook/sitemap-v3.xml
# 2023-05-24 15:22:49,080 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/nonprofits/sitemap.xml
# 2023-05-24 15:22:49,509 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/chrome/sitemap.xml
# 2023-05-24 15:22:49,943 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/adsense/start/sitemap-1.xml
# 2023-05-24 15:22:50,026 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/photos/sitemap.xml
# 2023-05-24 15:22:50,272 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/sitemap_search.xml
# 2023-05-24 15:22:50,301 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/chromebook/sitemap-v2.xml
# 2023-05-24 15:22:51,023 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/finance/sitemap.xml
# 2023-05-24 15:22:51,241 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.google.com/retail/sitemap.xml
#                                                                            loc
# 0                                           https://www.google.com/docs/about/  \
# 1                                   https://www.google.com/intl/af/docs/about/
# 2                                   https://www.google.com/intl/id/docs/about/
# 3                                   https://www.google.com/intl/ms/docs/about/
# 4                                   https://www.google.com/intl/ca/docs/about/
# ...                                                                        ...
# 46666  https://www.google.com/intl/it_ch/retail/solutions/manufacturer-center/
# 46667      https://www.google.com/intl/it_ch/retail/solutions/merchant-center/
# 46668        https://www.google.com/intl/it_ch/retail/solutions/not-available/
# 46669      https://www.google.com/intl/it_ch/retail/solutions/performance-max/
# 46670                     https://www.google.com/intl/it_ch/retail/why-google/
#
#       changefreq  priority                                    sitemap
# 0         Weekly       0.8   https://www.google.com/docs/sitemaps.xml  \
# 1         Weekly       0.8   https://www.google.com/docs/sitemaps.xml
# 2         Weekly       0.8   https://www.google.com/docs/sitemaps.xml
# 3         Weekly       0.8   https://www.google.com/docs/sitemaps.xml
# 4         Weekly       0.8   https://www.google.com/docs/sitemaps.xml
# ...          ...       ...                                        ...
# 46666        NaN       NaN  https://www.google.com/retail/sitemap.xml
# 46667        NaN       NaN  https://www.google.com/retail/sitemap.xml
# 46668        NaN       NaN  https://www.google.com/retail/sitemap.xml
# 46669        NaN       NaN  https://www.google.com/retail/sitemap.xml
# 46670        NaN       NaN  https://www.google.com/retail/sitemap.xml
#
#       sitemap_last_modified  sitemap_size_mb                    download_date
# 0       2020-05-25 08:30:00         0.392524 2023-05-24 13:22:46.736858+00:00  \
# 1       2020-05-25 08:30:00         0.392524 2023-05-24 13:22:46.736858+00:00
# 2       2020-05-25 08:30:00         0.392524 2023-05-24 13:22:46.736858+00:00
# 3       2020-05-25 08:30:00         0.392524 2023-05-24 13:22:46.736858+00:00
# 4       2020-05-25 08:30:00         0.392524 2023-05-24 13:22:46.736858+00:00
# ...                     ...              ...                              ...
# 46666   2023-04-17 05:30:00         4.386189 2023-05-24 13:22:51.261837+00:00
# 46667   2023-04-17 05:30:00         4.386189 2023-05-24 13:22:51.261837+00:00
# 46668   2023-04-17 05:30:00         4.386189 2023-05-24 13:22:51.261837+00:00
# 46669   2023-04-17 05:30:00         4.386189 2023-05-24 13:22:51.261837+00:00
# 46670   2023-04-17 05:30:00         4.386189 2023-05-24 13:22:51.261837+00:00
#
#       errors
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 46666    NaN
# 46667    NaN
# 46668    NaN
# 46669    NaN
# 46670    NaN
#
# [46671 rows x 8 columns]

# %% [markdown]
# #### Testing robots.txt
# For all URL/user-agent combinations check if the URL is blocked.

# %%
user_agents = robots_df[robots_df['directive'].str.contains('user-agent', case=False)]['content']
user_agents
# Out:
# 0                        *
# 281          AdsBot-Google
# 288             Twitterbot
# 294    facebookexternalhit
# Name: content, dtype: object

# %%
robots_report = adv.robotstxt_test(
    robotstxt_url=robotstxt_url,
    user_agents=user_agents,
    urls=sitemap['loc'].dropna())
robots_report
# Out:
#                             robotstxt_url           user_agent
# 0       https://www.google.com/robots.txt                    *  \
# 1       https://www.google.com/robots.txt                    *
# 2       https://www.google.com/robots.txt                    *
# 3       https://www.google.com/robots.txt                    *
# 4       https://www.google.com/robots.txt                    *
# ...                                   ...                  ...
# 186671  https://www.google.com/robots.txt  facebookexternalhit
# 186672  https://www.google.com/robots.txt  facebookexternalhit
# 186673  https://www.google.com/robots.txt  facebookexternalhit
# 186674  https://www.google.com/robots.txt  facebookexternalhit
# 186675  https://www.google.com/robots.txt  facebookexternalhit
#
#                       url_path  can_fetch
# 0       https://www.google.ad/       True
# 1       https://www.google.ae/       True
# 2       https://www.google.am/       True
# 3       https://www.google.as/       True
# 4       https://www.google.at/       True
# ...                        ...        ...
# 186671  https://www.google.tn/       True
# 186672  https://www.google.to/       True
# 186673  https://www.google.tt/       True
# 186674  https://www.google.vu/       True
# 186675  https://www.google.ws/       True
#
# [186676 rows x 4 columns]

# %% [markdown]
# Does Google have URLs listed in the XML sitemap that are also disallowed by its robots.txt
#
# (this is not necessarily a problem, because they might disallow it for some user-agents), but it's good to check.

# %% [markdown]
# ## Output

# %%
robots_report[~robots_report['can_fetch']]
# Out:
#                             robotstxt_url           user_agent
# 139889  https://www.google.com/robots.txt           Twitterbot  \
# 139890  https://www.google.com/robots.txt           Twitterbot
# 139891  https://www.google.com/robots.txt           Twitterbot
# 139892  https://www.google.com/robots.txt           Twitterbot
# 139893  https://www.google.com/robots.txt           Twitterbot
# 139894  https://www.google.com/robots.txt           Twitterbot
# 139895  https://www.google.com/robots.txt           Twitterbot
# 139896  https://www.google.com/robots.txt           Twitterbot
# 139897  https://www.google.com/robots.txt           Twitterbot
# 186558  https://www.google.com/robots.txt  facebookexternalhit
# 186559  https://www.google.com/robots.txt  facebookexternalhit
# 186560  https://www.google.com/robots.txt  facebookexternalhit
# 186561  https://www.google.com/robots.txt  facebookexternalhit
# 186562  https://www.google.com/robots.txt  facebookexternalhit
# 186563  https://www.google.com/robots.txt  facebookexternalhit
# 186564  https://www.google.com/robots.txt  facebookexternalhit
# 186565  https://www.google.com/robots.txt  facebookexternalhit
# 186566  https://www.google.com/robots.txt  facebookexternalhit
#
#                                                                  url_path
# 139889                               https://www.google.com/search/about/  \
# 139890                      https://www.google.com/search/howsearchworks/
# 139891           https://www.google.com/search/howsearchworks/algorithms/
# 139892    https://www.google.com/search/howsearchworks/crawling-indexing/
# 139893              https://www.google.com/search/howsearchworks/mission/
# 139894     https://www.google.com/search/howsearchworks/mission/open-web/
# 139895  https://www.google.com/search/howsearchworks/mission/site-owners/
# 139896    https://www.google.com/search/howsearchworks/mission/web-users/
# 139897            https://www.google.com/search/howsearchworks/responses/
# 186558                               https://www.google.com/search/about/
# 186559                      https://www.google.com/search/howsearchworks/
# 186560           https://www.google.com/search/howsearchworks/algorithms/
# 186561    https://www.google.com/search/howsearchworks/crawling-indexing/
# 186562              https://www.google.com/search/howsearchworks/mission/
# 186563     https://www.google.com/search/howsearchworks/mission/open-web/
# 186564  https://www.google.com/search/howsearchworks/mission/site-owners/
# 186565    https://www.google.com/search/howsearchworks/mission/web-users/
# 186566            https://www.google.com/search/howsearchworks/responses/
#
#         can_fetch
# 139889      False
# 139890      False
# 139891      False
# 139892      False
# 139893      False
# 139894      False
# 139895      False
# 139896      False
# 139897      False
# 186558      False
# 186559      False
# 186560      False
# 186561      False
# 186562      False
# 186563      False
# 186564      False
# 186565      False
# 186566      False
