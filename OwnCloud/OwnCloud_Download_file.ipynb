# %% [markdown]
# <img width="8%" alt="OwnCloud.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OwnCloud.png" style="border-radius: 15%">

# %% [markdown]
# # OwnCloud - Download file
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OwnCloud+-+Download+file:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #owncloud #cloud #storage #operations #snippet

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-05-08)

# %% [markdown]
# **Description:** This notebook allows users to download files from their OwnCloud account.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Install packages

# %%
# !pip install pyocclient

# %% [markdown]
# ### Import library

# %%
import naas
import owncloud

# %% [markdown]
# ## Model

# %% [markdown]
# ### Connect to your ownCloud

# %%
oc = owncloud.Client("https://cloud.damken.com")

oc.login("YOURNAME", "YOURPASS")

# %% [markdown]
# ## Output

# %% [markdown]
# ### Get file from your ownCloud

# %%
oc.get_file("testdir/download_to_owncloud.ipynb", "download_to_owncloud.ipynb")
