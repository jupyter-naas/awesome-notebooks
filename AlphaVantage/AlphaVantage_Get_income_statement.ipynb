# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # AlphaVantage - Get income statement
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/AlphaVantage/AlphaVantage_Get_income_statement.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #alphavantage #trading #market_data #investors #snippet #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/ACoAABCNSioBW3YZHc2lBHVG0E_TXYWitQkmwog/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# ### Variables

# %%
API_KEY = "demo"
COMPANY = "IBM"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get income statement

# %%
response = requests.get(f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol={COMPANY}&apikey={API_KEY}')
data = response.json()
df = pd.DataFrame(data.get("annualReports"))

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
df
