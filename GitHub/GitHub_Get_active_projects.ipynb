# %% [markdown]
# <img width="8%" alt="GitHub.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/GitHub.png" style="border-radius: 15%">

# %% [markdown]
# # GitHub - Get active projects
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=GitHub+-+Get+active+projects:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #github #projects #operations #snippet #dataframe

# %% [markdown]
# **Author:** [Sanjeet Attili](https://www.linkedin.com/in/sanjeet-attili-760bab190/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-03-18)

# %% [markdown]
# **Description:** This notebook provides an overview of active projects on GitHub.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Imports

# %%
from naas_drivers import github

# %% [markdown]
# ### Variables

# %%
# Github project url
PROJECT_URL = "https://github.com/orgs/jupyter-naas/projects"

# Github token
GITHUB_TOKEN = "ghp_COJiJEU4cQR4rjslUjM9Duxxxxxx"

# %% [markdown]
# ## Model

# %%
df_projects = github.connect(GITHUB_TOKEN).projects.get(PROJECT_URL)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
df_projects.head()
