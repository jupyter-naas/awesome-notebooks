# %% [markdown]
# <img width="8%" alt="RegEx.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/RegEx.png" style="border-radius: 15%">

# %% [markdown]
# # RegEx - Check email validity
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=RegEx+-+Check+email+validity:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #regex #python #email #validity #check #string

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-06-06 (Created: 2023-06-06)

# %% [markdown]
# **Description:** This notebook will demonstrate how to check the validity of an email address using `re` module.
# The `re.search()` function in Python's re module allows you to search for a specified pattern within a string. It returns a match object if the pattern is found, enabling you to extract relevant information from the string based on the given pattern.

# %% [markdown]
# **References:**
# - [Python Regular Expressions](https://docs.python.org/3/library/re.html)
# - [Python String Methods](https://docs.python.org/3/library/stdtypes.html#string-methods)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import re

# %% [markdown]
# ### Setup Variables
# - `email`: the email address to be checked

# %%
email = "florent.ravenel@gmail.com"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Check email validity

# %% [markdown]
# This function will check the validity of an email address using a regular expression.

# %%
def check_email_validity(email):
    regex = "^\w+([\.-]?\w+)*@\w+([\.-]?\w+)*(\.\w{2,3})+$"
    if re.search(regex, email):
        return True
    else:
        return False

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print(check_email_validity(email))
