# %% [markdown]
# <img width="8%" alt="Dash.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Dash.png" style="border-radius: 15%">

# %% [markdown]
# # Dash - Create Dropdown Callback
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Dash+-+Create+Dropdown+Callback:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #dashboard #plotly #dash #naas #asset #analytics #dropdown #callback #bootstrap

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-08-18)

# %% [markdown]
# Create a basic dropdown, provide options and a value to dcc.Dropdown in that order.

# %% [markdown]
# <u>Reference:</u> https://dash.plotly.com/dash-core-components/dropdown

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import os
try:
    import dash
except:
    # !pip install dash --user
    import dash
try:
    import dash_bootstrap_components as dbc
except:
    # !pip install dash_bootstrap_components --user
    import dash_bootstrap_components as dbcs
from dash import html, Input, Output, State, dcc

# %% [markdown]
# ### Setup Variables

# %%
DASH_PORT = 8050

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create dropdown

# %%
app = dash.Dash(
    requests_pathname_prefix=f'/user/{os.environ.get("JUPYTERHUB_USER")}/proxy/{DASH_PORT}/',
    external_stylesheets=[dbc.themes.BOOTSTRAP],
    meta_tags=[
        {"name": "viewport", "content": "width=device-width, initial-scale=1.0"}
    ],
)

app.layout = html.Div(
    [
        dcc.Dropdown(["NYC", "MTL", "SF"], "NYC", id="demo-dropdown"),
        html.Div(id="dd-output-container"),
    ]
)


@app.callback(
    Output("dd-output-container", "children"), Input("demo-dropdown", "value")
)
def update_output(value):
    return f"You have selected {value}"

# %% [markdown]
# ## Output

# %% [markdown]
# ### Generate URL and show logs

# %%
if __name__ == "__main__":
    app.run_server(proxy=f"http://127.0.0.1:{DASH_PORT}::https://app.naas.ai")
