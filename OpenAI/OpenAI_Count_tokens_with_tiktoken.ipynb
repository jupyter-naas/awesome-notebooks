# %% [markdown]
# <img width="8%" alt="OpenAI.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OpenAI.png" style="border-radius: 15%">

# %% [markdown]
# # OpenAI - Count tokens with tiktoken
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OpenAI+-+Count+tokens+with+tiktoken:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #openai #tiktoken #count #token #tokens #cookbook

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-06-16 (Created: 2023-06-16)

# %% [markdown]
# **Description:** This notebook shows how to count tokens used from a string with tiktoken to use OpenAI API.

# %% [markdown]
# **References:**
# - [OpenAI Cookbook](https://github.com/openai/openai-cookbook)
# - [How to count tokens with tiktoken](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import tiktoken
except:
    # !pip install tiktoken --user
    import tiktoken

# %% [markdown]
# ### Setup Variables
# - `text_string`: Given text string
# - `encoding_name`: Encoding

# %%
text_string = "tiktoken is great!"
encoding_name = "cl100k_base"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Count tokens
# Count tokens by counting the length of the list returned by .encode()

# %%
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
num_tokens = num_tokens_from_string(text_string, encoding_name)
print("Tokens:", num_tokens)
