# %% [markdown]
# <img width="8%" alt="Pandas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Pandas.png" style="border-radius: 15%">

# %% [markdown]
# # Pandas - Drop First column
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Pandas+-+Drop+First+column:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #pandas #snippet #datacleaning #operations

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-11-28)

# %% [markdown]
# **Description:** This notebook shows how to drop First Column in Pandas DataFrame (3 Methods).

# %% [markdown]
# <u>Reference:</u> https://www.statology.org/pandas-drop-first-column/

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Setup DataFrame

# %%
# create DataFrame
df = pd.DataFrame(
    {
        "team": ["A", "A", "A", "B", "B", "B"],
        "points": [11, 7, 8, 10, 13, 13],
        "assists": [5, 7, 7, 9, 12, 9],
        "rebounds": [11, 8, 10, 6, 6, 5],
    }
)
df

# %% [markdown]
# ## Model

# %% [markdown]
# ### Method 1: Use drop
# The following code shows how to use the drop() function to drop the first column of the pandas DataFrame.

# %%
# Copy init dataframe
df1 = df.copy()

df1 = df1.drop(columns=df1.columns[0], axis=1)
print(f"✅ Column '{df1.columns[0]}' removed from DataFrame.")
df1

# %% [markdown]
# ### Method 2: Use iloc
# The following code shows how to use the iloc function to drop the first column of the pandas DataFrame.

# %%
# Copy init dataframe
df2 = df.copy()


df2 = df2.iloc[:, 1:]
print(f"✅ Column '{df2.columns[0]}' removed from DataFrame.")
df2

# %% [markdown]
# ### Method 3: Use del
# The following code shows how to use the del function to drop the first column of the pandas DataFrame.

# %%
# Copy init dataframe
df3 = df.copy()

del df3[df3.columns[0]]
print(f"✅ Column '{df3.columns[0]}' removed from DataFrame.")
df3

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display Result

# %%
print("✅ Each method produces the same result")
