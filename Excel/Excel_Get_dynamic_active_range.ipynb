# %% [markdown]
# <img width="8%" alt="Excel.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Excel.png" style="border-radius: 15%">

# %% [markdown]
# # Excel - Get dynamic active range
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Excel+-+Get+dynamic+active+range:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #excel #openpyxl #active-range #finance #snippet #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/ACoAABCNSioBW3YZHc2lBHVG0E_TXYWitQkmwog/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-02-24)

# %% [markdown]
# **Description:** This notebook provides a method for dynamically retrieving the active range of an Excel worksheet.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from openpyxl import load_workbook
from openpyxl.utils import get_column_letter

# %% [markdown]
# ### Setup your Excel parameters

# %%
excel_path = "Excel_Template.xlsx"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Load Excel file and get active ws object

# %%
wb = load_workbook(excel_path)
ws = wb.active
ws

# %% [markdown]
# ### Get active range

# %%
def get_active_range(ws):
    max_row = ws.max_row
    max_col = get_column_letter(ws.max_column)
    active_range = f"A1:{max_col}{max_row}"
    return active_range


active_range = get_active_range(ws)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
active_range
