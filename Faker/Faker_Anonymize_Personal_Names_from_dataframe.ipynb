# %% [markdown]
# <img width="8%" alt="Faker.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Faker.png" style="border-radius: 15%">

# %% [markdown]
# # Faker - Anonymize Personal Names from dataframe
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Faker+-+Anonymize+Personal+Names+from+dataframe:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #faker #operations #snippet #database #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-09-09)

# %% [markdown]
# **Description:** This notebook provides a way to anonymize personal names from a dataframe using the Faker library.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    from faker import Faker
except:
    # !pip install faker
    from faker import Faker
import pandas as pd

# %% [markdown]
# ### Setup Data

# %%
data = [
    {"Name": "Marie", "Score": 12},
    {"Name": "Marie", "Score": 10},
    {"Name": "Mariana", "Score": 11},
]
df = pd.DataFrame(data)
df

# %% [markdown]
# ### Setup Faker
# Use faker.Faker() to create and initialize a faker generator, which can generate data by accessing properties named after the type of data you want.

# %%
faker = Faker()

# Column to be anonymize
col_name = "Name"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Fake names
# Through use of the `.unique` property on the generator, you can guarantee that any generated values are unique for this specific instance.

# %%
def fake_names(df, col_name):
    dict_names = {name: faker.unique.name() for name in df[col_name].unique()}
    df["New Name"] = df[col_name].map(dict_names)
    return df

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
df_fake_names = fake_names(df, col_name)
df_fake_names
