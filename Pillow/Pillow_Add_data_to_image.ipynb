# %% [markdown]
# <img width="8%" alt="Pillow.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Pillow.png" style="border-radius: 15%">

# %% [markdown]
# # Pillow - Add data to image
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Pillow+-+Add+data+to+image:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #pillow #opendata #snippet #data #image

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-04-19)

# %% [markdown]
# **Description:** This notebook demonstrates how to use the Pillow library to add data to an existing image.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from PIL import Image, ImageDraw, ImageFont
import naas

# %% [markdown]
# ### Setup variables

# %%
# Input
input_image = "layout.png"
input_font = "ArchivoBlack-Regular.ttf"

# Model
text_position = (50, 900)
text = "Your text"
font_size = 90

# Output
output_image = "output_image.png"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create output image

# %%
def create_image(
    input_image, output_image, text_position, text, font_size=90, input_font=None
):
    img = Image.open(input_image)
    d = ImageDraw.Draw(img)

    font = ImageFont.truetype(input_font, font_size)
    fill = (255, 255, 255)

    d.text(text_position, text, font=font, fill=fill)
    img.save(output_image)
    print("💾 Image saved :", output_image)
    return img


img = create_image(
    input_image, output_image, text_position, text, font_size, input_font
)
display(img)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save and share image

# %%
naas.asset.add(output_image)

# -> Uncomment the line below to remove your asset
# naas.asset.delete(output_image)
