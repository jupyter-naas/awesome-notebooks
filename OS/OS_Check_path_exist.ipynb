# %% [markdown]
# <img width="8%" alt="OS.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OS.png" style="border-radius: 15%">

# %% [markdown]
# # OS - Check path exist
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OS+-+Check+path+exist:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #os #python #path #file #system #library #snippet #operations #check

# %% [markdown]
# **Author:** [Benjamin Filly](https://www.linkedin.com/in/benjamin-filly-05427727a/)

# %% [markdown]
# **Last update:** 2023-06-08 (Created: 2023-06-08)

# %% [markdown]
# **Description:** This notebook will show how to check a path exist using os library.

# %% [markdown]
# **References:**
# - [os.path.exists() method](https://www.geeksforgeeks.org/python-os-path-exists-method/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import os

# %% [markdown]
# ### Setup Variables
# - `path`:  file path in your local system. If you are using Naas you should start with `/home/ftp` to locate your file

# %%
path = '/home/ftp/__templates__' # Specify path

# %% [markdown]
# ## Model

# %% [markdown]
# ### Check if path exists
# This function will check the precise location of the file or directory in a file system you put in the variable

# %%
is_exist = os.path.exists(path) # Check whether the specified path exists or not

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print("Is the path existing ?")
print(is_exist)
