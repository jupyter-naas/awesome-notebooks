# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - Delete Webhook
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+Delete+Webhook:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #scheduler #snippet #operations

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-04-24 (Created: 2023-04-24)

# %% [markdown]
# **Description:** This notebook will show how to delete a naas webhook.

# %% [markdown]
# **References:**
# - [Naas Documentation](https://docs.naas.ai/)
# - [Naas Webhook Documentation](https://docs.naas.ai/features/api)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import naas

# %% [markdown]
# ### Setup Variables
# - `path`: Go to your Naas manager, section "Jobs" and copy/paste the path of the scheduler you want to delete.
#
# If this notebook is not on your root folder, you need to set absolute path of your notebook starting with "/home/ftp/".

# %%
path = ""

# %% [markdown]
# ## Model

# %% [markdown]
# ### Delete Webhook

# %%
naas.webhook.delete(path=path)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print("🗑 Done! Your Notebook has been remove from production.")
