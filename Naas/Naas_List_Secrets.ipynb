# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - List Secrets
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+List+Secrets:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #secret #list #snippet

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-04-27 (Created: 2023-04-27)

# %% [markdown]
# **Description:** This notebook will show how to list of your secrets stored in Naas.
# A dataframe with the following column will be retunred:
# - "id"
# - "lastUpdate"
# - "name"
# - "secret"

# %% [markdown]
# **References:**
# - [Naas Documentation](https://docs.naas.ai/)
# - [Naas Secret Documentation](https://docs.naas.ai/features/secret)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import naas

# %% [markdown]
# ## Model

# %% [markdown]
# ### List Secrets

# %%
df = naas.secret.list()
df

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print('Secrets found:', len(df))
