# %% [markdown]
# <img width="8%" alt="IFTTT.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/IFTTT.png" style="border-radius: 15%">

# %% [markdown]
# # IFTTT - Trigger workflow
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=IFTTT+-+Trigger+workflow:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #ifttt #nocode #snippet #marketing

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-02-28)

# %% [markdown]
# **Description:** This notebook allows users to create automated workflows based on triggers from IFTTT.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import ifttt

# %% [markdown]
# ### Variables

# %%
event = "myevent"
key = "cl9U-VaeBu1**********"
data = {"value1": "Bryan", "value2": "Helmig", "value3": 27}

# %% [markdown]
# ## Model

# %% [markdown]
# ### Connect to IFTTT

# %%
result = ifttt.connect(key)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
result = ifttt.send(event, data)
