# %% [markdown]
# <img width="8%" alt="Pandas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Pandas.png" style="border-radius: 15%">

# %% [markdown]
# # Pandas - Keep columns
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Pandas+-+Keep+columns:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #pandas #snippet #datacleaning #operations

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-06-03 (Created: 2023-06-03)

# %% [markdown]
# **Description:** This notebook shows how to define a new DataFrame that only keeps columns defined in Input section.

# %% [markdown]
# **References:**
# - [Pandas - Keep columns](https://www.statology.org/pandas-keep-columns/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Setup Variables
# - `to_keep`: list of columns to keep in dataframe

# %%
to_keep = ["team", "points", "blocks"]

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create DataFrame

# %%
# create DataFrame
df = pd.DataFrame(
    {
        "team": ["A", "A", "A", "B", "B", "B"],
        "points": [11, 7, 8, 10, 13, 13],
        "assists": [5, 7, 7, 9, 12, 9],
        "rebounds": [11, 8, 10, 6, 6, 5],
    }
)
df

# %% [markdown]
# ### Create new DataFrame that only keeps defined columns
# You can't set one column that does not exists in your dataframe so we managed it in the function below.

# %%
def keep_columns(df, to_keep):
    # Check if all columns exist in dataframe
    for i, x in enumerate(to_keep):
        if not x in df.columns:
            print(
                f"🚨 Columns '{x}' does not exist in DataFrame -> removed from your list!"
            )
            to_keep.pop(i)
    df1 = df[to_keep]
    return df1

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display new DataFrame

# %%
df1 = keep_columns(df, to_keep)
df1
