# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - Set timezone
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+Set+timezone:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #timezone #snippet #operations

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-04-14)

# %% [markdown]
# **Description:** This notebook allows users to set the timezone for their Naas instance.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import needed library

# %%
import naas

# %% [markdown]
# ### Select your timezone
# [Wikipedia timezones](https://en.wikipedia.org/wiki/List_of_tz_database_time_zones)

# %%
new_timezone = "Europe/Paris"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get your current timezone

# %%
naas.get_remote_timezone()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Set your new timezone

# %%
naas.set_remote_timezone(new_timezone)
