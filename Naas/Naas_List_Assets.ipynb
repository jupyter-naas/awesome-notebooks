# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - List Assets
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+List+Assets:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #asset #snipet #operations

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-03-21)

# %% [markdown]
# **Description:** This notebook will show how to list current assets in production.

# %% [markdown]
# **References:**
# - [Naas Documentation](https://docs.naas.ai/)
# - [Naas Asset Documentation](https://docs.naas.ai/features/asset)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import naas

# %% [markdown]
# ## Model

# %% [markdown]
# ### List current Assets

# %%
assets = naas.asset.currents()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
assets
