# %% [markdown]
# <img width="10%" alt="Naas" href="https://app.naas.ai/hub/login" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Google - Get sheet data

# %% [markdown]
# <img width="20%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/l10u6f2c.png?w=800&h=400&fit=crop"/>

# %%
import naas_drivers

# %%
spreadsheet_id = "---------"
nass_drivers.gsheet.connect(spreadsheet_id)

# %%
naas_drivers.gsheet.get(sheet_name="TSLA")
