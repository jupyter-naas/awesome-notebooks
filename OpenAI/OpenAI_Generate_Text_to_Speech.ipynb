# %% [markdown]
# <img width="8%" alt="OpenAI.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OpenAI.png" style="border-radius: 15%">

# %% [markdown]
# # OpenAI - Generate Text to Speech
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OpenAI+-+Generate+Text+to+Speech:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #openai

# %% [markdown]
# **Author:** [Sriniketh Jayasendil](http://linkedin.com/in/sriniketh-jayasendil/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-02-10)

# %% [markdown]
# **Description:** This notebook focusses on using OpenAI for text-to-speech generation using [gTTS](https://pypi.org/project/gTTS/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import os
import naas

# OpenAI
try:
    import openai
except ModuleNotFoundError:
    # !pip install --user openai
    import openai

# Google Text to Speech API
try:
    from gtts import gTTS
except ModuleNotFoundError:
    # !pip install --user gTTS
    from gtts import gTTS

# %% [markdown]
# ### Setup Variables

# %%
# Inputs
openai.api_key = naas.secret.get("OPENAI_API_KEY") or "OPENAI_API_KEY"
language = 'en'
prompt = input('Enter the prompt: ')

# Outputs
speech_output = ''

# %% [markdown]
# ## Model

# %% [markdown]
# ### Establish connection with OpenAI and get the response

# %%
response = openai.Completion.create(
  model="text-davinci-003",
  prompt=prompt,
  temperature=0.7,
  max_tokens=256,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["\"\"\""]
)

speech_output = gTTS(text=response.choices[0].text, lang=language, slow=True)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save audio in `.mp3` format

# %%
speech_output.save('output.mp3')
