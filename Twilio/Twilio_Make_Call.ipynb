# %% [markdown]
# <img width="8%" alt="Twilio.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Twilio.png" style="border-radius: 15%">

# %% [markdown]
# # Twilio - Make Call
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Twilio+-+Make+Call:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #twilio #project #call #mobile

# %% [markdown]
# **Author:** [Sriniketh Jayasendil](https://www.linkedin.com/in/sriniketh-jayasendil/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-10-05)

# %% [markdown]
# **Description:** This notebook allows us to make a phone call to a verified twilio number. It also has different parameters to customize the output of the voice call.

# %% [markdown]
# ## Input

# %% [markdown]
# ## Import libraries

# %%
import time
import naas

try:
    from twilio.rest import Client
except ModuleNotFoundError:
    ! pip install twilio
    from twilio.rest import Client

# %% [markdown]
# ### Setup Twilio

# %%
account_sid = naas.secret.get(name="account_sid")  # From Twilio Console
auth_token = naas.secret.get(name="auth_token")  # From Twilio Console
from_number = naas.secret.get(name="from_number")  # From Twilio Console
to_number = naas.secret.get(
    name="to_number"
)  # Could send messages only to verified Caller ID's

# %% [markdown]
# ## Model

# %% [markdown]
# ### Connect to Twilio

# %%
client = Client(account_sid, auth_token)  # Set Client

# %% [markdown]
# ## Output

# %% [markdown]
# ### Make call

# %%
call = client.calls.create(
    url="http://demo.twilio.com/docs/voice.xml", to=to_number, from_=from_number
)

time.sleep(5)
print(call.sid)
