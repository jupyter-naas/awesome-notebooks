# %% [markdown]
# <img width="8%" alt="OpenAI.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OpenAI.png" style="border-radius: 15%">

# %% [markdown]
# # OpenAI - Brainstorm ideas
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OpenAI+-+Brainstorm+ideas:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #openai #brainstorm #ideas #ai #machinelearning #deeplearning

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-02-24)

# %% [markdown]
# **Description:** This notebook will help brainstorm ideas on a specific topic using OpenAI.

# %% [markdown]
# **References:**
# - [OpenAI](https://openai.com/)
# - [Brainstorming](https://en.wikipedia.org/wiki/Brainstorming)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import openai
except:
    # !pip install openai --user
    import openai
import naas

# %% [markdown]
# ### Setup Variables
# - `api_key`: OpenAI API key, to obtain an OpenAI API key, please refer to the [OpenAI Documentation](https://openai.com/docs/).
# - `topic`: the topic to brainstorm ideas on

# %%
# Inputs
api_key = naas.secret.get(name="OPENAI_API_KEY") or "ENTER_YOUR_OPENAI_API_KEY"
topic = "AI"
prompt = f"Brainstorm ideas on '{topic}'"

# Outputs
file_path = f"Brainstorm_ideas_{topic.replace(' ', '_')}.txt"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Send requests to OpenAI API

# %%
openai.api_key = api_key
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=prompt,
    max_tokens=100,
    temperature=0.9,
)

# %% [markdown]
# ### Get text

# %%
text = response['choices'][0]['text']
print(text)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save text to txt file

# %%
text_file = open(file_path, "w")
text_file.write(text)
text_file.close()
