# %% [markdown]
# <img width="8%" alt="Insee.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Insee.png" style="border-radius: 15%">

# %% [markdown]
# # Insee - Download PDF recap
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Insee+-+Download+PDF+recap:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #insee #pdf #snippet #url #naas #societe #opendata

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-05-04)

# %% [markdown]
# **Description:** This notebook downloads PDF summaries of data from the French National Institute of Statistics and Economic Studies (INSEE).

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import urllib

# %% [markdown]
# ### Setup Variables

# %%
# Input
SIRET = "87794XXXXXXXX"

# Output
PDF_OUTPUT = f"RECAPITULATIF_INSEE_{SIRET}.pdf"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Download PDF

# %%
def download_pdf(siret, filepath):
    url = f"https://api.avis-situation-sirene.insee.fr/identification/pdf/{siret}"
    response = urllib.request.urlopen(url)
    file = open(filepath, "wb")
    file.write(response.read())
    file.close()
    print("File saved:", filepath)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
download_pdf(SIRET, PDF_OUTPUT)
