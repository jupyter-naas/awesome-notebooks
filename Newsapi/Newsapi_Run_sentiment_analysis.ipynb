# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Newsapi - Run sentiment analysis on Bitcoin

# %%
import naas_drivers

# %%
data = naas_drivers.newsapi.get("bitcoin", fields=["image", "title", "image", "link", "description"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a2049bea8eaf> in <module>
# ----> 1 data = naas_drivers.newsapi.get("bitcoin", fields=["image", "title", "image", "link", "description"])
#
# TypeError: get() got multiple values for argument 'fields'

# %%
data
# Out:
#                                                 image  \
# 0
# 1
# 2   https://cleantechnica.com/files/2020/07/Tesla-...
# 3   https://driveteslacanada.ca/wp-content/uploads...
# 4   https://zdnet1.cbsistatic.com/hub/i/r/2020/10/...
# ..                                                ...
# 65  https://cdn.benzinga.com/files/imagecache/og_i...
# 66  https://observer.com/wp-content/uploads/sites/...
# 67  https://www.gannett-cdn.com/presto/2020/01/17/...
# 68  https://o.aolcdn.com/images/dims?resize=1200%2...
# 69
#
#                                                 title  \
# 0        Tesla sends made-in-China Model 3s to Europe
# 1   Ram is working on an electric version of its p...
# 2   Tesla Model Y From Giga Berlin Expected In Q1/...
# 3   Tesla Model Y deliveries in Europe could begin...
# 4   As Tesla full self-driving goes beta, Autopilo...
# ..                                                ...
# 65  New EPA Data Shows Tesla Excels In Electric Ve...
# 66  Tracking Elon Musk’s $56 Billion Tesla Bonus: ...
# 67  Fiat Chrysler CEO says Ram will offer electric...
# 68  Consumer Reports says Tesla Autopilot is a 'di...
# 69  Batteries Market 2020 Competitive Insights – P...
#
#                                                  logo  \
# 0   https://cityfalconproduction.blob.core.windows...
# 1   https://cityfalconproduction.blob.core.windows...
# 2   https://cityfalconproduction.blob.core.windows...
# 3   https://cityfalconproduction.blob.core.windows...
# 4   https://cityfalconproduction.blob.core.windows...
# ..                                                ...
# 65  https://cityfalconproduction.blob.core.windows...
# 66  https://cityfalconproduction.blob.core.windows...
# 67  https://cityfalconproduction.blob.core.windows...
# 68  https://cityfalconproduction.blob.core.windows...
# 69  https://cityfalconproduction.blob.core.windows...
#
#                                                  link  \
# 0   https://www.ecns.cn/video/2020-10-29/detail-ih...
# 1   https://www.engadget.com/ram-electrified-picku...
# 2   https://cleantechnica.com/2020/10/29/tesla-mod...
# 3   https://driveteslacanada.ca/model-y/tesla-mode...
# 4   https://www.zdnet.com/article/as-tesla-full-se...
# ..                                                ...
# 65  https://www.benzinga.com/tech/20/10/18098793/n...
# 66  https://observer.com/2020/10/elon-musk-tesla-p...
# 67  https://eu.freep.com/story/money/cars/chrysler...
# 68  https://www.engadget.com/tesla-autopilot-secon...
# 69  http://www.sbwire.com/press-releases/batteries...
#
#                                           description
# 0   The first batch of 7,000 Tesla Model 3s began ...
# 1   Ram is working on an electrified version of it...
# 2   It's hard to believe, but just 10 years after ...
# 3   In what seems to be a common trend as of late,...
# 4   Tesla's Autopilot loses out in the Consumer Re...
# ..                                                ...
# 65  One of the most important aspects of an electr...
# 66  Tesla CEO Elon Musk has hit four unlikely perf...
# 67  Fiat Chrysler will join the growing list of co...
# 68  Tesla's Autopilot was a 'distant second' to GM...
# 69  Harrisburg, NC -- ( SBWIRE ) -- 10/28/2020 -- ...
#
# [70 rows x 5 columns]

# %%
sentiment =  naas_drivers.sentiment_analysis.calculate(data, column_name="title")

# %%
sentiment
# Out:
#                                                 title Sentiment   Score
# 0        Tesla sends made-in-China Model 3s to Europe   Neutral  0.0000
# 1   Ram is working on an electric version of its p...  Positive  0.4215
# 2   Tesla Model Y From Giga Berlin Expected In Q1/...   Neutral  0.0000
# 3   Tesla Model Y deliveries in Europe could begin...   Neutral  0.0000
# 4   As Tesla full self-driving goes beta, Autopilo...  Positive  0.5994
# ..                                                ...       ...     ...
# 65  New EPA Data Shows Tesla Excels In Electric Ve...  Positive  0.7184
# 66  Tracking Elon Musk’s $56 Billion Tesla Bonus: ...  Positive  0.5423
# 67  Fiat Chrysler CEO says Ram will offer electric...   Neutral  0.0000
# 68  Consumer Reports says Tesla Autopilot is a 'di...   Neutral  0.0000
# 69  Batteries Market 2020 Competitive Insights – P...  Positive  0.1779
#
# [70 rows x 3 columns]
