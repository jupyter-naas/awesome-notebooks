# %% [markdown]
# <img width="8%" alt="FTP.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/FTP.png" style="border-radius: 15%">

# %% [markdown]
# # FTP - Send file
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=FTP+-+Send+file:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #ftp #file #naas_drivers #operations #snippet

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-03-03)

# %% [markdown]
# **Description:** This notebook allows users to securely transfer files to a remote server using the File Transfer Protocol (FTP).

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import ftp

# %% [markdown]
# ### Variables

# %%
path = "/path/to/file/in/ftp"
dest_path = "/path/to/file/in/ftp"
user = "my user"
passwd = "my passwd"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Connect to ftp

# %%
ftp = ftp.connect(user, passwd)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Send the data

# %%
ftp = naas_drivers.ftp.connect(user, passwd)
ftp.send(path, dest_path)
