# %% [markdown]
# <img width="8%" alt="FTP.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/FTP.png" style="border-radius: 15%">

# %% [markdown]
# # FTP - Connect
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=FTP+-+Connect:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #ftp #file #naas_drivers #operations #snippet

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-03-03)

# %% [markdown]
# **Description:** This notebook provides instructions on how to connect to an FTP server.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import ftp

# %% [markdown]
# ### Variables

# %%
user = "my user"
passwd = "my passwd"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Connect to FTP

# %%
ftp_get = ftp.connect(user, passwd, port=990, secure=True)

# %% [markdown]
# ## Output

# %%
ftp_get
