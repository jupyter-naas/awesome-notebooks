# %% [markdown]
# <img width="8%" alt="JSON.jpg" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/JSON.jpg" style="border-radius: 15%">

# %% [markdown]
# # JSON - Pretty print  data
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=JSON+-+Pretty+print++data:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #json #prettyprint #data #format #parse #string

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-07-31 (Created: 2023-07-31)

# %% [markdown]
# **Description:** This notebook will show how to pretty print JSON data.

# %% [markdown]
# **References:**
# - [JSON Pretty Print](https://www.jsonprettyprint.com/)
# - [JSON.org](https://www.json.org/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import json

# %% [markdown]
# ### Setup variables
# - `json_string`: a JSON string to be parsed

# %%
json_string = '{"name": "Florent", "age": 28, "city": "Paris"}'

# %% [markdown]
# ## Model

# %% [markdown]
# ### Parse JSON string

# %% [markdown]
# This function will parse a JSON string and display it in a readable format.

# %%
# Parse JSON string
parsed_json = json.loads(json_string)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
# Display result
print(json.dumps(parsed_json, indent=4))
