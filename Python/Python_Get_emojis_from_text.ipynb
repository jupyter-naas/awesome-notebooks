# %% [markdown]
# <img width="8%" alt="Python.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Python.png" style="border-radius: 15%">

# %% [markdown]
# # Python - Get emojis from text
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Python+-+Get+emojis+from+text:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #python #text #emoji #nlp #string #library

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-08-23 (Created: 2023-08-23)

# %% [markdown]
# **Description:** This notebook will show how to get emojis from text using `emoji` and `regex` libraries.

# %% [markdown]
# **References:**
# - [Python String - Emoji](https://www.w3schools.com/python/python_strings.asp)
# - [Python Regular Expression - Emoji](https://www.w3schools.com/python/python_regex.asp)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import emoji
except:
    # !pip install emoji==1.6.3
    import emoji
import regex

# %% [markdown]
# ### Setup variables
# - `text`: Text string to extract emojis from

# %%
text = "This is a text with emojis ✅😊😊"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get emojis from text

# %% [markdown]
# This function will extract all emojis from a text string using regular expression.

# %%
def get_emojis(text):
    emoji_list = []
    data = regex.findall(r"\X", text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI["en"] for char in word):
            emoji_list.append(word)
    return emoji_list

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
emojis = get_emojis(text)
print(emojis)
