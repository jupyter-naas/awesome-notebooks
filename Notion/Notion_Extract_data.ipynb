# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Notion - Extract data

# %% [markdown]
# <img width="20%" alt="Naas" src="https://project-management.com/wp-content/uploads/2020/01/notion-logo.png"/>

# %% [markdown]
# ## Get your token

# %% [markdown]
# To obtain the `token_v2` :
# - click right on a Notion.so logged-in (non-guest) session, then
# - "Inspect" will open a technical window
# - Go to "Applications" and in the table search for "token_v2" simply copy the value.

# %% [markdown]
# ## Use the driver to retrieve data

# %%
import naas_drivers

token = "701c35f542debe676e497f7c062c223b7a5c058a925023173ea57c58cc029606749210bbc37ee31f4800a3ee713089585cd84c5ea382ba1df6e9dbcfe91090ee096d3ae67d7ce0d980f15611f3f0"
url = "https://www.notion.so/cashstory/2784fd3635654d20bb9d8e0e28956bb6?v=53e00d2999aa4470b5c1026f2e93e0e4"
collection = naas_drivers.notion.connect(token=token).get_collection(url)
collection
# Out:
#     likes    views  comments                 created  \
# 0    30.0   2371.0      16.0 2021-01-21 08:38:23.854
# 1    20.0   3081.0       7.0 2021-01-21 15:04:00.000
# 2    26.0   6647.0      12.0 2021-01-21 16:29:00.000
# 3    11.0   1633.0       0.0 2021-01-21 16:31:00.000
# 4   113.0      0.0      54.0 2021-01-21 16:41:00.000
# 5    21.0   1427.0       8.0 2021-01-21 16:35:00.000
# 6    65.0    842.0      29.0 2021-01-21 15:03:00.000
# 7    30.0   2145.0       6.0 2021-01-21 08:38:23.854
# 8    90.0   5531.0      27.0 2021-01-21 17:55:00.000
# 9    48.0   2857.0       4.0 2021-01-21 08:38:23.854
# 10   56.0   3593.0      26.0 2021-01-21 09:04:00.000
# 11   64.0   3987.0       6.0 2021-01-21 14:44:00.000
# 12   83.0  29720.0       8.0 2021-01-21 17:57:00.000
# 13  245.0  77491.0      25.0 2021-01-21 17:59:00.000
# 14   26.0   1148.0       1.0 2021-01-21 16:54:00.000
# 15   64.0  24524.0      13.0 2021-01-21 18:00:00.000
# 16   24.0   1821.0      10.0 2021-01-21 18:00:00.000
# 17   50.0   7904.0       4.0 2021-01-21 16:56:00.000
# 18   52.0   1708.0       8.0 2021-01-21 18:07:00.000
# 19    NaN      NaN       NaN 2021-01-21 18:08:00.000
# 20  519.0   8563.0     109.0 2021-01-21 16:24:00.000
# 21    NaN      NaN       NaN 2021-02-18 13:14:43.217
# 22    NaN      NaN       NaN 2021-02-18 10:22:40.791
# 23    NaN      NaN       NaN 2021-02-18 10:15:28.165
# 24    NaN      NaN       NaN 2021-02-18 08:46:11.641
#
#                                             post_date  \
# 0   <notion.collection.NotionDate object at 0x7f42...
# 1   <notion.collection.NotionDate object at 0x7f42...
# 2   <notion.collection.NotionDate object at 0x7f42...
# 3   <notion.collection.NotionDate object at 0x7f42...
# 4   <notion.collection.NotionDate object at 0x7f42...
# 5   <notion.collection.NotionDate object at 0x7f42...
# 6   <notion.collection.NotionDate object at 0x7f42...
# 7   <notion.collection.NotionDate object at 0x7f42...
# 8   <notion.collection.NotionDate object at 0x7f42...
# 9   <notion.collection.NotionDate object at 0x7f42...
# 10  <notion.collection.NotionDate object at 0x7f42...
# 11  <notion.collection.NotionDate object at 0x7f42...
# 12  <notion.collection.NotionDate object at 0x7f42...
# 13  <notion.collection.NotionDate object at 0x7f42...
# 14  <notion.collection.NotionDate object at 0x7f42...
# 15  <notion.collection.NotionDate object at 0x7f42...
# 16  <notion.collection.NotionDate object at 0x7f42...
# 17  <notion.collection.NotionDate object at 0x7f42...
# 18  <notion.collection.NotionDate object at 0x7f42...
# 19  <notion.collection.NotionDate object at 0x7f42...
# 20  <notion.collection.NotionDate object at 0x7f42...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
#
#                                              property  \
# 0   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 1   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 2   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 3   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 4   https://www.linkedin.com/posts/martindonadieu_...
# 5   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 6   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 7   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 8   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 9   https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 10  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 11  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 12  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 13  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 14  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 15  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 16  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 17  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 18  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 19  https://www.linkedin.com/feed/update/urn:li:ac...
# 20  https://www.linkedin.com/posts/j%C3%A9r%C3%A9m...
# 21
# 22
# 23
# 24
#
#                                                sender  platform  \
# 0   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 1   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 2   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 3   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 4   [id='ac3a3d77-b62a-41c3-a277-2b0b14ce302b', em...  LinkedIn
# 5   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 6   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 7   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 8   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 9   [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 10  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 11  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 12  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 13  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 14  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 15  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 16  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 17  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 18  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 19  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 20  [id='6e3bab71-beeb-484b-af99-ea30fdef4773', em...  LinkedIn
# 21                                                 []      None
# 22                                                 []      None
# 23                                                 []      None
# 24                                                 []      None
#
#                                                  name
# 0   How are you today? To start the year, we have ...
# 1   Alerte enlèvement 🚨 Jean Castex et notre gouve...
# 2   🛑 Il faut en finir avec le suivi à l'ancienne ...
# 3   Hey #linkedinfamily, "Cash is king but data is...
# 4   🤯 Ma mère a toujours dit que j’étais un panier...
# 5   « 2020 was not the year to get everything you ...
# 6   🚒🔥 Data, automation & AI should NOT be only in...
# 7   ⏰ Are you dreaming of using robots to automate...
# 8   Professionals all over the world are spending ...
# 9   🙉 You don’t need to become a data scientist to...
# 10  ⚠️ 💌 Save 2020 by sending awesome season's gre...
# 11  Spreadsheets are NOT dead: hate it 😡 or love i...
# 12                     Cash is king but data is Gold!
# 13  Here we go, this is my first video as a Youtub...
# 14  Et vous, vous faites quoi pendant que les mach...
# 15  "If you care for your data, your data will tak...
# 16  It's the beginning of a new era for data access 🔥
# 17  ℹ️ Si vous êtes intéressé par les sujets data,...
# 18  🚀 Yesterday we launched **[Naas.ai](http://naa...
# 19       ⭐️ Jupyter is the new Excel = true or false?
# 20  ❤️ The businesses that embrace automation will...
# 21                              This is great news !!
# 22                                 My new social post
# 23                              Add data for the demo
# 24                                     Just some data

# %% [markdown]
# ## Save data as CSV file

# %%
collection.to_csv('data.csv')
