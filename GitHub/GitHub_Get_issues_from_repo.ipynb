# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # GitHub - Get issues from repo
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/GitHub/GitHub_Get_issues_from_repo.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #github #repos #issues #operations #analytics #dataframe #html #plotly

# %% [markdown]
# **Author:** [Sanjeet Attili](https://www.linkedin.com/in/sanjeet-attili-760bab190/)

# %% [markdown]
# The objective of the notebook is to maintain a track of issues that are open in a particular repository

# %% [markdown]
# ## Input

# %% [markdown]
# ### Imports

# %%
import requests
import pandas as pd
from urllib.parse import urlencode
from datetime import datetime
import plotly.express as px
from naas_drivers import github

# %% [markdown]
# ### Variables

# %%
# Github repository url
REPO_URL = "https://github.com/jupyter-naas/awesome-notebooks"

# Github token
GITHUB_TOKEN = "ghp_COJiJEU4cQR4rjslUxxxxxxxxxxxxxxxx"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get issues from repo

# %%
df_issues = github.connect(GITHUB_TOKEN).repos.get_issues(REPO_URL)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print("Nb issues:", len(df_issues))
df_issues.head(15)
# Out:
# Nb issues: 58
#                                     link_to_the_issue  issue_number  \
# 0   https://github.com/jupyter-naas/awesome-notebo...           435
# 1   https://github.com/jupyter-naas/awesome-notebo...           434
# 2   https://github.com/jupyter-naas/awesome-notebo...           433
# 3   https://github.com/jupyter-naas/awesome-notebo...           432
# 4   https://github.com/jupyter-naas/awesome-notebo...           431
# 5   https://github.com/jupyter-naas/awesome-notebo...           430
# 6   https://github.com/jupyter-naas/awesome-notebo...           429
# 7   https://github.com/jupyter-naas/awesome-notebo...           428
# 8   https://github.com/jupyter-naas/awesome-notebo...           427
# 9   https://github.com/jupyter-naas/awesome-notebo...           426
# 10  https://github.com/jupyter-naas/awesome-notebo...           425
# 11  https://github.com/jupyter-naas/awesome-notebo...           424
# 12  https://github.com/jupyter-naas/awesome-notebo...           423
# 13  https://github.com/jupyter-naas/awesome-notebo...           422
# 14  https://github.com/jupyter-naas/awesome-notebo...           421
#
#                                           issue_title issue_state    issue_id  \
# 0                             Github - drivers update        open  1190833290
# 1                    Python - Download image from URL        open  1188259864
# 2        Typeform - Add new Slack user from Typeform         open  1188235995
# 3   GitHub - Add new Github issues as page in Noti...        open  1188235463
# 4   Typeform - Log new Typeform entries in Notion ...        open  1188131037
# 5   Notion - Send Slack messages for new Notion da...        open  1188130566
# 6   Notion - Create Github issues from new items i...        open  1188129935
# 7   LinkedIn + Notion - Sync Feed with Content Cal...        open  1188055919
# 8               LinkedIn - Follow Total Content Views        open  1186449426
# 9       LinkedIn - Follow Number of Content Published        open  1186448952
# 10                     LeFigaro Immobilier - Analysis        open  1186413796
# 11                 CSV - Add new Slack user from CSV         open  1186282135
# 12  LinkedIn - Accept all LinkedIn invitation and ...        open  1186281796
# 13  Notion - Generate Google Sheets rows for new i...        open  1186281427
# 14  Slack - Follow number of Slack users in workspace        open  1185216447
#
#         issue_labels issue_assignees  comments_till_date last_created_date  \
# 0   good first issue       SanjuEpic                   1        2022-04-03
# 1               None      FlorentLvr                   0        2022-03-31
# 2               None            None                   1        2022-03-31
# 3               None            None                   1        2022-03-31
# 4               None            None                   1        2022-03-31
# 5               None            None                   1        2022-03-31
# 6               None            None                   1        2022-03-31
# 7        enhancement      FlorentLvr                   0        2022-03-31
# 8   good first issue            None                   1        2022-03-30
# 9   good first issue            None                   1        2022-03-30
# 10              None            None                   0        2022-03-30
# 11       enhancement        jravenel                   2        2022-03-30
# 12       enhancement      FlorentLvr                   1        2022-03-30
# 13  good first issue            None                   1        2022-03-30
# 14       enhancement       SanjuEpic                   1        2022-03-29
#
#    last_created_time last_updated_date last_updated_time  \
# 0           06:29:01        2022-04-03          06:32:47
# 1           15:24:44        2022-03-31          15:25:07
# 2           15:07:27        2022-03-31          15:07:41
# 3           15:07:02        2022-03-31          15:07:22
# 4           14:00:27        2022-03-31          14:00:44
# 5           14:00:06        2022-03-31          14:00:22
# 6           13:59:39        2022-03-31          14:00:00
# 7           13:10:10        2022-03-31          13:13:09
# 8           13:17:36        2022-03-31          13:08:22
# 9           13:17:16        2022-03-31          13:08:50
# 10          12:50:55        2022-03-30          12:53:08
# 11          10:57:58        2022-03-31          15:35:05
# 12          10:57:39        2022-03-31          13:09:06
# 13          10:57:17        2022-03-31          13:09:34
# 14          17:53:44        2022-03-30          08:43:05
#
#                                              comments linked_pr_state  \
# 0   ['All the required drivers have been updated i...            None
# 1                                         No comments            None
# 2   ['\n🚀 Branch and template have been created an...            None
# 3   ['\n🚀 Branch and template have been created an...            None
# 4   ['\n🚀 Branch and template have been created an...            None
# 5   ['\n🚀 Branch and template have been created an...            None
# 6   ['\n🚀 Branch and template have been created an...            None
# 7                                         No comments            None
# 8   ['\n🚀 Branch and template have been created an...            None
# 9   ['\n🚀 Branch and template have been created an...            None
# 10                                        No comments            None
# 11  ['\n🚀 Branch and template have been created an...            None
# 12  ['\n🚀 Branch and template have been created an...            None
# 13  ['\n🚀 Branch and template have been created an...            None
# 14  ['\n🚀 Branch and template have been created an...            None
#
#    PR_activity
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9         None
# 10        None
# 11        None
# 12        None
# 13        None
# 14        None
