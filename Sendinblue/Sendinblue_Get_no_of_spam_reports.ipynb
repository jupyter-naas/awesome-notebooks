# %% [markdown]
# <img width="8%" alt="Sendinblue.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Sendinblue.png" style="border-radius: 15%">

# %% [markdown]
# # Sendinblue - Get no of spam reports
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Sendinblue+-+Get+no+of+spam+reports:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #sendinblue #emails #campaign #spam #emailcampaigns #marketing #operations #snippet

# %% [markdown]
# **Author:** [Minura Punchihewa](https://www.linkedin.com/in/minurapunchihewa/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-07-09)

# %% [markdown]
# **Description:** This notebook provides a way to track the number of spam reports received through Sendinblue.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import requests
import json
import naas

# %% [markdown]
# ### Setup Sendinblue
# [How to get your Sendinblue API KEY?](https://developers.sendinblue.com/docs#:~:text=Generate%20your%20API%20key%20to,key%20%60api%2Dkey%60.)

# %%
SENDINBLUE_API_KEY = (
    naas.secret.get(name="SENDINBLUE_API_KEY") or "ENTER_YOUR_SENDINBLUE_API_KEY"
)

# %% [markdown]
# ### Variable

# %%
campaign_name = "Minura's Campaign"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Send request to Sendinblue API

# %%
response = requests.get(
    "https://api.sendinblue.com/v3/emailCampaigns",
    headers={"Accept": "application/json", "api-key": SENDINBLUE_API_KEY},
)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Get the campaign

# %%
campaign = next(
    item
    for item in json.loads(response.text)["campaigns"]
    if item["name"] == campaign_name
)

# %% [markdown]
# ### Get the number of complaints (spam reports)

# %%
campaign["statistics"]["globalStats"]["complaints"]
