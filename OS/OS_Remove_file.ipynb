# %% [markdown]
# <img width="8%" alt="OS.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OS.png" style="border-radius: 15%">

# %% [markdown]
# # OS - Remove file
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OS+-+Remove+file:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #os #python #remove #file #system #library #snippet #operations

# %% [markdown]
# **Author:** [Florent Ravenel](http://linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-06-06 (Created: 2023-06-06)

# %% [markdown]
# **Description:** This notebook will show how to remove file from system using os library.

# %% [markdown]
# **References:**
# - [os library documentation](https://docs.python.org/3/library/os.html)
# - [os.remove() documentation](https://docs.python.org/3/library/os.html#os.remove)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import os

# %% [markdown]
# ### Setup Variables
# - `file_path`: path of the file to be removed

# %%
file_path = "untitled.txt"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Remove file
# This function will remove the file from the system.

# %%
os.remove(file_path)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print(f"The file '{file_path}' has been removed from the system.")
