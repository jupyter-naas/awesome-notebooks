# %% [markdown]
# # Plotly - Candlestick

# %% [markdown]
# **Tags:** #plotly #chart #candlestick #group #dataviz

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
import naas
import naas_drivers
import plotly.graph_objects as go
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### Setup dataset

# %%
date_from = -360 # Date can be number or date or today
date_to = "today"
df = naas_drivers.yahoofinance.get("TSLA", date_from=date_from, date_to=date_to)
df
# Out:
# getted data for TSLA https://query1.finance.yahoo.com/v7/finance/download/TSLA?period1=1603650824&period2=1634751224&interval=1d&events=history
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-10-26  411.630005  425.760010  410.000000  420.279999  420.279999
# 1   2020-10-27  423.760010  430.500000  420.100006  424.679993  424.679993
# 2   2020-10-28  416.480011  418.600006  406.000000  406.019989  406.019989
# 3   2020-10-29  409.959991  418.059998  406.459991  410.829987  410.829987
# 4   2020-10-30  406.899994  407.589996  379.109985  388.040009  388.040009
# ..         ...         ...         ...         ...         ...         ...
# 244 2021-10-14  815.489990  820.250000  813.349976  818.320007  818.320007
# 245 2021-10-15  823.739990  843.210022  822.349976  843.030029  843.030029
# 246 2021-10-18  851.789978  875.260010  851.469971  870.109985  870.109985
# 247 2021-10-19  877.530029  877.950012  862.510010  864.270020  864.270020
# 248 2021-10-20  865.349976  869.479980  857.410095  863.924072  863.924072
#
#        Volume Company
# 0    28239200    TSLA
# 1    22686500    TSLA
# 2    25451400    TSLA
# 3    22655300    TSLA
# 4    42511300    TSLA
# ..        ...     ...
# 244  12247200    TSLA
# 245  18818000    TSLA
# 246  24207200    TSLA
# 247  17322900    TSLA
# 248   7400636    TSLA
#
# [249 rows x 8 columns]

# %% [markdown]
# ## Model

# %% [markdown]
# ### Setup graph

# %%
Title = "Candlestick"

# %%
fig = go.Figure()

config = {'displayModeBar': False}

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.update_layout(
    title=Title ,
    plot_bgcolor="#ffffff",
    #width=800,
    height=600,
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Price in $',
        titlefont_size=16,
        tickfont_size=14,
    )
)
fig.show(config=config)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Export in PNG and HTML

# %%
naas_drivers.plotly.export(fig, f"{Title}.png", css=None)
naas_drivers.plotly.export(fig, f"{Title}.html", css=None)
# Out:
# Saved as Candlestick.png
# Saved as Candlestick.html

# %% [markdown]
# ### Generate shareable assets

# %%
link_image = naas.asset.add(f"{Title}.png")
link_html = naas.asset.add(f"{Title}.html", {"inline":True})
# Out:
# 👌 Well done! Your Assets has been sent to production.
# Button(button_style='primary', description='Copy URL', style=ButtonStyle())
# Output()
# PS: to remove the "Assets" feature, just replace .add by .delete
# 👌 Well done! Your Assets has been sent to production.
# Button(button_style='primary', description='Copy URL', style=ButtonStyle())
# Output()
# PS: to remove the "Assets" feature, just replace .add by .delete
