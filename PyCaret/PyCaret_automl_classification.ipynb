# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # PyCaret - AutoML Classification
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/PyCaret/PyCaret_automl_classification.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #automl #pandas #snippet #classification #dataframe #visualize #pycaret #operations

# %% [markdown]
# **Author:** [Minura Punchihewa](https://www.linkedin.com/in/minurapunchihewa/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
try:
    from pycaret.classification import setup, compare_models, evaluate_model, predict_model, finalize_model, \
     save_model, load_model, create_docker
except:
    ! pip install --user pycaret
    from pycaret.classification import setup, compare_models, evaluate_model, predict_model, finalize_model, \
     save_model, load_model, create_docker
# Out:
# Collecting pycaret
#   Downloading pycaret-2.3.10-py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.2/320.2 kB 5.9 MB/s eta 0:00:0000:01
# Collecting scipy<=1.5.4
#   Downloading scipy-1.5.4-cp39-cp39-manylinux1_x86_64.whl (25.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 31.9 MB/s eta 0:00:0000:0100:01
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 1.7 MB/s eta 0:00:00ta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting kmodes>=0.10.1
#   Downloading kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Collecting numba<0.55
#   Downloading numba-0.54.1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 32.6 MB/s eta 0:00:00:00:01
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.0.1)
# Collecting lightgbm>=2.3.1
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.5 MB/s eta 0:00:00:00:01
# Collecting pyyaml<6.0.0
#   Downloading PyYAML-5.4.1-cp39-cp39-manylinux1_x86_64.whl (630 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.1/630.1 kB 10.5 MB/s eta 0:00:0000:01
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.2 MB/s eta 0:00:00:00:01
# Collecting pyod
#   Downloading pyod-1.0.2.tar.gz (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 2.4 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting mlflow
#   Downloading mlflow-1.26.1-py3-none-any.whl (17.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.8/17.8 MB 36.8 MB/s eta 0:00:0000:0100:01
# Collecting Boruta
#   Downloading Boruta-0.3-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 957.9 kB/s eta 0:00:00a 0:00:01
# Collecting gensim<4.0.0
#   Downloading gensim-3.8.3.tar.gz (23.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 20.0 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.4-py3-none-any.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.2/274.2 kB 5.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.9/site-packages (from pycaret) (3.4.1)
# Collecting wordcloud
#   Using cached wordcloud-1.8.1-cp39-cp39-manylinux1_x86_64.whl (363 kB)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.9/site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: plotly>=4.4.1 in /home/ftp/.local/lib/python3.9/site-packages (from pycaret) (5.7.0)
# Collecting pandas-profiling>=2.8.0
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.6/262.6 kB 5.2 MB/s eta 0:00:0000:01
# Collecting scikit-learn==0.23.2
#   Downloading scikit-learn-0.23.2.tar.gz (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 36.2 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: IPython in /opt/conda/lib/python3.9/site-packages (from pycaret) (7.23.1)
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 23.0 MB/s eta 0:00:00:00:01
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.2 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from pycaret) (1.2.4)
# Collecting spacy<2.4.0
#   Downloading spacy-2.3.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 32.0 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: seaborn in /home/ftp/.local/lib/python3.9/site-packages (from pycaret) (0.11.2)
# Collecting imbalanced-learn==0.7.0
#   Downloading imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.1/167.1 kB 3.2 MB/s eta 0:00:0000:01
# Collecting cufflinks>=0.17.0
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.7/81.7 kB 1.7 MB/s eta 0:00:00ta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.8/636.8 kB 11.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy>=1.13.3 in /home/ftp/.local/lib/python3.9/site-packages (from imbalanced-learn==0.7.0->pycaret) (1.19.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from scikit-learn==0.23.2->pycaret) (3.1.0)
# Requirement already satisfied: six>=1.9.0 in /home/ftp/.local/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret) (1.15.0)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in /opt/conda/lib/python3.9/site-packages (from cufflinks>=0.17.0->pycaret) (49.6.0.post20210108)
# Collecting smart_open>=1.8.1
#   Downloading smart_open-6.0.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 1.2 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (5.0.9)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (0.1.2)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (2.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (3.0.19)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (5.0.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (0.18.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (4.8.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.9/site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (3.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (5.5.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from ipywidgets->pycaret) (5.1.3)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.9/site-packages (from lightgbm>=2.3.1->pycaret) (0.36.2)
# Collecting mlxtend>=0.17.0
#   Downloading mlxtend-0.19.0-py2.py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.3 MB/s eta 0:00:00:00:01
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.9/site-packages (from matplotlib->pycaret) (2.4.7)
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp39-cp39-manylinux2014_x86_64.whl (26.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.3/26.3 MB 33.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas->pycaret) (2021.1)
# Requirement already satisfied: tqdm>=4.48.2 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (4.62.0)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (709 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.4/709.4 kB 11.7 MB/s eta 0:00:0000:01
# Collecting tangled-up-in-unicode==0.2.0
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 35.4 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: missingno>=0.4.2 in /home/ftp/.local/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (0.4.2)
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.24.0 in /home/ftp/.local/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (2.25.1)
# Collecting joblib
#   Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.4/102.4 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Collecting multimethod>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: pydantic>=1.8.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (1.8.2)
# Collecting markupsafe~=2.1.1
#   Downloading MarkupSafe-2.1.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/conda/lib/python3.9/site-packages (from pandas-profiling>=2.8.0->pycaret) (3.0.3)
# Requirement already satisfied: networkx>=2.4 in /home/ftp/.local/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (2.7.1)
# Requirement already satisfied: attrs>=19.3.0 in /opt/conda/lib/python3.9/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (21.2.0)
# Collecting imagehash
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.6/812.6 kB 11.5 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.9/site-packages (from plotly>=4.4.1->pycaret) (8.0.1)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp39-cp39-manylinux2014_x86_64.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.2/184.2 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.7-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting wasabi<1.1.0,>=0.4.0
#   Using cached wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 41.1 MB/s eta 0:00:0000:010:01
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.6-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp39-cp39-manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.7 MB/s eta 0:00:0000:01
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Collecting yellowbrick>=1.0.1
#   Downloading yellowbrick-1.3.post1-py3-none-any.whl (271 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 271.4/271.4 kB 5.7 MB/s eta 0:00:0000:01
# Collecting cloudpickle
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.17.0.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 1.6 MB/s eta 0:00:00ta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 1.5 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (0.3)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (1.4.22)
# Requirement already satisfied: Flask in /home/ftp/.local/lib/python3.9/site-packages (from mlflow->pycaret) (2.1.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (21.0)
# Requirement already satisfied: gitpython>=2.1.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (3.1.14)
# Collecting sqlparse>=0.3.1
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 850.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (4.6.3)
# Requirement already satisfied: protobuf>=3.12.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (4.21.1)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.20.2-py3-none-any.whl (18 kB)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.2/146.2 kB 3.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (8.1.3)
# Requirement already satisfied: alembic in /opt/conda/lib/python3.9/site-packages (from mlflow->pycaret) (1.6.5)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.9/site-packages (from nltk->pycaret) (2022.6.2)
# Collecting numexpr
#   Downloading numexpr-2.8.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.5/380.5 kB 7.8 MB/s eta 0:00:0000:01
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting funcy
#   Downloading funcy-1.17-py2.py3-none-any.whl (33 kB)
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.3.0.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.1 MB/s eta 0:00:00:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading pyLDAvis-3.2.2.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 22.6 MB/s eta 0:00:00:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /home/ftp/.local/lib/python3.9/site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.9/site-packages (from pyod->pycaret) (0.12.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.7.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18
pycaret
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.6.3
#     Uninstalling scipy-1.6.3:
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: 'INSTALLER'
# Consider using the `--user` option or check the permissions.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ad81b9c4642d> in <module>
#       2 try:
# ----> 3     from pycaret.classification import setup, compare_models, evaluate_model, predict_model, finalize_model, \
#       4      save_model, load_model, create_docker
#
# ModuleNotFoundError: No module named 'pycaret'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ad81b9c4642d> in <module>
#       5 except:
#       6     get_ipython().system(' pip install pycaret')
# ----> 7     from pycaret.classification import setup, compare_models, evaluate_model, predict_model, finalize_model, \
#       8      save_model, load_model, create_docker
#       9
#
# ModuleNotFoundError: No module named 'pycaret'

# %% [markdown]
# ### Variables

# %%
csv_path = "https://raw.githubusercontent.com/MinuraPunchihewa/pycaret-automl/main/data/iris.csv"
target_column = 'variety'

# %% [markdown]
# ## Model

# %% [markdown]
# ### Read the CSV from path

# %%
df = pd.read_csv(csv_path)

# %% [markdown]
# ### View a sample of the data

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ### Setup the dataset

# %%
# must be called before executing any other function
# can configure many types of transformation operations
# by default Missing Value Imputation, One-Hot Encoding and Train-Test Split operations will be performed
# press enter to continue
grid = setup(data=df, target=target_column)
# Out:
# <style type="text/css">
# #T_6928b_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6928b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6928b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6928b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6928b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6928b_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_6928b_row0_col1" class="data row0 col1" >7445</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6928b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6928b_row1_col1" class="data row1 col1" >variety</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6928b_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_6928b_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6928b_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_6928b_row3_col1" class="data row3 col1" >Setosa: 0, Versicolor: 1, Virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6928b_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_6928b_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6928b_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_6928b_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6928b_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_6928b_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6928b_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_6928b_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6928b_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_6928b_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6928b_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_6928b_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6928b_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_6928b_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6928b_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_6928b_row11_col1" class="data row11 col1" >(104, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6928b_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_6928b_row12_col1" class="data row12 col1" >(46, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6928b_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_6928b_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6928b_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_6928b_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6928b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_6928b_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6928b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_6928b_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6928b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_6928b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6928b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_6928b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6928b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_6928b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6928b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_6928b_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_6928b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_6928b_row21_col1" class="data row21 col1" >c299</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_6928b_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_6928b_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_6928b_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_6928b_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_6928b_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_6928b_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_6928b_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_6928b_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_6928b_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_6928b_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_6928b_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_6928b_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_6928b_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_6928b_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_6928b_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_6928b_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6928b_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_6928b_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <t

# %% [markdown]
# ### Train and compare all supported models

# %%
# uses cross-validation
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_34bb4 th {
#   text-align: left;
# }
# #T_34bb4_row0_col0, #T_34bb4_row0_col2, #T_34bb4_row1_col0, #T_34bb4_row1_col1, #T_34bb4_row1_col2, #T_34bb4_row1_col3, #T_34bb4_row1_col4, #T_34bb4_row1_col5, #T_34bb4_row1_col6, #T_34bb4_row1_col7, #T_34bb4_row2_col0, #T_34bb4_row2_col1, #T_34bb4_row2_col2, #T_34bb4_row2_col3, #T_34bb4_row2_col4, #T_34bb4_row2_col5, #T_34bb4_row2_col6, #T_34bb4_row2_col7, #T_34bb4_row3_col0, #T_34bb4_row3_col1, #T_34bb4_row3_col3, #T_34bb4_row3_col4, #T_34bb4_row3_col5, #T_34bb4_row3_col6, #T_34bb4_row3_col7, #T_34bb4_row4_col0, #T_34bb4_row4_col1, #T_34bb4_row4_col3, #T_34bb4_row4_col4, #T_34bb4_row4_col5, #T_34bb4_row4_col6, #T_34bb4_row4
row0_col8" class="data row0 col8" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_34bb4_level0_row1" class="row_heading level0 row1" >nb</th>
#       <td id="T_34bb4_row1_col0" class="data row1 col0" >Naive Bayes</td>
#       <td id="T_34bb4_row1_col1" class="data row1 col1" >0.9727</td>
#       <td id="T_34bb4_row1_col2" class="data row1 col2" >0.9976</td>
#       <td id="T_34bb4_row1_col3" class="data row1 col3" >0.9722</td>
#       <td id="T_34bb4_row1_col4" class="data row1 col4" >0.9791</td>
#       <td id="T_34bb4_row1_col5" class="data row1 col5" >0.9723</td>
#       <td id="T_34bb4_row1_col6" class="data row1 col6" >0.9589</td>
#       <td id="T_34bb4_row1_col7" class="data row1 col7" >0.9622</td>
#       <td id="T_34bb4_row1_col8" class="data row1 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_34bb4_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_34bb4_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_34bb4_row2_col1" class="data row2 col1" >0.9718</td>
#       <td id="T_34bb4_row2_col2" class="data row2 col2" >0.9976</td>
#       <td id="T_34bb4_row2_col3" class="data row2 col3" >0.9694</td>
#       <td id="T_34bb4_row2_col4" class="data row2 col4" >0.9780</td>
#       <td id="T_34bb4_row2_col5" class="data row2 col5" >0.9710</td>
#       <td id="T_34bb4_row2_col6" class="data row2 col6" >0.9572</td>
#       <td id="T_34bb4_row2_col7" class="data row2 col7" >0.9608</td>
#       <td id="T_34bb4_row2_col8" class="data row2 col8" >0.3370</td>
#     </tr>
#     <tr>
#       <th id="T_34bb4_level0_row3" class="row_heading level0 row3" >qda</th>
#       <td id="T_34bb4_row3_col0" class="data row3 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_34bb4_row3_col1" class="data row3 col1" >0.9718</td>
#       <td id="T_34bb4_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_34bb4_row3_col3" class="data row3 col3" >0.9722</td>
#       <td id="T_34bb4_row3_col4" class="data row3 col4" >0.9784</td>
#       <td id="T_34bb4_row3_col5" class="data row3 col5" >0.9714</td>
#       <td id="T_34bb4_row3_col6" class="data row3 col6" >0.9576</td>
#       <td id="T_34bb4_row3_col7" class="data row3 col7" >0.9611</td>
#       <td id="T_34bb4_row3_col8" class="data row3 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_34bb4_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_34bb4_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_34bb4_row4_col1" class="data row4 col1" >0.9718</td>
#       <td id="T_34bb4_row4_col2" class="data row4 col2" >1.0000</td>
#       <td id="T_34bb4_row4_col3" class="data row4 col3" >0.9722</td>
#       <td id="T_34bb4_row4_col4" class="data row4 col4" >0.9784</td>
#       <td id="T_34bb4_row4_col5" class="data row4 col5" >0.9714</td>
#       <td id="T_34bb4_row4_col6" class="data row4 col6" >0.9576</td>
#       <td id="T_34bb4_row4_col7" class="data row4 col7" >0.9611</td>
#       <td id="T_34bb4_row4_col8" class="data row4 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_34bb4_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_34bb4_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_34bb4_row5_col1" class="data row5 col1" >0.9718</td>
#       <td id="T_34bb4_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_34bb4_row5_col3" class="data row5 col3" >0.9722</td>
#       <td id="T_34bb4_row5_col4" class="data row5 col4" >0.9784</td>
#       <td id="T_34bb4_row5_col5" class="data row5 col5" >0.9714</td>
#       <td id="T_34bb4_row5_col6" class="data row5 col6" >0.9576</td>
#       <td id="T_34bb4_row5_col7" class="data row5 col7" >0.9611</td>
#       <td id="T_34bb4_

# %% [markdown]
# ### Report the best model

# %%
print(best_model)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# ### Evaluate the model using a number of different plots

# %%
# click on the different plot types to exlpore
# some plots may not work depending on the data and the model
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Make predictions on new data

# %%
# data should be a DataFrame without label
# predict_model(best_model, new_data)

# %% [markdown]
# ### Finalize model

# %%
# trains the model on the entire dataset including the hold-out set
# does not change any parameter of the model
final_model = finalize_model(best_model)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save model as a pickle file

# %%
save_model(final_model, 'classification_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='variety',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                  ('fix_perfect', Remove_100(target='variety')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'), ('fix_multi', 'passthrough'),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   KNeighborsClassifier(algorithm='auto', leaf_size=30,
#                                        metric='minkowski', metric_params=None,
#                                        n_jobs=-1, n_neighbors=5, p=2,
#                                        weights='uniform')]],
#           verbose=False),
#  'classification_model.pkl')

# %% [markdown]
# ### Load saved model from pickle file

# %%
model = load_model('classification_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ### Create Dockerfile for model

# %%
# also creates a requirements.txt file for dependencies
create_docker('classification_model')
# Out:
# Writing requirements.txt
# Writing Dockerfile
# Dockerfile and requirements.txt successfully created.
# To build image you have to run --> !docker image build -f "Dockerfile" -t IMAGE_NAME:IMAGE_TAG .
