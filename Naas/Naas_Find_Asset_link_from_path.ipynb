# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - Find Asset link from path
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+Find+Asset+link+from+path:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #asset #path #link #find #python

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-05-04 (Created: 2023-05-04)

# %% [markdown]
# **Description:** This notebook will help you find the asset link generated with naas from a given file path.

# %% [markdown]
# **References:**
# - [Naas Documentation](https://docs.naas.ai/)
# - [Naas Asset Documentation](https://docs.naas.ai/features/asset)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import naas

# %% [markdown]
# ### Setup Variables
# - `file_path`: File path in naas

# %%
file_path = "."

# %% [markdown]
# ## Model

# %% [markdown]
# ### Find asset link from path

# %%
def find_naas_asset_link(file_path):
    if not file_path.startswith("/home/ftp/"):
        file_path = f"/home/ftp/{file_path}"
    asset_link = naas.asset.find(file_path)
    if asset_link:
        print("✅ Asset link found:")
    return asset_link

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
asset_link = find_naas_asset_link(file_path)
print(asset_link)
