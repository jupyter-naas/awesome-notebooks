# %% [markdown]
# <img width="8%" alt="Naas" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # PDF - Extract Text from file
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=PDF+-+Extract+Text+from+file:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #pdf #extract #snippet #operations #text

# %% [markdown]
# **Author:** [Minura Punchihewa](https://www.linkedin.com/in/minurapunchihewa/)

# %% [markdown]
# **Last update:** 2023-07-04 (Created: 2022-10-03)

# %% [markdown]
# **Description:** This notebook extracts text from a PDF file in local or an URL.

# %% [markdown]
# **References:**
# - [PyPI - PyPDF2](https://pypi.org/project/PyPDF2/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import io
import requests
from urllib.parse import urlparse
import urllib
try:
    from PyPDF2 import PdfReader
except:
    # !pip install PyPDF2
    from PyPDF2 import PdfReader

# %% [markdown]
# ### Setup variables
# - `file_path`: This variable represents the file path of the PDF file you want to extract text from.

# %%
file_path = "https://slicedinvoices.com/pdf/wordpress-pdf-invoice-plugin-sample.pdf"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Download PDF
# Download PDF if it's coming from an URL.

# %%
def is_url(url):
    try:
        result = urlparse(url)
        return all([result.scheme, result.netloc])
    except ValueError:
        return False

def download_pdf(url):
    # Init
    if not is_url(url):
        return url
    file_path = url.split('/')[-1]
    
    # Get PDF
    response = urllib.request.urlopen(url)
    
    # Save PDF
    file = open(file_path, "wb")
    file.write(response.read())
    file.close()
    print("PDF saved in local:", file_path)
    return file_path
    
file_path = download_pdf(file_path)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Read PDF file and extract text

# %%
text = ""
with open(file_path, 'rb') as file:
    reader = PdfReader(file)
    num_pages = len(reader.pages)

    text = ''
    for page_num in range(num_pages):
        page = reader.pages[page_num]
        text += page.extract_text()
        
print("Text extracted:", text)
