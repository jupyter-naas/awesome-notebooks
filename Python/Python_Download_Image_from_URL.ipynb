# %% [markdown]
# <img width="8%" alt="Python.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Python.png" style="border-radius: 15%">

# %% [markdown]
# # Python - Download Image from URL
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Python+-+Download+Image+from+URL:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #python #image #url #naas #snippet

# %% [markdown]
# **Author:** [Abraham Israel](https://www.linkedin.com/in/abraham-israel/)

# %% [markdown]
# **Last update:** 2023-07-03 (Created: 2022-10-09)

# %% [markdown]
# **Description:** This notebook demonstrates how to download an image from a URL using Python and `wget` library.

# %% [markdown]
# **References:**
# - [PyPI wget](https://pypi.org/project/wget/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import wget
except:
    # !pip install wget
    import wget
from IPython.display import Image

# %% [markdown]
# ### Setup Variables
# - `image_url`: URL of the image

# %%
image_url = "https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Download Image

# %%
image_name = wget.download(image_url)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display image

# %%
print("Image downloaded: /", image_name)
Image(filename=image_name)
