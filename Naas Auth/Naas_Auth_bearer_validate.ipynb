# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Naas Auth - Bearer validate
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/Naas%20Auth/Naas_Auth_bearer_validate.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #naas #auth

# %% [markdown]
# **Author:** [Maxime Jublou](https://www.linkedin.com/in/maximejublou/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import naasauth

# %% [markdown]
# ## Model

# %% [markdown]
# ### Function

# %%
naasauth.connect()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
naasauth.bearer.validate()
