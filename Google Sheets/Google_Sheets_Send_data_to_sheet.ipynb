# %% [markdown]
# <img width="8%" alt="Google Sheets.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Google%20Sheets.png" style="border-radius: 15%">

# %% [markdown]
# # Google Sheets - Send data to sheet
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Google+Sheets+-+Send+data+to+sheet:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #googlesheets #gsheet #data #naas_drivers #operations #snippet

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-12-01 (Created: 2022-03-04)

# %% [markdown]
# **Description:** This notebook allows to send data to Google Sheets to a Google Sheets spreadsheet sheet.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import gsheet
import pandas as pd

# %% [markdown]
# ### Setup variables
# **Pre-requisite**
#
# - Share your Google Sheets spreadsheet with our service account : 🔗 naas-share@naas-gsheets.iam.gserviceaccount.com
#
# **Mandatory**
# - `spreadsheet_url`: Google Sheets spreadsheet URL
# - `sheet_name`: Google Sheets sheet name
#
# **Optional**
# - `append`: If False, data will be canceled and replaced.

# %%
# Mandatory
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1RdwdYXDFDSFSFxxxxxxxx/edit#gid=XXXXXXXX33"
sheet_name = "MY_SHEET"

# Optional
append = False

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create DataFrame

# %%
data = [
    {"name": "Jean", "email": "jean@appleseed.com"},
    {"name": "Bunny", "email": "bunny@appleseed.com"},
]
df = pd.DataFrame(data)
df

# %% [markdown]
# ## Output

# %% [markdown]
# ### Send data to a Google Sheets spreadsheet sheet

# %%
gsheet.connect(spreadsheet_url).send(sheet_name=sheet_name, data=df, append=append)
