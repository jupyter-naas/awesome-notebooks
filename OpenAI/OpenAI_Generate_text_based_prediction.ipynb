# %% [markdown]
# <img width="8%" alt="OpenAI.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/OpenAI.png" style="border-radius: 15%">

# %% [markdown]
# # OpenAI - Generate text based prediction
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=OpenAI+-+Generate+text+based+prediction:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #openai #prediction #text

# %% [markdown]
# **Author:** [Mohit Singh](https://www.linkedin.com/in/mohwits/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-03-08)

# %% [markdown]
# **Description:** This notebook shows how to use the OpenAI API to make predictions based on text data

# %% [markdown]
# ## Input

# %% [markdown]
# ### Install package

# %%
import os
# OpenAI
try:
    import openai
except ModuleNotFoundError:
    # !pip install --user openai
    import openai

# %% [markdown]
# ### Setup Variables

# %%
# api key
openai.api_key = "OPENAI_API_KEY"

# prompt to make prediction
prompt = input('Enter the prompt: ')

# Outputs
prediction = ''

# %% [markdown]
# ## Model

# %% [markdown]
# ### Establish connection with OpenAI and get the response

# %%
response = openai.Completion.create(
  model="text-davinci-003",
  prompt=prompt,
  temperature=0.7,
  max_tokens=256,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0
)

# %%
# get the prediction from response generated
prediction = response.choices[0].text

# %% [markdown]
# ## Output

# %%
print(prediction)
