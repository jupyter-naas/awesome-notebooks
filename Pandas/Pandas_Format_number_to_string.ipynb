# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Pandas - Format number to string
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/Pandas/Pandas_Format_number_to_string.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #pandas #dataframe #format #snippet #yahoofinance #naas_drivers #operations #jupyternotebooks

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# With this template, you can convert a series of number nicely using pandas.map

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import yahoofinance

# %% [markdown]
# ### Input parameters

# %%
ticker = "TSLA"
date_from = -100
date_to = 'today'

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get dataframe from Yahoo Finance

# %%
df_yahoo = yahoofinance.get(ticker,
                            date_from=-5)
df_yahoo

# %% [markdown]
# ## Output

# %% [markdown]
# ### Format number nicely
# Get more information in the doc [here](https://pandas.pydata.org/docs/reference/api/pandas.Series.map.html)

# %%
df_yahoo['VALUE'] = df_yahoo['Close'].map("€ {:,.2f}".format).str.replace(",", " ")
df_yahoo
