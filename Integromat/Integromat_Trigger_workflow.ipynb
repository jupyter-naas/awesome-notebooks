# %% [markdown]
# <img width="8%" alt="Integromat.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Integromat.png" style="border-radius: 15%">

# %% [markdown]
# # Integromat - Trigger workflow
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Integromat+-+Trigger+workflow:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #integromat #snippet #operations

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-02-23)

# %% [markdown]
# **Description:** This notebook allows you to create automated workflows that are triggered by specific events.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import integromat

# %% [markdown]
# ### Setup Integromat

# %%
URL = "https://hook.integromat.com/7edtlwmn8foer0r9i9ainjvsz3vxmwos"

DATA = {"first_name": "Bryan", "last_name": "Helmig", "age": 27}

# %% [markdown]
# ## Model

# %% [markdown]
# ### Send data

# %%
result = integromat.connect(URL).send(DATA)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
result
