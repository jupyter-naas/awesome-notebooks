# %% [markdown]
# <img width="8%" alt="Wikipedia.jpeg" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Wikipedia.jpeg" style="border-radius: 15%">

# %% [markdown]
# # Wikipedia - List largest cities in the world
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Wikipedia+-+List+largest+cities+in+the+world:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #wikipedia #list #cities #largest #world #data

# %% [markdown]
# **Author:** [Florent Ravenel](http://linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-03-29)

# %% [markdown]
# **Description:** This notebook will show how to extract the list of the largest cities in the world using pandas.read_html() on Wikipedia.

# %% [markdown]
# **References:**
# - [List of cities by population](https://en.wikipedia.org/wiki/List_of_cities_by_population)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Setup Variables
# - `url`: URL of the Wikipedia page containing the list of cities by population

# %%
# Inputs
url = "https://en.wikipedia.org/wiki/List_of_cities_by_population"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Extract table

# %%
df_table = pd.read_html(url)[1]
print('Rows fetched:', len(df_table))

# %% [markdown]
# ### Clean table

# %%
df_clean = df_table.copy()

# Dropna
df_clean = df_clean.dropna()

# # Flattern MultiIndex columns
# df_clean.columns = df_clean.columns.get_level_values(1)

print('Cities fetched:', len(df_clean))
df_clean.head(5)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
df_clean.head(5)
