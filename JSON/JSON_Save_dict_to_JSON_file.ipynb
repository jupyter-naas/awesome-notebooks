# %% [markdown]
# <img width="8%" alt="JSON.jpg" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/JSON.jpg" style="border-radius: 15%">

# %% [markdown]
# # JSON - Save dict to  file
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=JSON+-+Save+dict+to++file:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #json #python #file #save #data

# %% [markdown]
# **Author:** [Sriniketh Jayasendil](https://www.linkedin.com/in/sriniketh-jayasendil/)

# %% [markdown]
# **Last update:** 2023-05-09 (Created: 2023-03-10)

# %% [markdown]
# **Description:** This notebook will demonstrate how to save a dict to a json file.

# %% [markdown]
# **References:**
# - [Python json module](https://docs.python.org/3/library/json.html)
# - [Python json.dump()](https://www.programiz.com/python-programming/methods/json/dump)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import json

# %% [markdown]
# ### Setup variables
# - `json_path`: json file path

# %%
json_path = "data.json"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create data

# %%
data = {"name": "John Doe", "age": 30, "city": "New York"}
data

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save json file

# %% [markdown]
# Using the `json.dump()` function, the `data` dictionary can be saved to a json file.

# %%
with open(json_path, "w") as f:
    json.dump(data, f)
print("💾 The json file has been saved to the current directory.")
