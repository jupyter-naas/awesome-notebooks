# %% [markdown]
# <img width="8%" alt="Python.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Python.png" style="border-radius: 15%">

# %% [markdown]
# # Python - Convert time delta to months
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Python+-+Convert+time+delta+to+months:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #python #datetime #timedelta #calculate #date #time

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-05-22 (Created: 2023-05-22)

# %% [markdown]
# **Description:** This notebook convert the time delta between two dates to months.

# %% [markdown]
# **References:**
# - [Python datetime](https://docs.python.org/3/library/datetime.html)
# - [Python timedelta](https://docs.python.org/3/library/datetime.html#timedelta-objects)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from datetime import datetime

# %% [markdown]
# ### Setup Variables
# - `start_date`: First date
# - `end_date`: Second date

# %%
start_date = datetime(2022, 1, 15)
end_date = datetime(2023, 5, 22)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Calculate time delta

# %% [markdown]
# Calculate the time delta between two dates using the `timedelta` function from the `datetime` library.

# %%
delta = end_date - start_date
months = round(delta.days / 30, 1)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print(f"The time delta is {months} months.")
