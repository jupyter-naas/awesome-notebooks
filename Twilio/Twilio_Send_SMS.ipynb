# %% [markdown]
# <img width="8%" alt="Twilio.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Twilio.png" style="border-radius: 15%">

# %% [markdown]
# # Twilio - Send SMS
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Twilio+-+Send+SMS:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #twilio #project #send #sms #snippet #operations #dataframe

# %% [markdown]
# **Author:** [Sriniketh Jayasendil](https://www.linkedin.com/in/sriniketh-jayasendil/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-03-18)

# %% [markdown]
# **Description:** This notebook allows you to send SMS messages using the Twilio API.

# %% [markdown]
# ## Input

# %% [markdown]
# ## Import Library

# %%
try:
    from twilio.rest import Client
except:
    ! pip install --user twilio
    from twilio.rest import Client

# %% [markdown]
# ### Setup Twilio
# - [Get your credentials](https://support.twilio.com/hc/en-us/articles/223136027-Auth-Tokens-and-How-to-Change-Them)

# %%
# Credentials
account_sid = ""  # From Twilio Console
auth_token = ""  # From Twilio Console

# Message
from_number = (
    ""  # Buy a new number if not available preferably starting with "+1" country code
)
to_number = ""  # Could send messages only to verified Caller ID's
message = ""  # Message to be Sent

# %% [markdown]
# ## Model

# %% [markdown]
# ### Set Client

# %%
client = Client(account_sid, auth_token)  # Set Client

# %% [markdown]
# ## Output

# %% [markdown]
# ### Send message

# %%
client.api.account.messages.create(to=to_number, from_=from_number, body=message)
