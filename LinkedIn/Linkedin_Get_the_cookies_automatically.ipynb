# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # LinkedIn - Get the cookies automatically
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/template.ipynb" target="_parent">
# <img src="https://img.shields.io/badge/-Open%20in%20Naas-success?labelColor=000000&logo=data:image/svg+xml;base64,..."/>
# </a>

# %% [markdown]
# **Tags:** #linkedin #naas_drivers #naas #scheduler #snippet #automation

# %% [markdown]
# **Author:** [Maxime Jublou](https://www.linkedin.com/in/maximejublou)

# %% [markdown]
# This notebook will make it possible to refresh my LinkedIn cookies automatically.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import yahoofinance
import naas

# %% [markdown]
# ### Variables

# %%
# Input
stock_name = 'NFLX'
date_from = -3600
date_to = "today"
moving_averages = [20,50]

# Output
csv_output = "MY_OUTPUT.csv"

# %% [markdown]
# ### Schedule your notebook

# %%
# Schedule your notebook everyday at 9 AM
naas.scheduler.add(cron="0 9 * * *")

#-> Uncomment the line below to remove your scheduler
# naas.scheduler.delete()

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get data from yahoo finance (function description)

# %%
df = yahoofinance.get(stock_name,
                      date_from=date_from,
                      date_to=date_to,
                      moving_averages=moving_averages)
df

# %% [markdown]
# ## Output

# %% [markdown]
# ### Save result in csv

# %%
df.to_csv(csv_output, index=False)

# %% [markdown]
# ### Share your output with naas

# %%
naas.asset.add(csv_output)

#-> Uncomment the line below to remove your asset
# naas.asset.delete()
