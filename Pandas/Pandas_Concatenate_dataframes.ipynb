# %% [markdown]
# <img width="8%" alt="Pandas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Pandas.png" style="border-radius: 15%">

# %% [markdown]
# # Pandas - Concatenate dataframes
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Pandas+-+Concatenate+dataframes:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #pandas #concatenate #dataframe #snippet #operations

# %% [markdown]
# **Author:** [Benjamin Filly](https://www.linkedin.com/in/benjamin-filly-05427727a/)

# %% [markdown]
# **Last update:** 2023-06-30 (Created: 2023-06-06)

# %% [markdown]
# **Description:** This notebook demonstrates how to concatenate dataframes across rows or columns using the Pandas library.

# %% [markdown]
# **References:**
# - [Pandas - concat](https://pandas.pydata.org/docs/reference/api/pandas.concat.html)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Setup Variables
# - `df1`: DataFrame object
# - `df2`: DataFrame object
# - `axis`: The axis to concatenate along. 0 ="index", 1 ="columns"

# %%
df1 = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [4, 5, 6, 7]})
df2 = pd.DataFrame({'A': [7, 8, 9], 'B': [10, 11, 12]})
axis = 0

# %% [markdown]
# ## Model

# %% [markdown]
# ### Display DataFrame 1

# %%
print("Columns fetched:", len(df1.columns))
print("Rows fetched:", len(df1))
df1

# %% [markdown]
# ### Display DataFrame 2

# %%
print("Columns fetched:", len(df2.columns))
print("Rows fetched:", len(df2))
df2

# %% [markdown]
# ## Output

# %% [markdown]
# ### Concatenate dataframes

# %%
df_concat = pd.concat([df1, df2], axis=axis).reset_index(drop=True)
print("Columns fetched:", len(df_concat.columns))
print("Row fetched:", len(df_concat))
df_concat
