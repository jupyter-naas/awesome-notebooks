# %% [markdown]
# <img width="8%" alt="Qonto.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Qonto.png" style="border-radius: 15%">

# %% [markdown]
# # Qonto - Get positions
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Qonto+-+Get+positions:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #qonto #bank #organizations #positions #naas_drivers #finance #snippet #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-01-26)

# %% [markdown]
# **Description:** This notebook provides an overview of the positions available through Qonto, a digital banking service.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
from naas_drivers import qonto

# %% [markdown]
# ### Get your Qonto credentials
# <a href='https://www.notion.so/naas-official/Qonto-driver-Get-your-credentials-0cc97828b4e7467c8bfbcf704a77e5f4'>How to get your credentials ?</a>

# %%
QONTO_USER_ID = "YOUR_USER_ID"
QONTO_SECRET_KEY = "YOUR_SECRET_KEY"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get bank positions

# %%
df_positions = qonto.connect(QONTO_USER_ID, QONTO_SECRET_KEY).positions.get()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
df_positions
