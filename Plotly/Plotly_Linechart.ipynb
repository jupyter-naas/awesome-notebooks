# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Plotly - Line Chart
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/Plotly/Create%20Line%20Chart%20%28Basic%29.ipynb" target="_parent"><img src="https://img.shields.io/badge/-Open%20in%20Naas-success?labelColor=000000&logo=data:image/svg+xml;base64,..."/></a>

# %% [markdown]
# **Tags:** #plotly #chart #linechart #trend #dataviz

# %% [markdown]
# Learn more on the Plotly doc : https://plotly.com/python/line-charts/

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
import naas
from naas_drivers import yahoofinance, plotly
import plotly.express as px

# %% [markdown]
# ### Variables

# %%
title = "Linechart"

# %% [markdown]
# ### Get dataset

# %%
date_from = -360 # Date can be number or date or today
date_to = "today"
df = yahoofinance.get("TSLA", date_from=date_from, date_to=date_to)
df
# Out:
# getted data for TSLA https://query1.finance.yahoo.com/v7/finance/download/TSLA?period1=1604333756&period2=1635434156&interval=1d&events=history
#           Date         Open         High          Low        Close  \
# 0   2020-11-02   394.000000   406.980011   392.299988   400.510010
# 1   2020-11-03   409.730011   427.769989   406.690002   423.899994
# 2   2020-11-04   430.619995   435.399994   417.100006   420.980011
# 3   2020-11-05   428.299988   440.000000   424.000000   438.089996
# 4   2020-11-06   436.100006   436.570007   424.279999   429.950012
# ..         ...          ...          ...          ...          ...
# 245 2021-10-22   895.500000   910.000000   890.960022   909.679993
# 246 2021-10-25   950.530029  1045.020020   944.200012  1024.859985
# 247 2021-10-26  1024.689941  1094.939941  1001.440002  1018.429993
# 248 2021-10-27  1039.660034  1070.880005  1030.780029  1037.859985
# 249 2021-10-28  1068.310059  1081.000000  1054.380005  1072.744995
#
#        Adj Close    Volume Company
# 0     400.510010  29021100    TSLA
# 1     423.899994  34351700    TSLA
# 2     420.980011  32143100    TSLA
# 3     438.089996  28414500    TSLA
# 4     429.950012  21706000    TSLA
# ..           ...       ...     ...
# 245   909.679993  22836800    TSLA
# 246  1024.859985  62852100    TSLA
# 247  1018.429993  62415000    TSLA
# 248  1037.859985  38167800    TSLA
# 249  1072.744995  12487723    TSLA
#
# [250 rows x 8 columns]

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create the plot

# %%
fig = px.line(df, x="Date", y=["Open", "Close"])

fig.update_layout(
    title=title ,
    plot_bgcolor="#ffffff",
    width=None,
    height=600,
    showlegend=False,
    xaxis_showline=True,
    xaxis_showgrid=False,
    xaxis_showticklabels=True,
    xaxis_ticks='inside',
    yaxis_title='Price in $',
    yaxis_titlefont_size=16,
    yaxis_tickfont_size=14
)

config = {'displayModeBar': False}
fig.show(config=config)

# %% [markdown]
# ### Create function

# %%
import plotly.express as px

config = {'displayModeBar': False}

def update_layout(fig,
                  title=None,
                  plot_bgcolor=None,
                  width=None,
                  height=None,
                  showlegend=None,
                  xaxis_title=None,
                  yaxis_title=None):
    fig.update_layout(title=title,
                      plot_bgcolor=plot_bgcolor,
                      width=width,
                      height=height,
                      showlegend=showlegend,
                      xaxis_title=xaxis_title,
                      yaxis_title=yaxis_title)
    return fig

def linechart(df,
              x,
              y,
              title=None,
              plot_bgcolor="#ffffff",
              width=None,
              height=600,
              showlegend=False,
              xaxis_title=None,
              yaxis_title=None):
    fig = px.line(df, x, y)
    fig = update_layout(fig,
                        title,
                        plot_bgcolor,
                        width,
                        height,
                        showlegend,
                        xaxis_title,
                        yaxis_title)
    fig.show(config=config)
    return fig

fig = linechart(df, x="Date", y=["Open", "Close"], title=title, yaxis_title="Price in $")

# %% [markdown]
# ## Output

# %% [markdown]
# ### Export in PNG and HTML

# %%
plotly.export(fig, f"{title}.png", css=None)
plotly.export(fig, f"{title}.html", css=None)

# %% [markdown]
# ### Generate shareable assets

# %%
link_image = naas.asset.add(f"{title}.png")
link_html = naas.asset.add(f"{title}.html", {"inline":True})
