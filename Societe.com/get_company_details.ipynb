# %%
import pandas as pd


data = pd.read_html("https://www.societe.com/societe/cashstory-880612569.html")
data[0]
# Out:
#                                                     0  \
# 0                                          Statut RCS
# 1                                        Statut INSEE
# 2                                        Dénomination
# 3                                             Adresse
# 4                                               SIREN
# 5                                       SIRET (siege)
# 6                        N° de TVA Intracommunautaire
# 7   Voir  PLUS  +  Activité (Code NAF ou APE)  Con...
# 8   Voir  PLUS  +  Forme juridique  SA à directoir...
# 9                            Date immatriculation RCS
# 10                       Date de dernière mise à jour
# 11  Voir  PLUS  +  Effectif moyen  76  Historique ...
# 12  Voir  PLUS  +  Capital social  3579808,60 EURO...
# 13                            Chiffre d'affaires 2019
#
#                                                     1
# 0                   Immatriculée au RCS le 10-11-1999
# ...
