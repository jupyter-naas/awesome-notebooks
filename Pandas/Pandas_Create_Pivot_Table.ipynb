# %% [markdown]
# <img width="8%" alt="Pandas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Pandas.png" style="border-radius: 15%">

# %% [markdown]
# # Pandas - Create Pivot Table
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Pandas+-+Create+Pivot+Table:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #pandas #pivot #operations #snippet #dataframe

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-10-06)

# %% [markdown]
# **Description:** This notebook provides an example of how to use the Pandas library to create a pivot table.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
import pandas as pd

# %% [markdown]
# ### Variables

# %%
df = pd.DataFrame(
    {
        "item": ["apple", "apple", "apple", "apple", "apple"],
        "size": ["small", "small", "large", "large", "large"],
        "location": ["Walmart", "Aldi", "Walmart", "Aldi", "Aldi"],
        "price": [3, 2, 4, 3, 2.5],
    }
)
df

# %% [markdown]
# ## Model

# %% [markdown]
# ### Function

# %%
pivot = pd.pivot_table(
    df, values="price", index=["item", "size"], columns=["location"], aggfunc="mean"
)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
pivot
