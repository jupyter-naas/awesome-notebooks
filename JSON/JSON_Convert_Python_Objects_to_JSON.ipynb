# %% [markdown]
# <img width="8%" alt="JSON.jpg" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/JSON.jpg" style="border-radius: 15%">

# %% [markdown]
# # JSON - Convert Python Objects to
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=JSON+-+Convert+Python+Objects+to:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #json #python #convert #object #serialize #deserialize

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel)

# %% [markdown]
# **Last update:** 2023-07-31 (Created: 2023-07-31)

# %% [markdown]
# **Description:** This notebook will show how to convert Python objects to JSON and how to deserialize JSON back into Python objects.

# %% [markdown]
# **References:**
# - [Python JSON](https://docs.python.org/3/library/json.html)
# - [JSON Tutorial](https://www.w3schools.com/js/js_json_intro.asp)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import json

# %% [markdown]
# ### Setup variables
# - `data`: Python dictionary to be converted to JSON

# %%
data = {"name": "Florent", "age": 28, "city": "Paris"}

# %% [markdown]
# ## Model

# %% [markdown]
# ### Serialize Python object to JSON

# %%
# Serialize Python object to JSON
json_data = json.dumps(data)

# %% [markdown]
# ### Deserialize JSON to Python object

# %%
# Deserialize JSON to Python object
python_data = json.loads(json_data)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
# Display result
print(json_data)
print(python_data)
