# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - Get help
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+Get+help:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #help #snippet #operations

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-04-14)

# %% [markdown]
# **Description:** This notebook provides helpful resources and guidance for navigating the Naas platform.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import needed library

# %%
import naas

# %% [markdown]
# ## Model

# %% [markdown]
# ### Open help chatbox

# %%
naas.open_help()

# %% [markdown]
# ## Output

# %% [markdown]
# ### Close help chatbox

# %%
naas.close_help()
