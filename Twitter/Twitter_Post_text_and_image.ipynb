# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Twitter - Post text and image
# [![download](https://img.shields.io/static/v1?label=&labelColor=000000&message=Open%20in%20Naas&color=success&logo=image%2Fsvg%2Bxml%3Bbase64%%%2BbjwvdGV4dD4KIDwvZGVmcz4KIDx1c2UgaWQ9Im4iIHhsaW5rOmhyZWY9IiNzdHJpbmciLz4KPC9zdmc%2BCg%3D%3D)](https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/Twitter/Twitter_Post_text_and_image.ipynb)

# %%
import naas_drivers
data = naas_drivers.yahoofinance.get('^FCHI',date_from=-200, moving_averages=[50,20])
# Out:
# getted data for ^FCHI https://query1.finance.yahoo.com/v7/finance/download/^FCHI?period1=1597343142&period2=1614626742&interval=1d&events=history

# %%
chart = naas_drivers.plotly.stock(data)
chart.show()
# Out:
# Chart candlestick generated

# %%
name = "chart.png"
naas_drivers.plotly.export(chart, name)
# Out:
# Saved as chart.png

# %%
import naas
url = naas.assets.add(name, params={"inline":True})
# Out:
# 👌 Well done! Your Assets has been sent to production.
# Button(button_style='primary', description='Copy URL', style=ButtonStyle())
# Output()
# PS: to remove the "Assets" feature, just replace .add by .delete

# %%
twitter_post = """📈🚀 Every day at 9AM PST / 6PM CET<br>
CAC40 index value with #MovingAverages 20 and 50
<br>
Don't miss an #opportunity to #invest<br>
<br>
PS : this post has been generated automatically with https://www.naas.ai/ 😎 
#automation #trading #data #analysis @Nasdaq
"""
event = "twitter-post"
key = "ke4AigvXI5-EABaowdLt4fju1aOUxeMxSXQoN8FVyA"
data = { "value1" : twitter_post,  "value2" : url}

# %%
result = naas_drivers.ifttt.webhook(event, key, data)
