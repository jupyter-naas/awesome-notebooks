# %% [markdown]
# <img width="8%" alt="Pandas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Pandas.png" style="border-radius: 15%">

# %% [markdown]
# # Pandas - Sort values by multiples columns
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Pandas+-+Sort+values+by+multiples+columns:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #pandas #dataframe #sort #columns #values #multiples

# %% [markdown]
# **Author:** [Benjamin Filly](https://www.linkedin.com/in/benjamin-filly-05427727a/)

# %% [markdown]
# **Last update:** 2023-06-16 (Created: 2023-06-13)

# %% [markdown]
# **Description:** This notebook will show how to sort values by multiples columns in Pandas. It is usefull for data analysis and data manipulation.

# %% [markdown]
# **References:**
# - [Pandas - Sort values](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html)
# - [Pandas - Tutoriel Sort Value](https://www.geeksforgeeks.org/python-pandas-dataframe-sort_values-set-2/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd

# %% [markdown]
# ### Setup Variables

# %% [markdown]
# - `by`: Name or list of names to sort by.
# - `ascending`: bool or list of bool, default True. Specify list for multiple sort orders. If this is a list of bools, must match the length of the by.
# - `ignore_index`: bool, default False. If True, the resulting axis will be labeled 0, 1, …, n - 1.

# %%
by = ['Score', 'Age']
ascending = [False, True]
ignore_index = True

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create a dataframe

# %%
# Create a dataframe
data = {
    "Name": ["Tom", "nick", "krish", "jack"],
    "Age": [20, 21, 19, 18],
    "Score": [99, 98, 95, 90],
}
df = pd.DataFrame(data)
df

# %% [markdown]
# ## Output

# %% [markdown]
# ### Sort values by multiples columns

# %%
# Sort the DataFrame by multiple columns
sorted_df = df.sort_values(by=by, ascending=ascending, ignore_index=ignore_index)
sorted_df
