# %% [markdown]
# <img width="8%" alt="Naas" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # gTTS - Save Text to Speech to MP3
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=gTTS+-+Save+Text+to+Speech+to+MP3:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #gTTS #texttospeech #mp3 #python #library #audio

# %% [markdown]
# **Author:** [Sriniketh Jayasendil](http://linkedin.com/in/sriniketh-jayasendil/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-03-02)

# %% [markdown]
# **Description:** This notebook will demonstrate how to use the gTTS library to save text to speech as an MP3 file.

# %% [markdown]
# **References:**
# - [gTTS Documentation](https://pypi.org/project/gTTS/)
# - [gTTS GitHub Repository](https://github.com/pndurette/gTTS)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    from gtts import gTTS

except ModuleNotFoundError:
    # !pip install gTTS
    from gtts import gTTS

# %% [markdown]
# ### Setup Variables
# - `text`: Text to be converted to speech

# %%
text = "This is a demonstration of the gTTS library"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Convert Text to Speech

# %% [markdown]
# This code will convert the text to speech and save it as an MP3 file.

# %%
tts = gTTS(text=text, lang="en")
tts.save("text_to_speech.mp3")

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %% [markdown]
# This code will display the result of the conversion.

# %%
print("Text to Speech conversion successful!")
