# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # _Metrics_Store - Metrics Store Store Template
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/_Metrics_Store/_Metrics_Store_Store_Template.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #tag1 #tag2

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
import naas_drivers

# %% [markdown]
# ### Variables

# %%
stock_name = 'NFLX'

# %% [markdown]
# ## Model

# %% [markdown]
# ### Function

# %%
table = naas_drivers.yahoofinance.get(stock_name, date_from=-3600, date_to="today", moving_averages=[20,50])

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
table
