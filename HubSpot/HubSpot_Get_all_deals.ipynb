# %% [markdown]
# <img width="8%" alt="HubSpot.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/HubSpot.png" style="border-radius: 15%">

# %% [markdown]
# # HubSpot - Get all deals
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=HubSpot+-+Get+all+deals:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #hubspot #crm #sales #deal #naas_drivers #snippet #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-02-21)

# %% [markdown]
# **Description:** This notebook provides a comprehensive overview of all deals in HubSpot.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import hubspot

# %% [markdown]
# ### Setup HubSpot
# 👉 Starting November 30, 2022, HubSpot API keys no longer enable access to HubSpot APIs, so in Naas version 2.8.3 and above, you need [create a private app and use the access token](https://developers.hubspot.com/docs/api/private-apps).

# %% [markdown]
# #### Enter Your Access Token

# %%
HS_ACCESS_TOKEN = naas.secret.get("HS_ACCESS_TOKEN") or "YOUR_HS_ACCESS_TOKEN"

# %% [markdown]
# #### Define Deal properties
# List of properties you want to get from deal.<br>
# By default, you will get:
# - dealname
# - amount
# - dealstage
# - pipeline
# - createdate
# - closedate
# - hs_object_id
# - hs_lastmodifieddate

# %%
properties = []

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get all deals

# %%
df_deals = hubspot.connect(HS_ACCESS_TOKEN).deals.get_all(properties)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
df_deals
