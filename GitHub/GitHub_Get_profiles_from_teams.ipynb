# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # GitHub - Get profiles from teams
# <a href="https://app.naas.ai/user-redirect/naas/downloader?url=https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/GitHub/GitHub_Get_profiles_from_teams.ipynb" target="_parent"><img src="https://naasai-public.s3.eu-west-3.amazonaws.com/open_in_naas.svg"/></a>

# %% [markdown]
# **Tags:** #github #team #operations #snippet #dataframe

# %% [markdown]
# **Author:** [Sanjeet Attili](https://www.linkedin.com/in/sanjeet-attili-760bab190/)

# %% [markdown]
# This notebook enables you to get a dataframe of all the team members in a Github organization.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
from naas_drivers import github

# %% [markdown]
# ### Setup Github

# %% [markdown]
# **How to find your personal access token on Github?**
# - First we need to create a personal access token to get the details of our organization from here: https://github.com/settings/tokens
# - You will be asked to select scopes for the token. Which scopes you choose will determine what information and actions you will be able to perform against the API.
# - You should be careful with the ones prefixed with write:, delete: and admin: as these might be quite destructive.
# - You can find description of each scope in docs here (https://docs.github.com/en/developers/apps/building-oauth-apps/scopes-for-oauth-apps).

# %% [markdown]
# ### Variables

# %%
TEAM_URL = "https://github.com/orgs/jupyter-naas/teams"

GITHUB_TOKEN = "ghp_PITkKHTBIbcXXXXXXXXXXXXXX"

# %% [markdown]
# ## Model

# %%
df_teams = github.connect(GITHUB_TOKEN).teams.get_profiles(TEAM_URL)

# %% [markdown]
# ## Output

# %%
print(f'Dataset size -> {df_teams.shape}')
df_teams.head(25)
# Out:
# Dataset size -> (112, 14)
#                        TEAM                     SLUG  \
# 0                 core-team                core-team
# 1                 core-team                core-team
# 2                 core-team                core-team
# 3                 core-team                core-team
# 4                 core-team                core-team
# 5                 core-team                core-team
# 6                 core-team                core-team
# 7                 core-team                core-team
# 8                 core-team                core-team
# 9                 core-team                core-team
# 10  opensource-contributors  opensource-contributors
# 11  opensource-contributors  opensource-contributors
# 12  opensource-contributors  opensource-contributors
# 13  opensource-contributors  opensource-contributors
# 14  opensource-contributors  opensource-contributors
# 15  opensource-contributors  opensource-contributors
# 16  opensource-contributors  opensource-contributors
# 17  opensource-contributors  opensource-contributors
# 18  opensource-contributors  opensource-contributors
# 19  opensource-contributors  opensource-contributors
# 20  opensource-contributors  opensource-contributors
# 21  opensource-contributors  opensource-contributors
# 22  opensource-contributors  opensource-contributors
# 23  opensource-contributors  opensource-contributors
# 24  opensource-contributors  opensource-contributors
#
#                        TEAM_DESCRIPTION  \
# 0                  Naas core team group
# 1                  Naas core team group
# 2                  Naas core team group
# 3                  Naas core team group
# 4                  Naas core team group
# 5                  Naas core team group
# 6                  Naas core team group
# 7                  Naas core team group
# 8                  Naas core team group
# 9                  Naas core team group
# 10  Naas opensource contributors group
# 11  Naas opensource contributors group
# 12  Naas opensource contributors group
# 13  Naas opensource contributors group
# 14  Naas opensource contributors group
# 15  Naas opensource contributors group
# 16  Naas opensource contributors group
# 17  Naas opensource contributors group
# 18  Naas opensource contributors group
# 19  Naas opensource contributors group
# 20  Naas opensource contributors group
# 21  Naas opensource contributors group
# 22  Naas opensource contributors group
# 23  Naas opensource contributors group
# 24  Naas opensource contributors group
#
#                                       member_profile        GITHUB  \
# 0                https://api.github.com/users/riderx  jupyter-naas
# 1          https://api.github.com/users/navinkarkera  jupyter-naas
# 2              https://api.github.com/users/jravenel  jupyter-naas
# 3                https://api.github.com/users/Dr0p42  jupyter-naas
# 4             https://api.github.com/users/imasdekar  jupyter-naas
# 5          https://api.github.com/users/BobCashStory  jupyter-naas
# 6            https://api.github.com/users/FlorentLvr  jupyter-naas
# 7        https://api.github.com/users/sanjaysabu4205  jupyter-naas
# 8           https://api.github.com/users/tparente-ui  jupyter-naas
# 9            https://api.github.com/users/Valpiquard  jupyter-naas
# 10         https://api.github.com/users/housecricket  jupyter-naas
# 11                 https://api.github.com/users/Bl3f  jupyter-naas
# 12               https://api.github.com/users/riderx  jupyter-naas
# 13               https://api.github.com/users/vivard  jupyter-naas
# 14         https://api.github.com/users/HarshitDoshi  jupyter-naas
# 15            https://api.github.com/users/poojashri  jupyter-naas
# 16       https://api.github.com/users/justin-prather  jupyter-naas
# 17             https://api.github.com/users/brunosez  jupyter-naas
# 18             https://api.github.com/users/njgroene  jupyter-naas
# 19   https://api.github.com/users/tomhamiltonstubber  jupyter-naas
# 20  https://api.github.com/users/Charles-de-Montigny  jupyter-naas
# 21         https://api.github.com/users/Bharat123rox  jupyter-naas
# 22            https://api.github.com/users/billounet  jupyter-naas
# 23             https://api.github.com/users/dabumana  jupyter-naas
# 24            https://api.github.com/users/cherotich  jupyter-naas
#
#                     NAME                           EMAIL          LOCATION  \
# 0        Martin DONADIEU        martindonadieu@gmail.com            Remote
# 1          Navin Karkera             navin@opencraft.com              None
# 2         Jeremy Ravenel                  jeremy@naas.ai        Everywhere
# 3          Maxime Jublou                maxime@jublou.fr          Pyrénées
# 4         Ishan Masdekar           imasdekar@disroot.org              None
# 5                   None                            None              None
# 6                   None                            None              None
# 7            NIGHT_SHADE                            None             India
# 8       Thomas Parenteau                            None              None
# 9                   None                            None              None
# 10        Dang Trung Anh          dangtrunganh@gmail.com              None
# 11    Christophe Blefari    christophe.blefari@gmail.com              None
# 12       Martin DONADIEU        martindonadieu@gmail.com            Remote
# 13                  None                            None              None
# 14         Harshit Doshi                            None         Computers
# 15                 Pooja                            None              None
# 16        Justin Prather                            None              None
# 17          Bruno Seznec                            None             Paris
# 18                  None                            None           Estonia
# 19  Tom Hamilton Stubber    tomhamiltonstubber@gmail.com    United Kingdom
# 20    Charles Demontigny                            None  Montreal, Canada
# 21    Bharat Raghunathan  bharatraghunthan9767@gmail.com           Chennai
# 22                  None                            None              None
# 23              dabumana                            None             win32
# 24    Caroline cherotich   carolinecherotich19@gmail.com              None
#
#                        ORGANIZATION  \
# 0   @Forgr-ee @Captime @INDIEMAKERS
# 1                              None
# 2                      @JupyterNaas
# 3                          naas.ai
# 4                              None
# 5                              None
# 6                              None
# 7                     Bridge Global
# 8                              None
# 9                              None
# 10                       Many Areas
# 11                             None
# 12  @Forgr-ee @Captime @INDIEMAKERS
# 13                             None
# 14                        @shunyaek
# 15                             None
# 16                             None
# 17                          Meta AI
# 18                         Thrivity
# 19                   @tutorcruncher
# 20                          Fluxion
# 21   Software Engineer @ ServiceNow
# 22                             None
# 23                             None
# 24                             None
#
#                                                   BIO           LOGIN_NAME  \
