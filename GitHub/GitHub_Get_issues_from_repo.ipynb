# %% [markdown]
# <img width="8%" alt="GitHub.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/GitHub.png" style="border-radius: 15%">

# %% [markdown]
# # GitHub - Get issues from repo
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=GitHub+-+Get+issues+from+repo:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #github #repos #issues #operations #analytics #dataframe #html #plotly

# %% [markdown]
# **Author:** [Sanjeet Attili](https://www.linkedin.com/in/sanjeet-attili-760bab190/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-03-18)

# %% [markdown]
# **Description:** This notebook allows users to retrieve issues from a GitHub repository.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Imports

# %%
from naas_drivers import github

# %% [markdown]
# ### Variables

# %%
# Github repository url
REPO_URL = "https://github.com/jupyter-naas/awesome-notebooks"

# Github token
GITHUB_TOKEN = "ghp_COJiJEU4cQR4rjslUxxxxxxxxxxxxxxxx"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get issues from repo

# %%
df_issues = github.connect(GITHUB_TOKEN).repos.get_issues(REPO_URL)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
print("Nb issues:", len(df_issues))
df_issues.head(15)
