# %% [markdown]
# <img width="8%" alt="JSON.jpg" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/JSON.jpg" style="border-radius: 15%">

# %% [markdown]
# # JSON - Read local file
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=JSON+-+Read+local+file:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #json #python #read #file #data #parse

# %% [markdown]
# **Author:** [Sriniketh Jayasendil](https://www.linkedin.com/in/sriniketh-jayasendil/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-03-10)

# %% [markdown]
# **Description:** This notebook will demonstrate how to read a json file.

# %% [markdown]
# **References:**
# - [Python json module](https://docs.python.org/3/library/json.html)
# - [JSON format](https://www.json.org/json-en.html)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import json

# %% [markdown]
# ### Setup variables
# - `file_name`: Name of the json file to be read

# %%
file_name = "../templates.json"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Read json file

# %% [markdown]
# This function will read the json file and return the content as a dictionary.

# %%
def read_json_file(file_name):
    with open(file_name) as json_file:
        data = json.load(json_file)
    return data

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %%
data = read_json_file(file_name)
print("Data fetched:", len(data))
