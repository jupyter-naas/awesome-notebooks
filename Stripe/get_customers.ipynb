# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>
#
# # Get Stripe customers data

# %%
pip install stripe
# Out:
# Collecting stripe
#   Downloading stripe-2.55.1-py2.py3-none-any.whl (204 kB)
#      |████████████████████████████████| 204 kB 20.7 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.20 in /opt/conda/lib/python3.8/site-packages (from stripe) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.20->stripe) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.20->stripe) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.20->stripe) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.20->stripe) (3.0.4)
# Installing collected packages: stripe
# Successfully installed stripe-2.55.1
# Note: you may need to restart the kernel to use updated packages.

# %%
api_key = "sk_test_4eC39HqLyjWDarjtT1zdp7dc"

# %%
import stripe
import pandas as pd

stripe.api_key = api_key

# %%
customers = stripe.Customer.list(limit=30)
pd.DataFrame(customers.get('data'))
# Out:
#                     id    object  account_balance address  balance  \
# 0   cus_IqHEe3PhUotiH1  customer                0    None        0
# 1   cus_IqHEP5SMM6d9ZM  customer                0    None        0
# 2   cus_IqHEEukJDF6Mnj  customer                0    None        0
# 3   cus_IqHE5Wev2F1Ibt  customer                0    None        0
# 4   cus_IqHElDgwO0xmH6  customer                0    None        0
# 5   cus_IqHEJ3EWY8MBJQ  customer                0    None        0
# 6   cus_IqHE8OejesJTLe  customer                0    None        0
# 7   cus_IqHErQNfXd2xpf  customer                0    None        0
# 8   cus_IqHEhIs822XX5Q  customer                0    None        0
# 9   cus_IqHDGmVKrBren1  customer                0    None        0
# 10  cus_IqHDJxUEu8k9FI  customer                0    None        0
# 11  cus_IqHDcIxm9owOEc  customer                0    None        0
# 12  cus_IqHDcl9R4yjDeM  customer                0    None        0
# 13  cus_IqHDqLQJgDcGEK  customer                0    None        0
# 14  cus_IqHD6BZq9kvCMr  customer                0    None        0
# 15  cus_IqHD2tpzC7EDTG  customer                0    None        0
# 16  cus_IqHD5ZNBOGQRFc  customer                0    None        0
# 17  cus_IqHCSKDoMkKz9X  customer                0    None        0
# 18  cus_IqHC0Z2ZSwuNqQ  customer                0    None        0
# 19  cus_IqHCO6X92pJNon  customer                0    None        0
# 20  cus_IqHCFTPXlDTnYl  customer                0    None        0
# 21  cus_IqHCmZpP40PjCK  customer                0    None        0
# 22  cus_IqHCnPOfbIPuXv  customer                0    None        0
# 23  cus_IqHCkWxjdBsUpL  customer                0    None        0
# 24  cus_IqHCnG01cmvsSs  customer                0    None        0
# 25  cus_IqHCpi9U50CiXv  customer                0    None        0
# 26  cus_IqHCSzCiZ0avU0  customer                0    None        0
# 27  cus_IqHBcv56FjHNBB  customer                0    None        0
# 28  cus_IqHBewC0QEgSrQ  customer                0    None        0
# 29  cus_IqHBsEbm6mCsvX  customer                0    None        0
#
#        created currency default_source  delinquent description  ...  \
# 0   1611840995      usd           None       False        None  ...
# 1   1611840992      usd           None       False        None  ...
# 2   1611840990      usd           None       False        None  ...
# 3   1611840987      usd           None       False        None  ...
# 4   1611840986      usd           None       False        None  ...
# 5   1611840985      usd           None       False        None  ...
# 6   1611840982      usd           None       False        None  ...
# 7   1611840981      usd           None       False        None  ...
# 8   1611840981      usd           None       False        None  ...
# 9   1611840958      usd           None       False        None  ...
# 10  1611840958      usd           None       False        None  ...
# 11  1611840952      usd           None       False        None  ...
# 12  1611840941      usd           None       False        None  ...
# 13  1611840940      usd           None       False        None  ...
# 14  1611840935      usd           None       False        None  ...
# 15  1611840930      usd           None       False        None  ...
# 16  1611840920      usd           None       False        None  ...
# 17  1611840905      usd           None       False        None  ...
# 18  1611840886      usd           None       False        None  ...
# 19  1611840882      usd           None       False        None  ...
# 20  1611840881      usd           None       False        None  ...
# 21  1611840880      usd           None       False        None  ...
# 22  1611840877      usd           None       False        None  ...
# 23  1611840876      usd           None       False        None  ...
# 24  1611840873      usd           None       False        None  ...
# 25  1611840870      usd           None       False        None  ...
# 26  1611840868      usd           None       False        None  ...
# 27  1611840852      usd           None       False        None  ...
# 28  1611840847      usd           None       False        None  ...
# 29  1611840846      usd           None       False        None  ...
#
#    next_invoice_sequence phone preferred_locales shipping  \
# 0                      1  None                []     None
# 1                      1  None                []     None
# 2                      1  None                []     None
# 3                      1  None                []     None
# 4                      1  None                []     None
# 5                      1  None                []     None
# 6                      1  None                []     None
# 7                      1  None                []     None
# 8                      1  None                []     None
# 9                      1  None                []     None
# 10                     1  None                []     None
# 11                     1  None                []     None
# 12                     1  None                []     None
# 13                     1  None                []     None
# 14                     1  None                []     None
# 15                     1  None                []     None
# 16                     1  None                []     None
# 17                     1  None                []     None
# 18                     1  None                []     None
# 19                     1  None                []     None
# 20                     1  None                []     None
# 21                     1  None                []     None
# 22                     1  None                []     None
# 23                     1  None                []     None
# 24                     1  None                []     None
# 25                     1  None                []     None
# 26                     1  None                []     None
# 27                     1  None                []     None
# 28                     1  None                []     None
# 29                     1  None                []     None
#
#                                               sources  \
# 0   {'object': 'list', 'data': [], 'has_more': Fal...
# 1   {'object': 'list', 'data': [], 'has_more': Fal...
# 2   {'object': 'list', 'data': [], 'has_more': Fal...
# 3   {'object': 'list', 'data': [], 'has_more': Fal...
# 4   {'object': 'list', 'data': [], 'has_more': Fal...
# 5   {'object': 'list', 'data': [], 'has_more': Fal...
# 6   {'object': 'list', 'data': [], 'has_more': Fal...
# 7   {'object': 'list', 'data': [], 'has_more': Fal...
# 8   {'object': 'list', 'data': [], 'has_more': Fal...
# 9   {'object': 'list', 'data': [], 'has_more': Fal...
# 10  {'object': 'list', 'data': [], 'has_more': Fal...
# 11  {'object': 'list', 'data': [], 'has_more': Fal...
# 12  {'object': 'list', 'data': [], 'has_more': Fal...
# 13  {'object': 'list', 'data': [], 'has_more': Fal...
# 14  {'object': 'list', 'data': [], 'has_more': Fal...
# 15  {'object': 'list', 'data': [], 'has_more': Fal...
# 16  {'object': 'list', 'data': [], 'has_more': Fal...
# 17  {'object': 'list', 'data': [], 'has_more': Fal...
# 18  {'object': 'list', 'data': [], 'has_more': Fal...
# 19  {'object': 'list', 'data': [], 'has_more': Fal...
# 20  {'object': 'list', 'data': [], 'has_more': Fal...
# 21  {'object': 'list', 'data': [], 'has_more': Fal...
# 22  {'object': 'list', 'data': [], 'has_more': Fal...
# 23  {'object': 'list', 'data': [], 'has_more': Fal...
# 24  {'object': 'list', 'data': [], 'has_more': Fal...
# 25  {'object': 'list', 'data': [], 'has_more': Fal...
# 26  {'object': 'list', 'data': [], 'has_more': Fal...
# 27  {'object': 'list', 'data': [], 'has_more': Fal...
# 28  {'object': 'list', 'data': [], 'has_more': Fal...
# 29  {'object': 'list', 'data': [], 'has_more': Fal...
#
#                                         subscriptions tax_exempt  \
# 0   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 1   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 2   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 3   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 4   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 5   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 6   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 7   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 8   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 9   {'object': 'list', 'data': [], 'has_more': Fal...       none
# 10  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 11  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 12  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 13  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 14  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 15  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 16  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 17  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 18  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 19  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 20  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 21  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 22  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 23  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 24  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 25  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 26  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 27  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 28  {'object': 'list', 'data': [], 'has_more': Fal...       none
# 29  {'object': 'list', 'data': [], 'has_more': Fal...       none
#
#                                               tax_ids tax_info  \
# 0   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 1   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 2   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 3   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 4   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 5   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 6   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 7   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 8   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 9   {'object': 'list', 'data': [], 'has_more': Fal...     None
# 10  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 11  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 12  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 13  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 14  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 15  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 16  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 17  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 18  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 19  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 20  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 21  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 22  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 23  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 24  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 25  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 26  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 27  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 28  {'object': 'list', 'data': [], 'has_more': Fal...     None
# 29  {'object': 'list', 'data': [], 'has_more': Fal...     None
#
#    tax_info_verification
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# 5                   None
# 6                   None
# 7                   None
# 8                   None
# 9                   None
# 10                  None
# 11                  None
# 12                  None
# 13                  None
# 14                  None
# 15                  None
# 16                  None
# 17                  None
# 18                  None
# 19                  None
# 20                  None
# 21                  None
# 22                  None
# 23                  None
# 24                  None
# 25                  None
# 26                  None
# 27                  None
# 28                  None
# 29                  None
#
# [30 rows x 27 columns]
