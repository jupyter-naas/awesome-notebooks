# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Buffer - Create draft

# %% [markdown]
# **Tags:** #buffer #draft #create #socialmedia #socialnetworks #socialmediaplatforms

# %% [markdown]
# **Author:** [Firstname Lastname]()

# %% [markdown]
# **Last update:** 2023-10-05 (Created: 2023-10-05)

# %% [markdown]
# **Description:** This notebook creates a draft for Buffer, a social media platform. It is usefull for organizations to quickly create a post for their social media accounts.

# %% [markdown]
# **References:**
# - [Buffer Documentation](https://buffer.com/developers/api/overview)
# - [Buffer API](https://buffer.com/developers/api/overview)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import requests
import json

# %% [markdown]
# ### Setup variables
# - **access_token**: Access token for Buffer API. [Link to procedure](https://buffer.com/developers/api/overview)
# - **profile_id**: Profile ID of the account where the post will be created. [Link to procedure](https://buffer.com/developers/api/overview)
# - **text**: Text of the post.

# %%
access_token = "...
