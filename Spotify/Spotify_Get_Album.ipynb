# %% [markdown]
# <img width="10%" alt="Naas" src="https://landen.imgix.net/jtci2pxwjczr/assets/5ice39g4.png?w=160"/>

# %% [markdown]
# # Spotify - Get Album

# %% [markdown]
# **Tags:** #spotify #api #album #get #web #catalog #snippet

# %% [markdown]
# **Author:** [Alton Liew](https://www.linkedin.com/in/alton-liew-749944182/)

# %% [markdown]
# **Last update:** 2023-12-01 (Created: 2023-12-01)

# %% [markdown]
# **Description:** This notebook retrieves Spotify catalog information for a single album.

# %% [markdown]
# **References:**
# - [Spotify Web API Reference - Get an Album](https://developer.spotify.com/documentation/web-api/reference/get-an-album)
# - [Spotify Web API Authorization Guide](https://developer.spotify.com/documentation/general/guides/authorization-guide/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import spotipy
except:
    # !pip install spotipy --user
    import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import naas
from pprint import pprint
from IPython.display import Image, display

# %% [markdown]
# ### Setup variables
# - `client_id`: Your Spotify API client ID. [Get your client ID](https://developer.spotify.com/documentation/general/guides/app-settings/#register-your-app)
# - `client_secret`: Your Spotify API client secret. [Get your client secret](https://developer.spotify.com/documentation/general/guides/app-settings/#register-your-app)
# - `album_id`: The unique Spotify ID for the album. [Find the album ID](https://developer.spotify.com/documentation/web-api/reference/get-an-album)

# %%
client_id = naas.secret.get("SPOTIFY_CLIENT_ID")
client_secret = naas.secret.get("SPOTIFY_CLIENT_SECRET")
album_id = "7ivbFszr1TbVadj89BIy1y"  #1gIC63gC3B7o7FfpPACZQJ

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get album

# %% [markdown]
# * Retrieve Spotify catalog information for an album identified by their unique Spotify ID.
# * Sets up client with client id and client secret using spotipy library and fetches album information.

# %%
def get_album(client_id, client_secret, artist_id):
    data = None
    sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))
    try:
        data = sp.album(album_id)
    except spotipy.SpotifyException as e:
        print(f"Error retrieving album information: {e}")
    return data
    
data = get_album(client_id, client_secret, album_id)
pprint(data)
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#               'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#               'id': '20wkVLutqVOYrc0kxFs7rA',
#               'name': 'Daniel Caesar',
#               'type': 'artist',
#               'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'}],
#  'available_markets': ['AR',
#                        'AU',
#                        'AT',
#                        'BE',
#                        'BO',
#                        'BR',
#                        'BG',
#                        'CA',
#                        'CL',
#                        'CO',
#                        'CR',
#                        'CY',
#                        'CZ',
#                        'DK',
#                        'DO',
#                        'DE',
#                        'EC',
#                        'EE',
#                        'SV',
#                        'FI',
#                        'FR',
#                        'GR',
#                        'GT',
#                        'HN',
#                        'HK',
#                        'HU',
#                        'IS',
#                        'IE',
#                        'IT',
#                        'LV',
#                        'LT',
#                        'LU',
#                        'MY',
#                        'MT',
#                        'MX',
#                        'NL',
#                        'NZ',
#                        'NI',
#                        'NO',
#                        'PA',
#                        'PY',
#                        'PE',
#                        'PH',
#                        'PL',
#                        'PT',
#                        'SG',
#                        'SK',
#                        'ES',
#                        'SE',
#                        'CH',
#                        'TW',
#                        'TR',
#                        'UY',
#                        'US',
#                        'GB',
#                        'AD',
#                        'LI',
#                        'MC',
#                        'ID',
#                        'JP',
#                        'TH',
#                        'VN',
#                        'RO',
#                        'IL',
#                        'ZA',
#                        'SA',
#                        'AE',
#                        'BH',
#                        'QA',
#                        'OM',
#                        'KW',
#                        'EG',
#                        'MA',
#                        'DZ',
#                        'TN',
#                        'LB',
#                        'JO',
#                        'PS',
#                        'IN',
#                        'KZ',
#                        'MD',
#                        'UA',
#                        'AL',
#                        'BA',
#                        'HR',
#                        'ME',
#                        'MK',
#                        'RS',
#                        'SI',
#                        'KR',
#                        'BD',
#                        'PK',
#                        'LK',
#                        'GH',
#                        'KE',
#                        'NG',
#                        'TZ',
#                        'UG',
#                        'AG',
#                        'AM',
#                        'BS',
#                        'BB',
#                        'BZ',
#                        'BT',
#                        'BW',
#                        'BF',
#                        'CV',
#                        'CW',
#                        'DM',
#                        'FJ',
#                        'GM',
#                        'GE',
#                        'GD',
#                        'GW',
#                        'GY',
#                        'HT',
#                        'JM',
#                        'KI',
#                        'LS',
#                        'LR',
#                        'MW',
#                        'MV',
#                        'ML',
#                        'MH',
#                        'FM',
#                        'NA',
#                        'NR',
#                        'NE',
#                        'PW',
#                        'PG',
#                        'WS',
#                        'SM',
#                        'ST',
#                        'SN',
#                        'SC',
#                        'SL',
#                        'SB',
#                        'KN',
#                        'LC',
#                        'VC',
#                        'SR',
#                        'TL',
#                        'TO',
#                        'TT',
#                        'TV',
#                        'VU',
#                        'AZ',
#                        'BN',
#                        'BI',
#                        'KH',
#                        'CM',
#                        'TD',
#                        'KM',
#                        'GQ',
#                        'SZ',
#                        'GA',
#                        'GN',
#                        'KG',
#                        'LA',
#                        'MO',
#                        'MR',
#                        'MN',
#                        'NP',
#                        'RW',
#                        'TG',
#                        'UZ',
#                        'ZW',
#                        'BJ',
#                        'MG',
#                        'MU',
#                        'MZ',
#                        'AO',
#                        'CI',
#                        'DJ',
#                        'ZM',
#                        'CD',
#                        'CG',
#                        'IQ',
#                        'LY',
#                        'TJ',
#                        'VE',
#                        'ET',
#                        'XK'],
#  'copyrights': [{'text': '© 2023 Hollace Inc., under exclusive license to '
#                          'Republic Records, a division of UMG Recordings, Inc.',
#                  'type': 'C'},
#                 {'text': '℗ 2023 Hollace Inc., under exclusive license to '
#                          'Republic Records, a division of UMG Recordings, Inc.',
#                  'type': 'P'}],
#  'external_ids': {'upc': '00602455587794'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/7ivbFszr1TbVadj89BIy1y'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/7ivbFszr1TbVadj89BIy1y',
#  'id': '7ivbFszr1TbVadj89BIy1y',
#  'images': [{'height': 640,
#              'url': 'https://i.scdn.co/image/ab67616d0000b2737c68face1dc58127f3a7b1cc',
#              'width': 640},
#             {'height': 300,
#              'url': 'https://i.scdn.co/image/ab67616d00001e027c68face1dc58127f3a7b1cc',
#              'width': 300},
#             {'height': 64,
#              'url': 'https://i.scdn.co/image/ab67616d000048517c68face1dc58127f3a7b1cc',
#              'width': 64}],
#  'label': 'Republic Records',
#  'name': 'NEVER ENOUGH',
#  'popularity': 79,
#  'release_date': '2023-04-07',
#  'release_date_precision': 'day',
#  'total_tracks': 15,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/7ivbFszr1TbVadj89BIy1y/tracks?offset=0&limit=50',
#             'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#                                     'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#                                     'id': '20wkVLutqVOYrc0kxFs7rA',
#                                     'name': 'Daniel Caesar',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 153171,
#                        'explicit': False,
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5XUuMp2i5ojqcDOSusChqL'},
#                        'href': 'https://api.spotify.com/v1/tracks/5XUuMp2i5ojqcDOSusChqL',
#                        'id': '5XUuMp2i5ojqcDOSusChqL',
#                        'is_local': False,
#                        'name': 'Ocho Rios',
#                        'preview_url': None,
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:5XUuMp2i5ojqcDOSusChqL'},
#                       {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#                                     'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#                                     'id': '20wkVLutqVOYrc0kxFs7rA',
#                                     'name': 'Daniel Caesar',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 154531,
#                        'explicit': False,
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/0b83L1ToHRiwlpmUAjiCHc'},
#                        'href': 'https://api.spotify.com/v1/tracks/0b83L1ToHRiwlpmUAjiCHc',
#                        'id': '0b83L1ToHRiwlpmUAjiCHc',
#                        'is_local': False,
#                        'name': 'Valentina',
#                        'preview_url': None,
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:0b83L1ToHRiwlpmUAjiCHc'},
#                       {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#                                     'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#                                     'id': '20wkVLutqVOYrc0kxFs7rA',
#                                     'name': 'Daniel Caesar',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zkKkDDra0jlsiJYz57P3P'},
#                                     'href': 'https://api.spotify.com/v1/artists/1zkKkDDra0jlsiJYz57P3P',
#                                     'id': '1zkKkDDra0jlsiJYz57P3P',
#                                     'name': 'Mustafa',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:1zkKkDDra0jlsiJYz57P3P'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 277518,
#                        'explicit': False,
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/4t9R5rbtovdvya28uMODDz'},
#                        'href': 'https://api.spotify.com/v1/tracks/4t9R5rbtovdvya28uMODDz',
#                        'id': '4t9R5rbtovdvya28uMODDz',
#                        'is_local': False,
#                        'name': 'Toronto 2014 (with Mustafa)',
#                        'preview_url': None,
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:4t9R5rbtovdvya28uMODDz'},
#                       {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#                                     'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#                                     'id': '20wkVLutqVOYrc0kxFs7rA',
#                                     'name': 'Daniel Caesar',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
# ...
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 174512,
#                        'explicit': False,
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/736PP5LTtREkDgktNmX3Gu'},
#                        'href': 'https://api.spotify.com/v1/tracks/736PP5LTtREkDgktNmX3Gu',
#                        'id': '736PP5LTtREkDgktNmX3Gu',
#                        'is_local': False,
#                        'name': 'Superpowers',
#                        'preview_url': None,
#                        'track_number': 14,
#                        'type': 'track',
#                        'uri': 'spotify:track:736PP5LTtREkDgktNmX3Gu'},
#                       {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#                                     'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#                                     'id': '20wkVLutqVOYrc0kxFs7rA',
#                                     'name': 'Daniel Caesar',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 247805,
#                        'explicit': True,
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/0gmviE2bUkRUlEaQer08Ie'},
#                        'href': 'https://api.spotify.com/v1/tracks/0gmviE2bUkRUlEaQer08Ie',
#                        'id': '0gmviE2bUkRUlEaQer08Ie',
#                        'is_local': False,
#                        'name': 'Unstoppable',
#                        'preview_url': None,
#                        'track_number': 15,
#                        'type': 'track',
#                        'uri': 'spotify:track:0gmviE2bUkRUlEaQer08Ie'}],
#             'limit': 50,
#             'next': None,
#             'offset': 0,
#             'previous': None,
#             'total': 15},
#  'type': 'album',
#  'uri': 'spotify:album:7ivbFszr1TbVadj89BIy1y'}

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display result

# %% [markdown]
# * If album information is available, this will print out the required information.

# %%
if data:
    album_info = {
        "Name": data['name'],
        "Artist": data['artists'][0]['name'],
        "Release date": data['release_date'],
        "Total Tracks": data['total_tracks'],
        "Popularity": data['popularity'],
        "External URLs": data['external_urls'].get("spotify"),
        "Copyrights": data['copyrights'][0]['text'],
        "Image": data['images'][0].get("url"),
    }
    print("Album Information")
    print("-----------------")
    for key, value in album_info.items():
        if key == "Image":
            display(Image(url=value))
        else:
            print(f"{key}: {value}")
else:
    print("Failed to retrieve album information.")
# Out:
# Album Information
# -----------------
# Name: NEVER ENOUGH
# Artist: Daniel Caesar
# Release date: 2023-04-07
# Total Tracks: 15
# Popularity: 79
# External URLs: https://open.spotify.com/album/7ivbFszr1TbVadj89BIy1y
# Copyrights: © 2023 Hollace Inc., under exclusive license to Republic Records, a division of UMG Recordings, Inc.
# <img src="https://i.scdn.co/image/ab67616d0000b2737c68face1dc58127f3a7b1cc"/>
