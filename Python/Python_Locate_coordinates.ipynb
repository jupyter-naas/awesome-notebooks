# %% [markdown]
# <img width="8%" alt="Python.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Python.png" style="border-radius: 15%">

# %% [markdown]
# # Python - Locate coordinates
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Python+-+Locate+coordinates:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #python #snippet #naas #geocoder

# %% [markdown]
# **Author:** [Suhas B](https://www.linkedin.com/in/suhasbrao/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2023-03-24)

# %% [markdown]
# **Description:** This notebook provides a way to find the geographic coordinates of a given location using Python.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
try:
    import geocoder
except:
    # !pip install geocoder --user
    import geocoder

# %% [markdown]
# ### Setup Variables

# %%
latitude = 12.30215530579874
longitude = 76.65306751341747

# %% [markdown]
# ## Model

# %% [markdown]
# ### Get location from coordinates

# %%
location_from_coordinates = geocoder.arcgis([latitude, longitude], method="reverse")

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display location from coordinates

# %%
print(f"Location from coordinates: {location_from_coordinates[0]}")
