# %% [markdown]
# <img width="8%" alt="Naas.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Naas.png" style="border-radius: 15%">

# %% [markdown]
# # Naas - Dependency demo
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Naas+-+Dependency+demo:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #naas #dependency #snippet #operations

# %% [markdown]
# **Author:** [Jeremy Ravenel](https://www.linkedin.com/in/ACoAAAJHE7sB5OxuKHuzguZ9L6lfDHqw--cdnJg/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2021-04-14)

# %% [markdown]
# **Description:** This notebook demonstrates how to use Naas to manage dependencies in a project.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
import naas

# %% [markdown]
# ## Model

# %% [markdown]
# ### Path of your document

# %%
PATH = "PATH_OF_YOUR_DOCUMENT.png"

# %% [markdown]
# ## Output

# %% [markdown]
# ### Add the dependency

# %%
naas.dependency.add("YOUR_DOCUMENT.png")
