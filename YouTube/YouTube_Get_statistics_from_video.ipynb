# %% [markdown]
# <img width="8%" alt="YouTube.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/YouTube.png" style="border-radius: 15%">

# %% [markdown]
# # YouTube - Get statistics from video
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=YouTube+-+Get+statistics+from+video:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #youtube #video #statistics #naas_drivers #content #snippet #dataframe

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/ACoAABCNSioBW3YZHc2lBHVG0E_TXYWitQkmwog/)

# %% [markdown]
# **Last update:** 2023-04-12 (Created: 2022-03-18)

# %% [markdown]
# **Description:** This notebook provides a way to get detailed statistics from YouTube videos.

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import library

# %%
import naas
from naas_drivers import youtube

# %% [markdown]
# ### Variables
#
# To know how to generate a YouTube api key you can [watch this video](https://www.youtube.com/watch?v=ltdJOX_DVtE).

# %%
# Youtube api Key
YOUTUBE_API_KEY = naas.secret.get("YOUTUBE_API_KEY")

# Channel ID
video_url = "https://www.youtube.com/watch?v=W8H57kam9kg&t=3685s"

# %% [markdown]
# ## Model

# %%
df_stats = youtube.connect(YOUTUBE_API_KEY).video.get_statistics(video_url)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Display results

# %%
df_stats
