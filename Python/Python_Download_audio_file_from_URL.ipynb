# %% [markdown]
# <img width="8%" alt="Python.png" src="https://raw.githubusercontent.com/jupyter-naas/awesome-notebooks/master/.github/assets/logos/Python.png" style="border-radius: 15%">

# %% [markdown]
# # Python - Download audio file from URL
# <a href="https://bit.ly/3JyWIk6">Give Feedback</a> | <a href="https://github.com/jupyter-naas/awesome-notebooks/issues/new?assignees=&labels=bug&template=bug_report.md&title=Python+-+Download+audio+file+from+URL:+Error+short+description">Bug report</a>

# %% [markdown]
# **Tags:** #python #download #snippet #url #naas #operations

# %% [markdown]
# **Author:** [Florent Ravenel](https://www.linkedin.com/in/florent-ravenel/)

# %% [markdown]
# **Last update:** 2023-07-23 (Created: 2023-07-23)

# %% [markdown]
# **Description:** This notebook demonstrates how to download audio file from an URL using Python.

# %% [markdown]
# **References:**
# - [response.content – Python requests](https://www.geeksforgeeks.org/response-content-python-requests/)

# %% [markdown]
# ## Input

# %% [markdown]
# ### Import libraries

# %%
import requests

# %% [markdown]
# ### Setup Variables
# - `audio_url`: Audio URL

# %%
# Inputs
audio_url = "https://filesamples.com/samples/audio/m4a/sample4.m4a"

# %% [markdown]
# ## Model

# %% [markdown]
# ### Create output path

# %%
# Path to save the downloaded file
output_path = audio_url.split('/')[-1]
print("➡️ Output path:", output_path)

# %% [markdown]
# ## Output

# %% [markdown]
# ### Download audio file

# %%
def download_audio(url, output_path):
    # Send a GET request to download the file
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Save the content of the response (M4A file) to a local file
        with open(output_path, "wb") as file:
            file.write(response.content)
        print("✅ M4A file downloaded successfully.")
    else:
        print("❌ Failed to download the audio file.")
        
download_audio(audio_url, output_path)
